# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 235,
  'headline': 'Claude Sonnet 4.6 Lands on Amazon Bedrock Today',
  'output': "Anthropic's Claude Sonnet 4.6 is now live on Amazon Bedrock, upgrading from version 4.5 with sharper instruction following and better multi-step orchestration for agentic workflows. The model excels at coding, compliance review, financial modeling, and data summarization, and can serve as lead or subagent in multi-model pipelines. It ships with a 1 million token context window in preview, though beta limitations apply. Enterprise teams gain near-human reliability for browser-based automation across business tools, making it easier to scale AI adoption for knowledge work and spreadsheet generation starting today.",
  'image_url': None},
 {'id': 236,
  'headline': "Leonardo.Ai Opens API So Developers Can Embed Canva's AI",
  'output': "Leonardo.Ai launched its Creative Engine API on February 23, letting developers plug Leonardo's generative AI models directly into their own apps for design, gaming, media, and marketing. Acquired by Canva in July 2024, Leonardo now serves 19 million users and powers Dream Lab inside Canva's Magic Studio, which has logged 7 billion AI uses. The API runs on Leonardo's Phoenix foundation model and generates images in over 15 styles. For product teams, this means you can prototype and ship AI visuals inside your workflows this week without building models in-house. Canva promises no user content sharing unless teams opt in.",
  'image_url': None},
 {'id': 237,
  'headline': "DeepSeek's Next Model Could Shake Nasdaq, Details Unknown",
  'output': 'DeepSeek plans to release a new AI model, according to CNBC, though specifics on capabilities, availability, and timing remain undisclosed. The announcement itself carries weight because CNBC flags potential turbulence for Nasdaq stocks tied to major model releases, reflecting how investor sentiment now swings around AI launches. For teams, the lack of benchmarks or rollout details means planning around coding agents and data workflows stays speculative for now. The real signal is competitive pressure: every new entrant forces incumbents to accelerate, and markets are pricing in that uncertainty before technical details even land.',
  'image_url': None},
 {'id': 238,
  'headline': "Korea's ETRI Embeds 20 Safety Filters Inside Vision Models",
  'output': 'ETRI released Safe LLaVA, six vision-language models that bake safety directly into their architecture rather than relying on post-training fixes. The models embed roughly 20 harmful-content categorizers to automatically detect risks across seven areas and refuse unsafe requests with explanations. Six variants are now on Hugging Face, including Safe LLaVA 7B/13B, Safe Qwen-2.5-VL 7B/32B, and SafeGem 12B/27B, plus the HoliSafe-Bench dataset. Benchmarks show 93-97% safety rates. This shifts safety from moderation filters bolted on afterward to native model behavior, giving ML teams safer building blocks from day one.',
  'image_url': None},
 {'id': 239,
  'headline': "Wispr Flow's Android App Adds Hinglish Dictation Across Apps",
  'output': "Wispr Flow launched its Android app on February 23, bringing AI dictation to any app via a floating bubble that eliminates keyboard switching. A complete infrastructure rewrite delivers 30% faster transcription, while new Hinglish support handles mixed Hindi-English speech across 100+ languages including Spanish, Portuguese, French, Italian, Thai, Chinese, and Hindi. Automatic translation isn't available yet, and Android requires an internet connection. For Android-heavy teams, especially in India, the cross-app dictation could cut typing friction significantly starting this week, though real productivity gains depend on piloting it in your actual workflow.",
  'image_url': None},
 {'id': 240,
  'headline': 'OpenAI Taps McKinsey, BCG, Accenture to Sell Frontier AI',
  'output': "OpenAI has formed multiyear Frontier Alliances with Accenture, BCG, Capgemini, and McKinsey to sell and deploy its Frontier AI agent platform into enterprise clients. The partnerships embed OpenAI's Forward Deployed Engineering team with dedicated practice groups at each consulting firm to accelerate production rollouts. Early Frontier customers include Intuit, State Farm, Thermo Fisher, and Uber. The move signals OpenAI's pivot from direct sales to a consulting-led enterprise go-to-market strategy, essentially outsourcing implementation to firms that already own C-suite relationships. No equity or financial terms were disclosed in the strategic agreements.",
  'image_url': None},
 {'id': 241,
  'headline': "Picsart's Aura Generates Images and Video in One Chat",
  'output': 'Picsart launched Aura, an AI assistant that generates both images and video from a single prompt conversation, eliminating tool-switching for creators. It remembers context across iterations, supports multi-scene videos and full campaigns, and offers clonable session links for team collaboration. The platform serves 150M+ creators and claims its AI video tool cuts production time 80% and delivers 58% higher engagement. For marketing teams, Aura compresses ideation-to-publish cycles and enables faster A/B testing across social formats. Pilot with a cross-functional squad to produce three to five campaigns in two-week sprints and measure time-to-publish gains.',
  'image_url': None},
 {'id': 242,
  'headline': 'Amazon Drops $12B on Louisiana AI Data Centers',
  'output': "Amazon is pumping $12 billion into northwest Louisiana to build two interconnected data center campuses dedicated to AI and cloud computing workloads, with partner STACK Infrastructure handling development. Construction starts in the coming weeks and will roll out in phases over multiple years. Amazon is also funding up to $400 million in local water infrastructure upgrades. The project will create 540 permanent on-site jobs, 1,700 indirect positions, and 1,500 construction roles. The scale signals Amazon's bet on regional capacity to meet surging AI compute demand outside traditional tech hubs.",
  'image_url': None},
 {'id': 243,
  'headline': "Commotion's AI OS Resolves 40% of Enterprise Tasks Autonomously",
  'output': 'Commotion launched an Enterprise AI Operating System built on NVIDIA Nemotron open models that lets AI Workers complete end-to-end business tasks across telecom, aviation, hospitality, and automotive sectors. Live deployments show a global telecom resolving over 40% of operational issues autonomously with 35% faster resolution, while an airline expects AI to handle 30% of customer calls in year one. An Indian automotive OEM saw 50% higher ROI, 30% lower cost per call, and 60% fewer peak-hour calls. The unified orchestration layer maintains governance while scaling automation across regions and languages, moving enterprises from pilots to production-grade AI Workers.',
  'image_url': None},
 {'id': 244,
  'headline': 'Lightspeed Leads $23M Series A in AI Accounting Startup Stacks',
  'output': 'Stacks closed a $23 million Series A led by Lightspeed on February 19, 2026, with EQT Ventures, General Catalyst, and S16VC participating. The AI accounting platform, which raised $12 million in its seed round a year ago, now counts over 30 enterprise customers including Future PLC and Epidemic Sound. The fresh capital will scale the platform and accelerate enterprise deployments. With total funding now around $35 million, Stacks is pushing into corporate finance departments as AI automation moves beyond pilot projects into production accounting workflows.',
  'image_url': None},
 {'id': 245,
  'headline': "Samsung Embeds Perplexity Across Galaxy S26 with 'Hey Plex'",
  'output': 'Samsung is adding Perplexity as a system-level AI agent on the Galaxy S26 and future flagships, activated by saying "Hey Plex" or holding the side button. The assistant will be embedded directly into Notes, Clock, Gallery, Reminders, and Calendar apps, plus select third-party apps, letting users complete multi-step tasks without switching apps manually. Samsung\'s internal research shows 8 in 10 users already juggle multiple AI agents daily. Full details drop at Galaxy Unpacked on February 25, though availability varies by carrier and device. This means Galaxy users can finally orchestrate cross-app workflows through one wake word instead of app-hopping.',
  'image_url': None},
 {'id': 246,
  'headline': "MercadoLibre's CEO Backs Humand's $66M AI Play for Deskless Workers",
  'output': "Argentina's Humand just closed a $66M Series A led by Kaszek Ventures and Goodwater Capital to scale its AI operating system for the world's 2.7 billion deskless workers. MercadoLibre founder Marcos Galperin joined as an angel investor alongside Y Combinator and Dropbox co-founder Arash Ferdowsi. The cash fuels US expansion and AI agent development across 30+ HR and operations modules. The bet signals investor appetite for HRtech targeting frontline workers in retail, logistics, and hospitality where traditional software has struggled to gain traction.",
  'image_url': None},
 {'id': 247,
  'headline': 'Cadence Closes €2.7B Hexagon D&E Acquisition in Push for Physical AI',
  'output': "Cadence Design Systems completed its €2.7 billion acquisition of Hexagon's Design & Engineering business on February 23, paying 70% cash and 30% stock (roughly 3.2 million shares). The deal adds MSC Software's simulation tools like MSC Nastran and Adams to Cadence's multiphysics portfolio, coupling physics-based simulation with AI-driven design exploration. Cadence expects $160 million incremental revenue in 2026 but a 28-cent non-GAAP EPS dilution before turning accretive in 2027. The move signals Cadence is betting big on Physical AI workflows that marry traditional engineering simulation with machine learning.",
  'image_url': None},
 {'id': 248,
  'headline': 'DeepSeek, Moonshot, MiniMax Used 24,000 Fake Accounts to Clone Claude',
  'output': 'Anthropic reported that three Chinese AI labs ran model-distillation campaigns using over 16 million Claude interactions through roughly 24,000 fraudulent accounts to steal capabilities. DeepSeek targeted reasoning and censorship rewrites; Moonshot focused on agentic tasks and coding; MiniMax pursued tool orchestration. When Anthropic released a new model mid-campaign, operators pivoted within 24 hours and redirected nearly half their traffic to capture the latest system. The attacks highlight how competitor models can be rapidly replicated through illicit extraction, potentially bypassing export controls and weakening safety guardrails at scale. Implementation takeaway: deploy distillation-detection telemetry to flag high-volume, repetitive API prompts this quarter.',
  'image_url': None},
 {'id': 249,
  'headline': 'Anthropic Blocked 16 Million Illicit Queries from Chinese AI Labs',
  'output': "Anthropic disclosed it detected and shut down three industrial-scale campaigns by DeepSeek, Moonshot AI, and MiniMax to illicitly clone Claude's capabilities through 16 million exchanges across 24,000 fraudulent accounts. The labs used sprawling proxy networks to extract reasoning patterns, coding skills, and tool use via coordinated queries that shifted within 24 hours when new Claude models dropped. Anthropic warns distillation attacks circumvent export controls and strip safety guardrails, creating risks for cyber operations and disinformation. The company is urging industry-wide intelligence sharing and deploying behavioral fingerprinting to catch coordinated account activity before capabilities leak to foreign competitors.",
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA single, oversized 3D cloud form in bright coral-orange floating against a deep teal background, with a sleek silver pipeline or conduit threading through its center. The cloud has a soft, billowing texture that suggests both data and abstraction, while the metallic pipe represents connectivity and infrastructure. Minimalist editorial illustration style with dramatic lighting that creates a gentle glow around',
#   'id': 235},
#  {'final_output': '# Image Prompt\n\nA single giant glowing golden key floating horizontally against a deep purple gradient background, with its teeth transforming into colorful abstract paint brush strokes and digital pixels that dissolve into the negative space. The key is positioned in the center-left, rendered in a bold editorial illustration style with smooth gradients and sharp edges. The background uses generous negative space with a subtle radial glow eman',
#   'id': 236},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 235,
#   'headline': 'Claude Sonnet 4.6 Lands on Amazon Bedrock Today',
#   'output': "Anthropic's Claude Sonnet 4.6 is now live on Amazon Bedrock, upgrading from version 4.5 with sharper instruction following and better multi-step orchestration for agentic workflows. The model excels at coding, compliance review, financial modeling, and data summarization, and can serve as lead or subagent in multi-model pipelines. It ships with a 1 million token context window in preview, though beta limitations apply. Enterprise teams gain near-human reliability for browser-based automation across business tools, making it easier to scale AI adoption for knowledge work and spreadsheet generation starting today.",
#   'image_url': None},
#  {'id': 236,
#   'headline': "Leonardo.Ai Opens API So Developers Can Embed Canva's AI",
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': '# Image Prompt\n\nA single, oversized 3D cloud form in bright coral-orange floating against a deep teal background, with a sleek silver pipeline or conduit threading through its center. The cloud has a soft, billowing texture that suggests both data and abstraction, while the metallic pipe represents connectivity and infrastructure. Minimalist editorial illustration style with dramatic lighting that creates a gentle glow around',
  'id': 235},
 {'final_output': '# Image Prompt\n\nA single giant glowing golden key floating horizontally against a deep purple gradient background, with its teeth transforming into colorful abstract paint brush strokes and digital pixels that dissolve into the negative space. The key is positioned in the center-left, rendered in a bold editorial illustration style with smooth gradients and sharp edges. The background uses generous negative space with a subtle radial glow eman',
  'id': 236},
 {'final_output': '# Image Prompt\n\nA single sleek black chess knight piece casting a long, dramatic shadow across a vibrant tech-blue surface, with the shadow fragmenting into digital pixels as it extends. Minimalist composition with the chess piece positioned in the left third of the frame, leaving generous negative space in glossy blue on the right. The piece has a subtle metallic sheen with gradient highlights. Shot from a',
  'id': 237},
 {'final_output': '# Image Prompt\n\nA single, minimalist digital shield icon rendered in soft gradients of blue and white, floating in clean negative space against a gentle lavender background. The shield has a subtle geometric pattern of interconnected hexagonal nodes or circuits embedded within its surface, suggesting AI architecture. One small eye symbol is centered on the shield, representing vision AI. The composition is centered with abundant breathing room, using a modern',
  'id': 238},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a large smartphone floating vertically in space, with a glowing speech bubble emerging from its screen that contains both Hindi देवनागरी script and English letters flowing together in a seamless, intertwined pattern. The speech bubble is oversized and prominent. Color palette: deep indigo background, coral pink smartphone, bright cyan glowing speech bubble with white',
  'id': 239},
 {'final_output': '# Image Prompt\n\nA single sleek robotic handshake emerging from beneath a pristine surface against a bold gradient background of deep navy blue transitioning to vibrant coral orange. The handshake is rendered in a modern, geometric illustration style—one hand represented by metallic chrome segments with subtle circuit-like details (representing AI), the other in matte charcoal gray with a crisp suit c',
  'id': 240},
 {'final_output': '# Image Prompt\n\nA sleek smartphone floating in vertical orientation against a soft gradient background, with a single glowing chat bubble emerging from its screen. From the chat bubble, a stylized film strip unfurls and transforms into colorful paint strokes that dissolve into the negative space. The color palette features vibrant electric purple, coral pink, and bright cyan against a clean cream or off-white background.',
  'id': 241},
 {'final_output': '# Image Prompt\n\nA bold editorial illustration in wide 16:9 format showing a single massive server tower rising from Louisiana bayou water, rendered in a minimalist style. The server is depicted as a sleek, geometric monolith in deep blacks and metallic silvers with subtle glowing blue circuit-like details. Spanish moss drapes elegantly from one corner of the structure, bridging technology and',
  'id': 242},
 {'final_output': '# Image Prompt\n\nA sleek, minimalist illustration of a single glowing AI brain or neural node floating above a simplified desk workspace, with gentle circuit-like connections dissolving into particles that drift upward. The brain/node is rendered in vibrant electric blue and cyan gradients, while the desk below shows only the subtle outline of a laptop in warm coral or orange. The background is a clean gradient from',
  'id': 243},
 {'final_output': '# Image Prompt\n\nA single glowing stack of coins or ledger books levitating against a deep gradient background transitioning from navy blue to electric purple. A subtle beam of light illuminates the stack from above, creating a long shadow below. The composition is vertical-center with vast negative space surrounding the central object. Modern editorial illustration style with bold, saturated colors and clean geometric shapes. Minimalist corporate',
  'id': 244},
 {'final_output': '**Image Prompt:**\n\nA sleek Samsung Galaxy smartphone floating vertically in space with a glowing purple speech bubble emerging from its screen containing the text "Hey Plex". Minimalist composition against a gradient background transitioning from deep blue to vibrant magenta. The phone is rendered in clean, editorial illustration style with bold outlines and flat colors. The speech bubble has a luminous, holographic quality',
  'id': 245},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A single large smartphone floating in clean negative space, rendered in bold teal/turquoise. On the glowing screen, a simple silhouette of a warehouse worker or delivery person wearing a safety vest, depicted in warm orange/coral. The figure appears to be interfacing with or emerging from the screen, symbolizing',
  'id': 246},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of two interlocking geometric gears merging together - one gear rendered in electric cyan blue, the other in vibrant coral orange - against a clean white background with generous negative space. At the point where the gears mesh, small circuit-pattern details and neural network nodes subtly emerge, symbolizing the fusion of traditional engineering with AI. The gears are positioned',
  'id': 247},
 {'final_output': "# Image Prompt\n\nA striking editorial illustration showing a single large Claude AI logo (Anthropic's distinctive orange-coral wavemark) being reflected/cloned into two ghostly, translucent mirror copies that fade into darkness. The original logo is solid and vivid in warm coral-orange, while the clone reflections appear as cold blue-tinted, semi-transparent phantoms. Minimal composition with",
  'id': 248},
 {'final_output': '# Image Prompt\n\nA single oversized padlock in bold red, positioned prominently against a clean gradient background transitioning from deep navy to electric blue. Behind the lock, faint ghostly silhouettes of multiple identical keys in pale gray dissolve into the negative space, suggesting blocked attempts. The composition is minimal and asymmetric, with the solid padlock occupying the left third of the frame and vast',
  'id': 249}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 with open(file_name, "rb") as f:
#       3     image_bytes = f.read()
# ----> 5 supabase.storage.from_("article-image").upload(
#       6     "52.png",
#       7     image_bytes,
#       8     file_options={"content-type": "image/png"}
#       9 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/storage3/_sync/file_api.py:578, in SyncBucketActionsMixin.upload(self, path, file, file_options)
#     564 """
#     565 Uploads a file to an existing bucket.
#     566
#    (...)
#     575     HTTP headers.
#     576 """
#     577 path_parts = relative_path_to_parts(path)
# --> 578 return self._upload_or_update("POST", path_parts, file, file_options)
#
# ...

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
