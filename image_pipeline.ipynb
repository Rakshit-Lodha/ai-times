# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 146,
  'headline': "Meta's $2B Manus AI Now Automates Your Ad Campaigns",
  'output': "Meta has started rolling out Manus AI inside Ads Manager, letting advertisers automate grunt work like data analysis and report generation. Manus, acquired in December for over $2 billion, is an autonomous AI agent that handles multi-step tasks without constant human input. Think of it as a smart intern that actually delivers: it can build reports, research audiences, and even code. Meta severed all Chinese ties post-acquisition, relocating Manus to Singapore. This marks Meta's pivot from chatbots to agentic AI, agents that execute complex workflows independently. As Manus scales across Meta's platforms, advertisers could spend less time on spreadsheets and more time on strategy.",
  'image_url': None},
 {'id': 147,
  'headline': 'Unilever Goes All-In On Google AI For Shopping Revolution',
  'output': 'Unilever just signed a five-year deal with Google Cloud to transform how you discover and buy Dove, Vaseline, and Hellmann\'s using AI. The consumer goods giant is migrating its entire data platform to Google Cloud and deploying Vertex AI to power what they call "agentic commerce." Think intelligent systems that can predict what you need, personalize marketing in real-time, and create conversational shopping experiences. Essentially, AI agents will handle complex tasks across Unilever\'s operations, from brand discovery to customer engagement. This could reshape how everyday products reach consumers, making shopping more intuitive and brands more responsive in an AI-driven marketplace.',
  'image_url': None},
 {'id': 148,
  'headline': "India's Sarvam AI Launches Kaze Smart Glasses in May",
  'output': "Sarvam AI unveiled Kaze, India's first homegrown AI smart glasses, at the India AI Impact Summit 2026, with PM Modi testing the device on the expo floor. The glasses pack dual front cameras, microphones, and speakers, running on-device AI models trained specifically for Indian languages. Think real-time voice interaction and visual capture, all processed locally for privacy. Developers can build custom apps on Sarvam's platform, differentiating Kaze from competitors like Meta's Ray-Ban glasses. Set to launch in May 2026, Kaze signals India's ambition in sovereign AI hardware, potentially democratizing accessible, language-inclusive wearable tech for millions across the subcontinent.",
  'image_url': None},
 {'id': 149,
  'headline': "Alibaba's Qwen3.5 Claims to Beat GPT-5.2 at 60% Less Cost",
  'output': "Alibaba just dropped Qwen3.5, an agentic AI model designed to autonomously handle complex tasks across apps, devices, and languages. The beast packs 397 billion parameters but activates only 17 billion per task using a sparse Mixture-of-Experts setup, making it blazing fast and surprisingly cheap. It understands text, images, video, and UI screenshots across 201 languages, with context stretching up to 1 million tokens. Alibaba claims it outperforms GPT-5.2, Claude Opus 4.5, and Gemini 3 Pro while running 60% cheaper and eight times faster on big workloads. This launch signals China's serious play to dominate enterprise AI infrastructure globally, especially as Alibaba pours 380 billion yuan into AI expansion through 2028.",
  'image_url': None},
 {'id': 150,
  'headline': '19-Year-Old Raises $7M To Kill The Chatbot Era',
  'output': 'Skygen.AI just emerged from stealth with $7 million in seed funding and a bold claim: chatbots are over. Founded by 19-year-old Mike Shperling in San Francisco, the startup built autonomous AI agents that can actually control software like humans do. Think AI clicking through your CRM, ERP, or banking apps two to three times faster than current tools, learning as it goes. The platform uses isolated virtual machines and zero-trust security, so your data stays locked down. Instead of answering questions, these agents complete entire workflows autonomously. If Skygen delivers, enterprises could automate digital labor at scale, turning AI from assistant to employee.',
  'image_url': None},
 {'id': 151,
  'headline': 'Infosys and Anthropic Team Up for AI Agents',
  'output': "Infosys and Anthropic are partnering to build agentic AI solutions, starting with telecommunications before expanding to finance, manufacturing, and software development. Think of agentic AI as a digital assistant that independently handles multi-step tasks without constant human supervision. The collaboration integrates Anthropic's Claude models with Infosys Topaz to automate complex workflows and modernize outdated systems in heavily regulated industries. A dedicated Center of Excellence will develop industry-specific AI agents. With India being a major hub for Claude activity, this partnership could accelerate how enterprises adopt intelligent automation, potentially transforming operations across sectors by making AI agents handle persistent, complex processes that traditionally required human coordination.",
  'image_url': None},
 {'id': 152,
  'headline': 'Alibaba Drops Qwen3.5: AI Agents Just Got Cheaper',
  'output': "Alibaba just launched Qwen3.5, a massive AI model built specifically for autonomous agents that can handle multi-step tasks on their own. Think of it as an AI assistant that doesn't just answer questions but actually completes entire workflows without hand-holding. The flagship model packs 397 billion parameters but cleverly activates only 17 billion at a time, making it super efficient. It handles an insane 1 million token context window, speaks 201 languages, and costs just 0.8 yuan per million tokens. Alibaba claims it rivals top US models on benchmarks while undercutting them on price. If agentic AI becomes the next battleground, Qwen3.5's open-source availability and rock-bottom pricing could accelerate enterprise adoption and force competitors to slash costs or risk losing developer mindshare in the agent-building race.",
  'image_url': None},
 {'id': 153,
  'headline': "China's Moonshot AI Hunts $10B Valuation With Kimi Chatbot",
  'output': "Beijing-based Moonshot AI is targeting a massive $10 billion valuation as it expands its funding round, with over $700 million already secured from tech giants Alibaba and Tencent, alongside 5Y Capital. The startup's flagship product, Kimi chatbot, tackles complex tasks like coding and multi-step problem solving. This move capitalizes on surging investor appetite for Chinese AI developers aiming to challenge Silicon Valley's dominance. If successful, this valuation would cement Moonshot as a major player in the global AI race, potentially reshaping the competitive landscape between Eastern and Western AI powerhouses.",
  'image_url': None},
 {'id': 154,
  'headline': 'Adani Drops $100B Bomb on Green AI Data Centers',
  'output': "Adani Group just announced a massive $100 billion plan to build renewable-powered AI data centers across India by 2035, tripling its capacity from 2 GW to 5 GW. This investment is expected to trigger another $150 billion in related spending on servers, cloud platforms, and infrastructure, creating a $250 billion AI ecosystem. Google is partnering on a gigawatt-scale campus in Visakhapatnam, while Microsoft joins for facilities in Hyderabad and Pune. Powered by Adani's 30 GW Khavda renewable energy project, this integrated energy-and-compute platform positions India as a serious global AI infrastructure player, potentially attracting $200 billion in total data center investments and establishing technological sovereignty in the AI race.",
  'image_url': None},
 {'id': 155,
  'headline': "Bill Ackman Bets $2 Billion on Meta's AI Future",
  'output': "Billionaire investor Bill Ackman's hedge fund Pershing Square just disclosed a massive $2 billion stake in Meta, representing 10% of the fund's capital. The bet, initiated in November 2025 at around $625 per share, centers on Meta's aggressive AI push. Despite Meta planning to spend between $115 billion and $135 billion on AI in 2026, its stock has slumped over investor concerns about these massive expenditures. Ackman believes the market is underestimating how AI integration across Facebook, Instagram, and WhatsApp could drive future profits. This move signals growing conviction among top investors that Meta's AI gamble will eventually pay off big, potentially reshaping social media economics and validating huge tech spending on artificial intelligence infrastructure.",
  'image_url': None},
 {'id': 156,
  'headline': 'Cohere Drops Tiny Aya: Offline AI for 70+ Languages',
  'output': "Cohere just unveiled Tiny Aya, a family of open-weight AI models packing 3.35 billion parameters across 70+ languages, announced at India's AI Summit. The twist? These models run entirely offline on your device, no internet needed. Think real-time translation for Bengali, Hindi, Tamil, and dozens more without data costs or connectivity issues. Regional variants like Tiny Aya Earth (African/West Asian languages) and Fire (South Asian) target specific linguistic needs. Trained on just 64 Nvidia H100 GPUs, the models are available on Hugging Face for researchers and developers. This could democratize AI access in connectivity-poor regions, making powerful language tech genuinely accessible where internet infrastructure lags behind.",
  'image_url': None},
 {'id': 157,
  'headline': "AlphaFold's Free Protein Database Hits 3 Million Researchers",
  'output': "Google DeepMind's AlphaFold Protein Database now serves over 3 million researchers across 190+ countries, offering free access to 240 million predicted protein structures. Think of it as Google Maps for biology: scientists can now see the 3D shapes of nearly every known protein instantly, rather than spending months in labs. Real-world wins include Malaysian teams fighting tropical disease Melioidosis and Indian researchers breeding drought-resistant crops. With 2024's AlphaFold 3 launch and over 30% of citations tied to disease research, this Nobel Prize-winning tool is turning protein prediction from a niche science into everyday infrastructure for global health breakthroughs.",
  'image_url': None},
 {'id': 158,
  'headline': 'SurrealDB 3.0 Wants to Kill Your Five-Database Stack',
  'output': 'SurrealDB 3.0 just dropped with a $23 million funding extension (now $44 million total), promising one Rust-native engine to replace your entire relational, document, graph, vector, and time-series setup. The kicker? It embeds AI agent memory and business logic directly inside the database via its Surrealism plugin, so your AI can think, remember, and act without juggling five different systems. With 2.3 million downloads and 31,000 GitHub stars, developers are clearly hooked. If it delivers, enterprise AI stacks could get a lot simpler, and database vendors a lot more nervous.',
  'image_url': None},
 {'id': 159,
  'headline': 'Figma and Claude Just Made Code Talk to Design',
  'output': 'Figma and Anthropic just dropped Code to Canvas, letting developers turn AI-generated code from Claude directly into fully editable Figma designs. Install the Figma Model Context Protocol server, run Claude Code, and watch lines of code transform into design layers you can tweak on the canvas. It works both ways: designers can export Figma files to seed code generation, creating a true roundtrip workflow. Claude can even generate FigJam diagrams from screenshots or PDFs. This blur between code and design could finally bridge the developer-designer gap, speeding up prototyping and making cross-functional collaboration smoother across product teams.',
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA sleek robotic hand made of metallic blue and purple gradient material delicately manipulating a single oversized advertising megaphone that glows with warm orange and pink tones. The composition is minimal and centered, set against a clean cream or pale blue background with dramatic shadows. The robotic hand should appear precise and elegant, suggesting automation and intelligence, while the megaphone represents',
#   'id': 146},
#  {'final_output': '# Image Prompt\n\nA clean, minimalist editorial illustration showing a single shopping cart glowing with soft AI-infused light, filled with just two iconic product silhouettes (a soap bar and a jar). The cart floats against a bold gradient background of Google blue transitioning to clean white, with subtle digital particles or dots emanating from the cart suggesting AI intelligence. The composition is centered with generous negative space',
#   'id': 147},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 146,
#   'headline': "Meta's $2B Manus AI Now Automates Your Ad Campaigns",
#   'output': "Meta has started rolling out Manus AI inside Ads Manager, letting advertisers automate grunt work like data analysis and report generation. Manus, acquired in December for over $2 billion, is an autonomous AI agent that handles multi-step tasks without constant human input. Think of it as a smart intern that actually delivers: it can build reports, research audiences, and even code. Meta severed all Chinese ties post-acquisition, relocating Manus to Singapore. This marks Meta's pivot from chatbots to agentic AI, agents that execute complex workflows independently. As Manus scales across Meta's platforms, advertisers could spend less time on spreadsheets and more time on strategy.",
#   'image_url': None},
#  {'id': 147,
#   'headline': 'Unilever Goes All-In On Google AI For Shopping Revolution',
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': '# Image Prompt\n\nA sleek robotic hand made of metallic blue and purple gradient material delicately manipulating a single oversized advertising megaphone that glows with warm orange and pink tones. The composition is minimal and centered, set against a clean cream or pale blue background with dramatic shadows. The robotic hand should appear precise and elegant, suggesting automation and intelligence, while the megaphone represents',
  'id': 146},
 {'final_output': '# Image Prompt\n\nA clean, minimalist editorial illustration showing a single shopping cart glowing with soft AI-infused light, filled with just two iconic product silhouettes (a soap bar and a jar). The cart floats against a bold gradient background of Google blue transitioning to clean white, with subtle digital particles or dots emanating from the cart suggesting AI intelligence. The composition is centered with generous negative space',
  'id': 147},
 {'final_output': '# Image Prompt\n\nA sleek, modern pair of smart glasses floating in elegant three-quarter view against a rich saffron orange gradient background. The glasses feature a minimalist black frame design with subtle lens reflections showing hints of digital interface elements. A single small microphone detail visible on the temple. Clean studio lighting creates a soft shadow beneath the glasses. Editorial illustration style with bold, saturated colors - deep',
  'id': 148},
 {'final_output': "# Image Prompt\n\nA powerful Chinese dragon made of flowing digital particles and circuit patterns facing off against a sleek Western knight's chess piece, both rendered in a bold editorial illustration style. The dragon glows in vibrant electric red and gold, while the chess piece is rendered in cool blue-gray. Minimal composition with the two elements meeting in the center against a clean gradient background from deep navy to white, suggesting",
  'id': 149},
 {'final_output': "# Image Prompt\n\nA sleek robotic hand pressing a large, glowing red power button that's shutting down a simple chat bubble icon. The composition is minimal and centered, with the robotic hand entering from the left side in chrome silver, the oversized circular button in vibrant red at the center, and a fading speech bubble symbol on the button's surface. Dark navy blue background with plenty of",
  'id': 150},
 {'final_output': '# Image Prompt\n\nA sleek, modern illustration of a single robotic hand or mechanical arm emerging from the bottom of the frame, holding or passing a glowing, luminous orb or sphere of light. The orb radiates soft, intelligent energy in vibrant electric blue and purple hues. The background is a clean gradient from deep navy to soft violet, with minimal geometric line work suggesting digital connectivity.',
  'id': 151},
 {'final_output': '# Image Prompt\n\nA single sleek robotic hand or arm composed of geometric, minimalist segments reaching down to pick up or hold a glowing golden coin, set against a bold gradient background transitioning from deep purple to electric blue. The robotic arm should be rendered in a modern editorial illustration style with clean lines and metallic silver-white coloring. The coin emits a soft luminous glow,',
  'id': 152},
 {'final_output': '# Image Prompt\n\nA sleek silver rocket ship pointed upward toward a glowing crescent moon against a deep midnight blue sky. The rocket has subtle Chinese design elements and a small chat bubble icon on its side. Bold, vibrant composition with the rocket positioned in the lower third, creating dramatic upward movement and vast empty space above, symbolizing ambitious growth and moonshot aspirations.\n\n**Style**: Modern',
  'id': 153},
 {'final_output': '# Image Prompt\n\nA single massive server tower monument rising from a bed of vibrant green solar panels that stretch to the horizon, set against a bold gradient sky of saffron orange transitioning to deep tech blue. The server tower is rendered as a sleek, minimalist monolithic structure with subtle glowing circuit patterns, planted like a seed in the renewable energy field. The composition is extremely simple with the tower',
  'id': 154},
 {'final_output': '# Image Prompt\n\nA giant, gleaming blue Meta logo sphere floating in white space, with a single golden chess piece (king or knight) positioned confidently on top of it. The Meta sphere has a subtle gradient and modern tech sheen. The chess piece should be oversized and prominent, symbolizing the strategic investment move. Clean shadows beneath both objects. Bold editorial illustration style with a limited color palette: deep',
  'id': 155},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single glowing smartphone floating in space, with subtle light trails of different vibrant colors (saffron orange, turquoise, magenta) flowing out from its screen and dissolving into the air around it, representing multilingual communication radiating outward. The phone is centered against a deep navy blue background with ample negative space. The light trails are',
  'id': 156},
 {'final_output': "# Image Prompt\n\nA single oversized protein structure floating in clean white space, rendered as an elegant 3D ribbon diagram in vibrant turquoise and coral gradient colors. The protein's flowing, twisted form casts a subtle shadow below. Tiny silhouettes of diverse scientists (2-3 figures) stand at the base, gazing up at the structure in awe, emphasizing the mon",
  'id': 157},
 {'final_output': '# Image Prompt\n\nA single, bold database cylinder being pierced or shattered by a glowing Rust-orange geometric spear or arrow, with fragments of the database dissolving into particles. The database is rendered in deep purple or navy blue, while the penetrating element glows in vibrant Rust orange with subtle circuit-like patterns. Clean white or light gradient background with generous negative space around the central',
  'id': 158},
 {'final_output': '# Image Prompt\n\nA sleek editorial illustration showing a single speech bubble or dialogue balloon that seamlessly transitions from geometric code brackets "{}" on one side to smooth curved design pen tool nodes on the other side. The speech bubble floats centrally against a vibrant two-tone background split between electric blue and coral orange. Minimalist, bold, and symbolic—the merging bubble represents code and design finally speaking',
  'id': 159}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        public_urls_5.append({
            'public_url': public_url,
            'id': i['id']
        })

        print(f"✅ {i['final_output']} → {public_url}")

# %%
image_result(prompt)
# Out:
# Storage endpoint URL should have a trailing slash.
# ✅ # Image Prompt
#
# A sleek robotic hand made of metallic blue and purple gradient material delicately manipulating a single oversized advertising megaphone that glows with warm orange and pink tones. The composition is minimal and centered, set against a clean cream or pale blue background with dramatic shadows. The robotic hand should appear precise and elegant, suggesting automation and intelligence, while the megaphone represents → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png
# ✅ # Image Prompt
#
# ...

# %%
a = []
for i in public_urls_5:
    if i['id']>=146:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
#   'id': 146},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
#   'id': 147},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
#   'id': 148},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
#   'id': 149},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
#   'id': 150},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
#   'id': 151},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
#   'id': 152},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
#   'id': 153},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(public_urls_6)

# %%
def upload_to_supabase(dictionary):
    for i in dictionary:
        supabase.table("hundred_word_articles").update(
                {"image_url": i['public_url']}
            ).eq("id", i['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
