# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 160,
  'headline': 'Meta and NVIDIA Partner to Build Personal Superintelligence',
  'output': 'Meta and NVIDIA just announced a massive multiyear partnership to deploy millions of next-gen Blackwell and Rubin GPUs across Meta\'s AI infrastructure. The goal? Delivering what Zuckerberg calls "personal superintelligence" to users. Meta will build hyperscale data centers optimized for training and inference, integrating NVIDIA\'s Spectrum-X Ethernet and Arm-based Grace CPUs. The collaboration extends NVIDIA\'s privacy-preserving tech to WhatsApp and beyond. Engineering teams will co-design systems to optimize Meta\'s AI models. This alliance could reshape how billions access AI-powered assistance, potentially bringing ChatGPT-level capabilities directly into Facebook, Instagram, and WhatsApp by 2027.',
  'image_url': None},
 {'id': 161,
  'headline': '91% of Customer Service Leaders Pressured to Deploy AI',
  'output': 'A Gartner survey of 321 customer service leaders reveals that 91% face executive pressure to implement AI in 2026, marking an urgent industry-wide transformation. The shift means robots are taking over repetitive support tasks, pushing companies to reimagine human roles. Nearly 80% plan to transition frontline agents into new positions, with 84% adding skills like knowledge management to support AI systems. Think less scripted chat responses, more strategic problem-solving. The goal is faster resolutions and smoother customer journeys through self-service. This signals a future where AI handles the basics while humans tackle complex issues, potentially redefining what customer service actually means.',
  'image_url': None},
 {'id': 162,
  'headline': 'Claude Sonnet 4.6 Drops with 1M Token Superpowers',
  'output': "Anthropic just launched Claude Sonnet 4.6, a major upgrade boosting coding, reasoning, and agent planning. The standout? A massive 1M token context window that can swallow entire codebases, lengthy contracts, or dozens of research papers in one go. Pricing stays unchanged at $3/$15 per million tokens, and it's now the default model for Free and Pro users. The API adds automated web search tools and Excel gets MCP connector support for external data sources like S&P Global and PitchBook. This could reshape how developers handle complex projects and how analysts crunch data, making AI assistance far more comprehensive without extra cost.",
  'image_url': None},
 {'id': 163,
  'headline': 'Kana Raises $15M to Build Customizable AI Marketing Agents',
  'output': 'Kana just emerged from stealth with $15 million in seed funding led by Mayfield to build flexible AI agents specifically for marketers. Think of it as having smart digital assistants that can handle data analysis, audience targeting, campaign management, and even optimize chatbots, all while plugging into your existing marketing tools like CRMs and data warehouses. The twist? These agents can generate synthetic data to fill gaps in market research and be customized on the fly without vendor lock-in. Founded by ad-tech veterans who previously sold companies to Microsoft and Salesforce, Kana could reshape how brands automate marketing by offering modular agents instead of clunky, all-in-one platforms that trap you in their ecosystem.',
  'image_url': None},
 {'id': 164,
  'headline': 'DeepMind Legend Chasing $1B Seed for Superhuman AI',
  'output': "David Silver, the brain behind AlphaGo at Google DeepMind, is reportedly raising Europe's largest seed round ever: $1 billion at a $4 billion valuation for his London startup Ineffable Intelligence. Sequoia's leading, with Nvidia, Google, and Microsoft eyeing deals. Unlike typical chatbots that predict text, Silver's betting on reinforcement learning (think AI that learns by trial and error, like mastering chess) to crack superhuman intelligence. Founded just months ago in November 2025, terms aren't final yet. If it closes, this mega-round signals investors believe the next AI breakthrough won't come from scaling up language models, but from teaching machines to think and strategize beyond human limits.",
  'image_url': None},
 {'id': 165,
  'headline': "India's $2B AI Bet: Nvidia Powers Sovereign Payments Brain",
  'output': "NPCI and Nvidia are building India's first payments-native sovereign AI foundation model, using Nvidia's Nemotron models and NPCI's existing FiMI and UPI Help Assistant as the base. Meanwhile, Yotta is deploying Asia-Pacific's largest DGX Cloud cluster with 20,736 Nvidia Blackwell Ultra GPUs, backed by over $2 billion investment, going live August 2026. The system will handle multilingual payments queries with low latency while keeping data within India's borders, meeting regulatory requirements. Together, these moves position India to control its AI infrastructure for 500 million UPI users, reducing reliance on foreign tech giants and potentially reshaping how developing nations approach digital sovereignty in financial services.",
  'image_url': None},
 {'id': 166,
  'headline': 'World Labs Raises $1B, Autodesk Drops $200M',
  'output': "World Labs just closed a massive $1 billion funding round, with design software giant Autodesk leading the charge at $200 million. Other backers include Nvidia, AMD, and Fidelity. The partnership will integrate World Labs' AI-powered world models into Autodesk's 3D workflows, starting with entertainment. World Labs' product Marble already lets users generate downloadable 3D environments from text, images, or video prompts, complete with editing tools for gaming and interactive media. The deal positions World Labs to compete against Google DeepMind and Runway in the spatial intelligence race. If successful, this could revolutionize how designers, game developers, and filmmakers create immersive 3D worlds at scale.",
  'image_url': None},
 {'id': 167,
  'headline': 'This AI Reads Your Brainwaves to Type Your Thoughts',
  'output': 'Zyphra just dropped ZUNA, a 380-million-parameter AI model that cleans up brainwave signals to move us closer to typing with our thoughts. Trained on 2 million hours of EEG data, it takes messy brain readings from any headset (even cheap consumer ones) and reconstructs missing channels, denoises signals, and upsamples data without needing retraining. Think of it as autocorrect for your brain. Released open-source under Apache 2.0, ZUNA beats current industry standards and works across devices from basic headbands to 256-electrode research rigs. If perfected, noninvasive brain-computer interfaces could let paralyzed patients communicate or enable hands-free computing for everyone, no Neuralink surgery required.',
  'image_url': None},
 {'id': 168,
  'headline': 'Microsoft Drops $50 Billion AI Bet on Global South',
  'output': 'Microsoft just announced a massive $50 billion investment plan targeting the Global South (developing countries, mostly in the southern hemisphere) by 2030, revealed at the AI Impact Summit in New Delhi. The cash will fuel a five-part program covering infrastructure, skills training, multilingual AI, local innovations, and adoption tracking. India gets special attention with plans to train 20 million people in AI skills by 2030, including two million teachers. Microsoft already dropped $8 billion on datacenters last year and wants to connect 250 million people to the internet. This could seriously shrink the AI adoption gap, where only 14% of Global South workers use AI versus 25% up north, potentially reshaping who leads the next tech wave.',
  'image_url': None},
 {'id': 169,
  'headline': 'Construction Firm Merges Into $1.5B Defense AI Robotics Giant',
  'output': "JFB Construction Holdings is pivoting hard. The company announced an all-stock merger with XTEND on February 17, 2026, creating XTEND AI Robotics, a $1.5 billion defense tech player trading on Nasdaq as XTND by mid-2026. The new entity will specialize in AI-powered autonomous drones for defense and security, powered by XTEND's operating system that enables remote, multi-domain missions. XTEND shareholders will own 70%, JFB just 30%. High-profile backers include Eric Trump and several venture groups. JFB's stock tumbled as investors digested the dramatic industry shift. The deal positions XTEND AI Robotics as a major US player in autonomous defense tech, a booming sector as militaries worldwide embrace AI-driven systems.",
  'image_url': None},
 {'id': 170,
  'headline': 'Pentagon Threatens to Drop Anthropic Over AI Safety Limits',
  'output': 'The U.S. military reportedly used Anthropic\'s Claude AI during a Venezuela operation targeting Maduro, sparking a heated dispute over acceptable use cases. The Pentagon now wants all four major AI vendors (Anthropic, OpenAI, Google, xAI) to agree to "all lawful use cases" on classified networks. Anthropic is pushing back hard, demanding carve-outs that prohibit fully autonomous weapons and mass domestic surveillance. Despite launching Claude Gov in June 2025 with looser guardrails for intelligence work, the company refuses to sign the DoD\'s blanket authorization. By mid-February 2026, Pentagon officials began threatening to terminate or rework their $200 million contract. This standoff reveals a fundamental tension: can AI companies maintain safety principles while serving national security?',
  'image_url': None},
 {'id': 171,
  'headline': 'India Gets $2 Billion AI Supercomputer With Nvidia Chips',
  'output': "Yotta Data Services is building Asia's largest AI computing hub in India, powered by over 20,000 Nvidia Blackwell Ultra GPUs. The $2 billion project, launching August 2026, will operate from Greater Noida with scalability to 250 MW. Nvidia is anchoring a four-year, $1 billion DGX Cloud engagement at the facility. The supercluster features liquid cooling, lightning-fast 800 Gbps networking, and 40 petabytes of storage to handle massive AI workloads. This positions India as a serious contender in the global AI infrastructure race, offering homegrown sovereign AI capabilities while attracting international tech giants to deploy cutting-edge compute resources locally.",
  'image_url': None},
 {'id': 172,
  'headline': 'Cogent Raises $42M to Let AI Agents Fix Security Flaws',
  'output': "Cogent Security just landed $42 million in Series A funding led by Bain Capital Ventures, with Greylock and Definition joining in. Their pitch? AI agents that autonomously handle vulnerability management from start to finish, investigating threats, assigning tasks, assessing risk, and tracking fixes until completion. Think of it as a security team that never sleeps. Early customers are seeing a 97% reduction in how long critical risks stay exposed, and dozens of Fortune 1000 companies are already on board. The funding pushes Cogent beyond vulnerability management into broader security operations, potentially automating one of cybersecurity's messiest bottlenecks at enterprise scale.",
  'image_url': None},
 {'id': 173,
  'headline': "Circuit Raises $30M in Texas's Largest Angel Round",
  'output': "Austin-based Circuit just closed a $30 million angel round from heavy hitters like Jim Breyer and former Silicon Labs CEO Tyson Tuttle, who now leads the startup. Circuit's AI platform transforms boring technical manuals, CAD files, and exploded diagrams into step-by-step workflows for factory floors and service teams. It connects with existing enterprise software to guide workers through complex tasks, slashing errors and speeding up training. Early users like Culligan report faster quotes and smoother onboarding. With nearly 2 million U.S. manufacturing jobs at risk of going unfilled by 2033, Circuit's timing couldn't be sharper. The cash fuels product upgrades and a hiring spree.",
  'image_url': None},
 {'id': 174,
  'headline': 'OpenAI Drops Lightning-Fast Coding AI Powered By Cerebras',
  'output': "OpenAI just launched GPT-5.3-Codex-Spark, a blazingly fast coding model that churns out 1000+ tokens per second thanks to Cerebras' massive wafer-scale chip hardware. This stripped-down variant of Codex is built for real-time coding, slashing roundtrip delays by 80% and speeding up first responses by 50%. ChatGPT Pro users get preview access today via the Codex app, CLI, and VS Code extension, while API access remains limited to select partners. The move signals OpenAI's pivot away from Nvidia-only infrastructure. If Spark delivers on its speed promise, expect coding assistants to feel less like autocomplete and more like a pair-programming partner who actually keeps up.",
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': 'A sleek, glowing AI brain made of interlocking circuit pathways floats in the center against a deep gradient background of electric blue and purple. A single human hand reaches up from below, palm open, as if catching or receiving this luminous digital consciousness. The brain emits soft rays of light. Minimal, bold editorial illustration style with dramatic lighting and generous negative space around the central interaction.',
#   'id': 160},
#  {'final_output': '# Image Prompt\n\nA sleek, modern robot hand and human hand reaching toward each other against a bold two-tone background split between electric blue and coral orange, almost touching at their fingertips in the center of the frame. The robot hand is metallic silver with clean geometric joints, while the human hand is rendered in a simplified, graphic style. Dramatic side lighting creates strong shadows. Vast negative space',
#   'id': 161},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 160,
#   'headline': 'Meta and NVIDIA Partner to Build Personal Superintelligence',
#   'output': 'Meta and NVIDIA just announced a massive multiyear partnership to deploy millions of next-gen Blackwell and Rubin GPUs across Meta\'s AI infrastructure. The goal? Delivering what Zuckerberg calls "personal superintelligence" to users. Meta will build hyperscale data centers optimized for training and inference, integrating NVIDIA\'s Spectrum-X Ethernet and Arm-based Grace CPUs. The collaboration extends NVIDIA\'s privacy-preserving tech to WhatsApp and beyond. Engineering teams will co-design systems to optimize Meta\'s AI models. This alliance could reshape how billions access AI-powered assistance, potentially bringing ChatGPT-level capabilities directly into Facebook, Instagram, and WhatsApp by 2027.',
#   'image_url': None},
#  {'id': 161,
#   'headline': '91% of Customer Service Leaders Pressured to Deploy AI',
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': 'A sleek, glowing AI brain made of interlocking circuit pathways floats in the center against a deep gradient background of electric blue and purple. A single human hand reaches up from below, palm open, as if catching or receiving this luminous digital consciousness. The brain emits soft rays of light. Minimal, bold editorial illustration style with dramatic lighting and generous negative space around the central interaction.',
  'id': 160},
 {'final_output': '# Image Prompt\n\nA sleek, modern robot hand and human hand reaching toward each other against a bold two-tone background split between electric blue and coral orange, almost touching at their fingertips in the center of the frame. The robot hand is metallic silver with clean geometric joints, while the human hand is rendered in a simplified, graphic style. Dramatic side lighting creates strong shadows. Vast negative space',
  'id': 161},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single, oversized glowing brain made of flowing golden circuit pathways, emerging from or connected to a sleek open laptop at the bottom of the frame. The brain should appear luminous and powerful, with subtle data streams or light particles flowing into it from the sides. Deep navy blue or dark purple background with ample negative space above and around the brain.',
  'id': 162},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single sleek robotic hand or arm emerging from the bottom, holding up a glowing megaphone that radiates bold, vibrant energy waves. The composition features the robotic element in deep metallic blue or silver against a clean gradient background of coral pink fading to warm orange. The megaphone emits geometric light rays or sound waves in electric',
  'id': 163},
 {'final_output': '# Image Prompt\n\nA single gleaming white chess king piece stands prominently on a gradient surface that transitions from deep electric blue to vibrant magenta. The king piece appears to be radiating or glowing with a subtle golden aura, suggesting superhuman power or intelligence. The composition is stark and minimal, with the chess piece positioned in the lower third of the frame, leaving abundant negative space above in a clean',
  'id': 164},
 {'final_output': "# Image Prompt\n\nA sleek, futuristic microchip or neural processor floating against a vibrant gradient background of saffron orange to deep indigo blue (reflecting Indian national colors). The chip glows with electric blue circuit pathways forming the recognizable shape of the Indian subcontinent. A single digital rupee symbol (₹) emerges holographically from the chip's center, rendered",
  'id': 165},
 {'final_output': 'A giant glowing 3D wireframe sphere floating in vast empty space, with a single golden key inserting into its surface, rendered in bold editorial illustration style with electric blue and gold gradient colors against a deep navy background',
  'id': 166},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single human head silhouette in profile, colored in deep navy blue, with a glowing wave pattern emerging from the forehead area that transforms into elegant floating letters or typography dissolving into space. The wave starts as an organic, undulating brain signal visualization in electric cyan/turquoise, then seamlessly transitions into crisp, legible letterforms (',
  'id': 167},
 {'final_output': '# Image Prompt\n\nA giant, glowing blue AI chip or circuit board planted like a seed in rich, terracotta-colored earth, with small green shoots or digital nodes sprouting upward from its surface. The chip should have a subtle Microsoft-style aesthetic with clean geometric patterns. The composition is centered with the chip taking up the middle third of the frame, surrounded by warm, earthy negative space that',
  'id': 168},
 {'final_output': '# Image Prompt\n\nA sleek, autonomous military drone hovers in the center against a bold two-tone background split between construction orange and deep navy blue. The drone is modern and geometric, rendered in metallic gray with subtle blue AI circuit patterns glowing on its surface. Minimalist editorial illustration style with clean lines and dramatic lighting. The drone casts a sharp shadow below, emphasizing its presence in negative',
  'id': 169},
 {'final_output': '# Image Prompt\n\nA single chess piece—a white knight—standing on a battlefield caught in a tug-of-war between two massive hands pulling from opposite sides. One hand in military camouflage pattern from the left, another hand in clean corporate blue from the right. The knight piece is rendered in bright red, positioned dead center. Dramatic tension lines radiate from the piece. Deep navy blue',
  'id': 170},
 {'final_output': '# Image Prompt\n\nA sleek, oversized microchip floating majestically above the outline of the Indian subcontinent, rendered in bold editorial illustration style. The chip glows with electric blue and neon green circuits, while the map of India beneath is depicted in warm saffron and deep orange tones. Dramatic lighting creates a sense of technological power and national significance. Clean composition with the chip',
  'id': 171},
 {'final_output': '# Image Prompt\n\nA sleek, modern illustration of a single robotic hand gently sealing or mending a glowing crack in a large digital shield. The shield is a bold, solid geometric shape in deep navy blue, with the crack emitting a soft cyan glow. The robotic hand is white and minimalist in design, shown mid-action from the side. The background is a clean gradient',
  'id': 172},
 {'final_output': '# Image Prompt\n\nA single glowing robotic hand holding a vintage paper technical manual or blueprint, suspended in clean space. The hand is rendered in bold, vibrant orange and electric blue gradients with a sleek, modern finish. The manual shows simplified line drawings of mechanical parts. Warm golden light emanates from where the hand touches the paper, suggesting transformation. Deep navy blue background with generous negative space.',
  'id': 173},
 {'final_output': '# Image Prompt\n\nA single lightning bolt made of glowing neon code characters strikes down into a sleek, minimalist computer chip or processor, set against a deep electric blue gradient background with generous negative space. The lightning bolt should be rendered in bright cyan and white, with visible code syntax (brackets, semicolons, function names) forming its jagged shape. The chip below is depicted as a simple,',
  'id': 174}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        public_urls_5.append({
            'public_url': public_url,
            'id': i['id']
        })

        print(f"✅ {i['final_output']} → {public_url}")

# %%
image_result(prompt)
# Out:
# ✅ A sleek, glowing AI brain made of interlocking circuit pathways floats in the center against a deep gradient background of electric blue and purple. A single human hand reaches up from below, palm open, as if catching or receiving this luminous digital consciousness. The brain emits soft rays of light. Minimal, bold editorial illustration style with dramatic lighting and generous negative space around the central interaction. → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/160.png
# ✅ # Image Prompt
#
# ...

# %%
a = []
for i in public_urls_5:
    if i['id']>=160:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
#   'id': 146},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
#   'id': 147},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
#   'id': 148},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
#   'id': 149},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
#   'id': 150},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
#   'id': 151},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
#   'id': 152},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
#   'id': 153},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(public_urls_6)

# %%
def upload_to_supabase(dictionary):
    for i in dictionary:
        supabase.table("hundred_word_articles").update(
                {"image_url": i['public_url']}
            ).eq("id", i['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
