# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 280,
  'headline': "Google's Image AI Now Searches the Web Before Drawing",
  'output': "Google just released Gemini 3.1 Flash Image (codenamed Nano Banana 2), and the standout feature isn't sharper pixels. It can search the web before generating an image, grounding visuals in real locations, events, or objects. Need a poster with accurate Tokyo street signs or a product shot mimicking a viral aesthetic? The model pulls reference imagery first, then renders. It also handles extreme aspect ratios (8:1 banners, anyone?) and finally fixes AI's nemesis: readable text in multiple languages. The catch? Outputs still vary, and you'll need a paid API key to try it in Google AI Studio.",
  'image_url': None},
 {'id': 281,
  'headline': 'Pentagon Gives Anthropic Friday Deadline or Loses $200M Contract',
  'output': 'Multiple outlets report that Defense Secretary Pete Hegseth gave Anthropic CEO Dario Amodei until Friday to loosen Claude\'s usage restrictions for Pentagon operations, threatening to label the company a "supply chain risk" and invoke the Defense Production Act. The ultimatum is striking because Claude is the only AI model cleared to run inside the Pentagon\'s classified networks. Anthropic opposes removing safeguards that would enable mass surveillance or autonomous weapons; the DoD insists it needs flexibility for lawful operations. Claude reportedly helped capture Nicolás Maduro in January, though details remain undisclosed. The standoff reveals how quickly AI safety principles collide with national security impatience.',
  'image_url': None},
 {'id': 282,
  'headline': 'Meta Bets 10% of AMD on Ditching Nvidia',
  'output': 'Meta just handed AMD the biggest customer commitment in chip history: up to 6 gigawatts of AI processors starting late 2026, plus warrants for 160 million AMD shares (roughly 10% of the company). The warrants vest only if AMD hits delivery and stock-price milestones, turning Meta into a quasi-investor. External reports peg the deal\'s potential value near $100 billion, though neither company disclosed a total price. The arrangement doubles as insurance against Nvidia\'s dominance and a signal that hyperscalers would rather help build a rival than stay locked into a single supplier. If AMD delivers, Meta gets cheaper chips and a seat at the table. If not, the warrants expire worthless and Zuckerberg\'s "personal superintelligence" vision stalls.',
  'image_url': None},
 {'id': 283,
  'headline': 'Korean Telecom KT Built 32B Model for Four Languages',
  'output': 'KT announced it will unveil Mi:dm K 2.5 Pro at Mobile World Congress next week, a 32-billion-parameter model trained on Korean, English, Japanese, and Chinese. The pitch: businesses can analyze hundreds of pages across those four languages in one go, thanks to a 128,000-token context window (enough for a short novel). KT claims it scored 87% on an agent benchmark, meaning the model can call tools and complete tasks, not just answer questions. The telecom giant is betting regional companies want AI that speaks their languages natively, rather than relying on models trained mostly on English and clumsily adapted afterward.',
  'image_url': None},
 {'id': 284,
  'headline': 'UK Commits £50M to Test AI Inside Live Data Centers',
  'output': "The UK government's research agency ARIA is putting £16 million into a new Scaling Inference Lab, part of a £50 million push to test AI inference inside working data centers. The lab, run by CommonAI, will experiment with making AI responses cheaper and faster using real-world conditions instead of isolated test beds. It's tied to Britain's national compute strategy, which treats shared AI computing power as critical infrastructure. The bet: countries that figure out how to run AI models efficiently at massive scale won't just save money, they'll set the technical standards everyone else follows.",
  'image_url': None},
 {'id': 285,
  'headline': 'Notion Now Has More AI Agents Than Employees',
  'output': 'Notion just launched Custom Agents, letting Business and Enterprise customers build AI bots that work around the clock across Slack, email, calendars, and a dozen other tools. The surprise? Notion itself already runs more agents than it has people on payroll. Early testers have built over 21,000 agents since beta started. Payments startup Ramp deployed more than 300. The bots handle Q&A, route tasks, and post status updates automatically. It\'s free for two months, then costs $10 per 1,000 credits. One early customer, Remote, saved 20 hours a week. The shift from "helpful assistant" to "outnumbering the workforce" happened faster than anyone expected.',
  'image_url': None},
 {'id': 286,
  'headline': 'Half of Workers Pay for AI Themselves',
  'output': "A year-long survey of 193,000 Americans reveals that 42% of work AI users brought the tools in themselves, with no formal company program. Even more striking: half of paid work subscriptions are still funded by employees, not employers. That's starting to shift (employer-paid plans rose from 40% to 50% in six months), but millions of workers decided AI was worth their own money before their bosses did. The payoff? Users report saving 6.3 hours weekly. Companies are now racing to catch up to their own employees.",
  'image_url': None},
 {'id': 287,
  'headline': '30% of Top US Accounting Firms Now Use AI Agents',
  'output': "Basis just raised $100 million at a $1.15 billion valuation, led by Accel with backing from Google Ventures and former Goldman CEO Lloyd Blankfein. The startup's AI agents handle end-to-end accounting tasks, including filing complex partnership tax returns. Already, 30% of America's 25 largest accounting firms have adopted the platform. That's not a pilot program statistic. It's a signal that AI is moving from assistant to accountant faster than anyone expected. The money will expand engineering and machine learning teams to meet demand that's clearly already here, not hypothetical.",
  'image_url': None},
 {'id': 288,
  'headline': 'AT&T Cuts AI Costs 90% as Token Use Triples',
  'output': "AT&T's internal AI assistant went from 8 billion to 27 billion tokens per day in just months, and instead of watching costs explode, the company slashed them by 90%. The trick? Rebuilding its system so a coordinator AI assigns tasks to smaller, cheaper models instead of running everything through one expensive model. Over 100,000 employees now use the drag-and-drop tool daily, with some reporting 90% productivity gains. The irony: handling three times the volume for a tenth of the cost required rethinking the plumbing, not buying better AI.",
  'image_url': None},
 {'id': 289,
  'headline': 'UK Self-Driving Startup Wayve Raises $1.2B From Uber, Nvidia',
  'output': 'Wayve closed a $1.2 billion Series D led by Eclipse, Balderton, and SoftBank, with Uber, Nvidia, Microsoft, and three automakers (Mercedes, Nissan, Stellantis) joining. The UK startup hit an $8.6 billion valuation selling what carmakers actually want: plug-and-play self-driving software they can install without redesigning vehicles. Uber added a $300 million kicker if Wayve hits deployment targets for London robotaxi trials starting this year. The money signals a bet that autonomy will be won by flexible AI platforms, not companies building their own cars from scratch.',
  'image_url': None},
 {'id': 290,
  'headline': 'Figma and OpenAI Link Design Files Directly to Code',
  'output': 'Figma and OpenAI just launched a beta integration that finally closes the loop between designers and developers. Copy a Figma frame URL into Codex, and it generates working code from your design. The reverse works too: point Codex at a live UI, and it spits out editable Figma files in seconds. Teams can now iterate on both the design canvas and the codebase without losing context or restarting from scratch. Codex already has over 1 million weekly users. The surprise? You no longer need to pick whether to start in code or design.',
  'image_url': None},
 {'id': 291,
  'headline': "MatX Raises $500M to Take on Nvidia's AI Chip Monopoly",
  'output': "MatX just closed a $500 million Series B to build chips it claims will outperform Nvidia's GPUs for training large language models. Jane Street and a fund called Situational Awareness LP led the round, joined by Marvell Technology and Stripe's co-founders. The startup plans to tape out its MatX One chip within a year and ship in 2027 via TSMC. Here's the signal: serious money is betting that Nvidia's grip on AI hardware isn't unbreakable. The question is whether MatX can actually deliver before the next generation of H-series GPUs arrives.",
  'image_url': None},
 {'id': 292,
  'headline': 'Salesforce Now Shows Exactly Which Orders Your AI Chatbot Closed',
  'output': "Salesforce's February commerce update finally answers the question every retailer asks about AI shopping assistants: are they actually selling anything? The new Shopper Agent attribution feature tracks orders and revenue directly tied to the B2C Shopping Agent, visible in Commerce Intelligence dashboards. It's the first time merchants can measure ROI instead of guessing whether their chatbot is helpful or just annoying. The update also cuts busy work for merchandisers with saved catalog filters and lets developers publish single-page updates instead of exporting entire site libraries. The subtext? Salesforce knows AI tools won't stick unless companies can prove they're worth the investment.",
  'image_url': None},
 {'id': 293,
  'headline': 'Adobe Opens Firefly to Runway, OpenAI, and Gemini Models',
  'output': "Adobe is letting Firefly subscribers generate images and video using partner models from OpenAI, Google, Runway, and others, ending its walled-garden approach. Through March 16, Pro and Premium plans get unlimited generations across all models. That means designers can test a concept in Firefly, Gemini, and FLUX without counting credits or switching apps. The catch: Adobe hasn't said what happens after the promo ends or how much each partner model will cost per generation. For now, creative teams can burn through dozens of variations in a morning instead of rationing monthly credits. The real test is whether Adobe keeps unlimited generation or reverts to metered billing once the trial window closes.",
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single large magnifying glass hovering over a glowing, simplified web browser window. The magnifying glass reveals a vibrant, stylized image materializing from colorful pixel particles where it focuses. The browser window is depicted as a clean, flat geometric shape in soft blue, while the magnifying glass handle is bold yellow. The forming image within the lens shows',
#   'id': 280},
#  {'final_output': '# Image Prompt\n\nA single sleek robotic hand reaching toward or grasping a glowing red "STOP" button against a dark navy blue background. The hand is rendered in clean, geometric metallic silver forms with minimal detail. The stop button floats in space, emitting a soft crimson glow. Dramatic side lighting creates sharp contrast. Editorial illustration style with bold, limited color palette of',
#   'id': 281},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 280,
#   'headline': "Google's Image AI Now Searches the Web Before Drawing",
#   'output': "Google just released Gemini 3.1 Flash Image (codenamed Nano Banana 2), and the standout feature isn't sharper pixels. It can search the web before generating an image, grounding visuals in real locations, events, or objects. Need a poster with accurate Tokyo street signs or a product shot mimicking a viral aesthetic? The model pulls reference imagery first, then renders. It also handles extreme aspect ratios (8:1 banners, anyone?) and finally fixes AI's nemesis: readable text in multiple languages. The catch? Outputs still vary, and you'll need a paid API key to try it in Google AI Studio.",
#   'image_url': None},
#  {'id': 281,
#   'headline': 'Pentagon Gives Anthropic Friday Deadline or Loses $200M Contract',
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single large magnifying glass hovering over a glowing, simplified web browser window. The magnifying glass reveals a vibrant, stylized image materializing from colorful pixel particles where it focuses. The browser window is depicted as a clean, flat geometric shape in soft blue, while the magnifying glass handle is bold yellow. The forming image within the lens shows',
  'id': 280},
 {'final_output': '# Image Prompt\n\nA single sleek robotic hand reaching toward or grasping a glowing red "STOP" button against a dark navy blue background. The hand is rendered in clean, geometric metallic silver forms with minimal detail. The stop button floats in space, emitting a soft crimson glow. Dramatic side lighting creates sharp contrast. Editorial illustration style with bold, limited color palette of',
  'id': 281},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A single, oversized red AMD computer chip floating in the center against a deep blue gradient background. The chip casts a bold, geometric shadow below it. Emerging from behind the chip is a subtle white Meta infinity logo symbol, partially obscured, suggesting backing or support. The composition uses strong negative space with the chip positioned',
  'id': 282},
 {'final_output': '# Image Prompt\n\nA single, oversized smartphone standing upright in portrait orientation, with four bold, overlapping speech bubbles floating above it in Korean, English, Japanese, and Chinese characters. Each speech bubble is a different vibrant color (electric blue, coral red, bright yellow, and emerald green) creating a dynamic cluster. The phone is rendered in simple, clean lines with a minimal interface glow',
  'id': 283},
 {'final_output': '# Image Prompt\n\nA single massive glowing AI chip or processor floating in the center of a vast, dark data center corridor. The chip radiates bright electric blue and cyan light, with subtle circuit-like patterns visible on its surface. Rows of minimalist black server racks recede into shadow on either side, creating dramatic perspective lines. The environment feels cavernous and industrial, with the illuminated chip',
  'id': 284},
 {'final_output': '# Image Prompt\n\nA single sleek humanoid robot figure sits confidently at a minimalist desk, with a tiny potted plant beside it, set against a bold two-tone background split between deep midnight blue and vibrant coral orange. The robot has a smooth, friendly design with a glowing chest panel showing the Notion logo. The composition is extremely minimal with vast negative space above and around the figure,',
  'id': 285},
 {'final_output': '# Image Prompt\n\nA single minimalist briefcase split open at the center, with one half containing traditional office items (paper, pen) in corporate navy blue, while the other half glows with a vibrant electric purple/magenta light representing AI, with simple geometric circuitry patterns emerging from it. The briefcase sits centered against a clean cream or light gray background with dramatic shadows. The composition emphasizes',
  'id': 286},
 {'final_output': '# Image Prompt\n\nA sleek, modern calculator floating in space, with its digital display glowing bright cyan against a deep navy blue background. One robotic arm emerges from the side of the calculator, pressing a button with a metallic finger. The composition is minimal and centered, with dramatic lighting that creates a soft glow around the calculator. The color palette is bold: midnight blue, electric cyan, and',
  'id': 287},
 {'final_output': '# Image Prompt\n\nA sleek, oversized robotic arm or mechanical crane effortlessly lifting a single, tiny glowing AI chip or processor, set against a bold two-tone background (deep blue and electric coral). The composition emphasizes scale contrast—the massive efficient machinery versus the minimal resource. Minimalist editorial illustration style with clean geometric shapes, dramatic side lighting, and abundant negative space surrounding the central',
  'id': 288},
 {'final_output': '# Image Prompt\n\nA sleek autonomous car dashboard interior where a glowing AI neural network orb hovers above the steering wheel, casting blue and purple light rays across a minimalist black dashboard. The steering wheel appears untouched, slightly faded or transparent to suggest hands-free driving. Clean, dramatic lighting with deep shadows and plenty of negative space around the central glowing AI brain. Editorial illustration style with',
  'id': 289},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration showing a single design artboard frame seamlessly transforming into flowing lines of code, depicted as a smooth gradient transition from left to right. The artboard (left side) features simple geometric shapes in bold cyan and purple, while the right side shows the same shapes dissolving into clean, stylized code brackets "<>" in vibrant orange and pink. The transformation happens in',
  'id': 290},
 {'final_output': '# Image Prompt\n\nA single sleek microchip rendered in bold metallic silver with glowing electric blue circuits, positioned at a dramatic angle against a vibrant gradient background of deep purple to coral orange. The chip casts a sharp geometric shadow, suggesting disruption and challenge. Minimal composition with the chip occupying the lower third of the frame, leaving generous negative space in the upper portion. Editorial illustration style',
  'id': 291},
 {'final_output': '# Image Prompt\n\nA sleek robotic hand emerging from the bottom of the frame, holding up a single glowing shopping bag that radiates soft light. The bag is simple and geometric, floating against a gradient background that transitions from deep purple to warm coral. The composition is minimal with the robotic hand occupying only the lower third of the frame, leaving vast negative space above. Modern editorial illustration style with bold',
  'id': 292},
 {'final_output': '# Image Prompt\n\nA single glowing digital doorway or portal frame in bright Adobe red, standing wide open in the center of a clean white space. Flowing through the open doorway are colorful, abstract AI-generated image fragments and light trails in blues, purples, and oranges, symbolizing the flow of multiple AI models now accessible through one entry point. The composition is minimal and centered, with',
  'id': 293}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 with open(file_name, "rb") as f:
#       3     image_bytes = f.read()
# ----> 5 supabase.storage.from_("article-image").upload(
#       6     "52.png",
#       7     image_bytes,
#       8     file_options={"content-type": "image/png"}
#       9 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/storage3/_sync/file_api.py:578, in SyncBucketActionsMixin.upload(self, path, file, file_options)
#     564 """
#     565 Uploads a file to an existing bucket.
#     566
#    (...)
#     575     HTTP headers.
#     576 """
#     577 path_parts = relative_path_to_parts(path)
# --> 578 return self._upload_or_update("POST", path_parts, file, file_options)
#
# ...

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
