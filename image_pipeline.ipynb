# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 105,
#   'headline': 'US Drops $20M to Push American AI Across Asia',
#   'output': "The United States just announced a $20 million fund to accelerate adoption of American AI technologies across Asia-Pacific economies, disclosed by senior official Casey Mace during APEC meetings in Guangzhou. The initiative promotes AI exports and maritime surveillance tech, including tools to combat illegal fishing. Part of the broader APEC AI Initiative for 2026–2030, the move strengthens US leadership in emerging tech ahead of President Trump's April China visit. This strategic play could reshape the Asia-Pacific AI landscape, positioning American tech as the go-to alternative in a region where influence—and algorithms—matter most.",
#   'image_url': None},
#  {'id': 106,
#   'headline': 'WINN.AI Scores $18M to Coach Sales Reps Live',
# ...

# %%
public_urls_5 = []

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = f"""
            You are an art director for a modern digital news platform targeting GenZ readers.

            Given a news story, generate an image prompt that:
            - Captures the THEME or EMOTION of the story, not a literal depiction
            - Uses symbolic/conceptual imagery (e.g. for a story about inflation, don't show a chart — show a shrinking shopping cart in a vast empty supermarket)
            - Follows this structure: [symbolic subject], [action/state], [setting], editorial illustration style, [mood-appropriate lighting], [2-3 color palette words]
            - Keeps it under 50 words
            - Never includes text, brand logos, or recognizable faces
            - The image should be in a s
            
            Story headline: {i['headline']}
            Story summary: {i['output']}
            """,
            size = "1024x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        public_urls_5.append({
            'public_url': public_url,
            'id': i['id']
        })

        print(f"✅ {i['headline']} → {public_url}")

# %%
a = [{'id': 105,
  'headline': 'US Drops $20M to Push American AI Across Asia',
  'output': "The United States just announced a $20 million fund to accelerate adoption of American AI technologies across Asia-Pacific economies, disclosed by senior official Casey Mace during APEC meetings in Guangzhou. The initiative promotes AI exports and maritime surveillance tech, including tools to combat illegal fishing. Part of the broader APEC AI Initiative for 2026–2030, the move strengthens US leadership in emerging tech ahead of President Trump's April China visit. This strategic play could reshape the Asia-Pacific AI landscape, positioning American tech as the go-to alternative in a region where influence—and algorithms—matter most.",
  'image_url': None},
 {'id': 106,
  'headline': 'WINN.AI Scores $18M to Coach Sales Reps Live',
  'output': "Tel Aviv-based WINN.AI just landed an $18 million Series A led by Insight Partners to expand its real-time sales coaching platform across the U.S. Founded in 2022, the startup delivers live guidance during customer calls, reinforcing playbooks and automating CRM busywork. The results? Wild. ARR tripled in 2025 and exploded 30x over two years, with zero enterprise churn. Deel saw a 33% win-rate jump, while Kaseya's 1,200 reps slashed admin time by 98%. As AI moves from post-call summaries to live execution, WINN.AI's timing could reshape how sales teams close deals in real-time.",
  'image_url': None},
 {'id': 107,
  'headline': 'Robo.ai Scores First Major Robot Training Data Deal',
  'output': "Robo.ai's subsidiary just landed its first commercial order, delivering 30,000 hours of robot training data to Silicon Valley's DaBoss.AI over 12 months. The deal follows their February UAE joint venture launch, marking the real kickoff of Robo.ai's Embodied AI Data Port strategy. The multi-modal dataset includes RGB-D vision, 6-DoF motion trajectories, and tactile feedback—designed to train Level 4+ Embodied AI models. With Robo.ai holding 51% equity, revenues will hit their 2026 financials under U.S. GAAP. This validates a data-centric model for training physical AI, potentially positioning the UAE as a critical node in global robot intelligence supply chains.",
  'image_url': None},
 {'id': 108,
  'headline': 'Simile Raises $100M to Predict Human Behavior with AI',
  'output': "Simile emerged from stealth with a $100 million Series A led by Index Ventures, backed by AI heavyweights Fei-Fei Li and Andrej Karpathy. The Stanford-affiliated startup builds AI agents that predict human behavior in any situation—from consumer purchases to corporate earnings calls. CVS Health is already testing the platform to optimize store layouts and inventory decisions. Beyond retail, Simile's tech simulates litigation outcomes, policy changes, and business scenarios. As behavioral prediction moves from theory to enterprise reality, companies gain a crystal ball for decision-making—raising questions about how deeply AI will reshape strategic planning across industries.",
  'image_url': None},
 {'id': 109,
  'headline': 'Microsoft Drops $17.4B on Nebius GPU Deal',
  'output': "Nebius just landed a massive multi-year agreement with Microsoft to supply dedicated GPU infrastructure from its new Vineland, New Jersey data center. The five-year contract, starting later in 2025, is worth $17.4 billion—potentially ballooning to $19.4 billion with extra capacity. GPU services will roll out in tranches through 2025-2026. Nebius plans to fund this through deal cash flow and contract-backed debt. The company's already flexing: 2025 revenue hit $529.8 million (up from $91.5 million in 2024), backed by a $700 million funding round from Accel and NVIDIA. This positions Nebius as a serious player in the AI infrastructure arms race.",
  'image_url': None},
 {'id': 110,
  'headline': 'Talkiatry Raises $210M to Scale AI-Powered Mental Health',
  'output': "Talkiatry just closed an oversubscribed $210 million Series D led by Perceptive Advisors, pushing its total funding past $400 million. The telepsychiatry giant employs 800+ full-time psychiatrists and has delivered over 3 million visits across 100+ insurers nationwide. The cash will fuel its AI-powered platform that handles care delivery and patient engagement—though the CEO admits clinical AI plans remain fuzzy. With 87% of anxiety patients improving after just two visits and dropout rates 60% below industry norms, Talkiatry's model is proving sticky. As mental health tech heats up, this war chest positions them to dominate the nationwide psychiatry shortage.",
  'image_url': None},
 {'id': 111,
  'headline': "China's Zhipu AI Drops GLM-5: 744B Parameters Challenge OpenAI",
  'output': "Zhipu AI just unleashed GLM-5, a massive open-source language model with 744 billion parameters trained on 28.5 trillion tokens. The flagship model doubles its predecessor's size and runs entirely on Huawei chips—no US hardware needed. Using DeepSeek's Mixture-of-Experts architecture, GLM-5 claims industry-leading coding chops, allegedly outperforming Google's Gemini 3 Pro and nearing Anthropic's Claude Opus 4.5. Markets loved it: Zhipu's Hong Kong stock surged 28.7% to HK$402. As China floods the zone with homegrown models post-IPO, GLM-5 signals Beijing's serious play for AI independence and global competitiveness.",
  'image_url': None},
 {'id': 112,
  'headline': "Gradient's Echo-2 Slashes AI Training Costs by 80%",
  'output': "Gradient launched Echo-2 in February 2026, a distributed reinforcement learning framework promising up to 80% lower post-training costs versus traditional cloud setups. Using a dual-swarm architecture that splits training and inference across distributed hardware, Echo-2 crushed benchmarks—reducing a 30B model's training time from 124 hours to 9.5 hours and costs from $4,490 to just $425. Early experiments show smaller models outperforming larger rivals. Gradient's upcoming RL-as-a-Service platform, Logits, opens reservations for researchers now, with enterprise access coming later in 2026. This could democratize cutting-edge AI development beyond Big Tech's data centers.",
  'image_url': None},
 {'id': 113,
  'headline': "Google's Gemini 3 Deep Think Crushes Math Olympiads",
  'output': "Google just dropped a major upgrade to Gemini 3's Deep Think mode, a specialized reasoning engine built for tackling hardcore science, research, and engineering problems. The results? Gold-medal-level performance on 2025's International Math, Physics, and Chemistry Olympiads, plus an 84.6% score on the ARC-AGI-2 benchmark and a whopping 3455 Elo on Codeforces. Deep Think can even transform sketches into 3D-printable files and model complex physical systems through code. Google AI Ultra subscribers get access now, while researchers and enterprises can request early API access. This positions Google aggressively against OpenAI's reasoning models in the high-stakes AI race.",
  'image_url': None},
 {'id': 114,
  'headline': 'OpenAI Ditches Nvidia for New Coding Model',
  'output': "OpenAI just launched GPT-5.3-Codex-Spark, its first production model running on Cerebras Systems chips instead of Nvidia hardware. This streamlined, lower-power variant specializes in fast, interruptible coding tasks like editing specific code sections and running targeted tests. Spark runs on Cerebras' third-generation Wafer Scale Engine, featuring hundreds of thousands of AI cores on a single wafer-scale processor optimized for low-latency workflows. Rolling out Thursday as a research preview to ChatGPT Pro subscribers, developers can swap existing OpenAI endpoints for Cerebras in just 15 seconds. This marks a strategic shift toward hardware diversification beyond Nvidia's dominance in AI compute.",
  'image_url': None},
 {'id': 115,
  'headline': 'OpenAI Drops GPT-5.3-Codex-Spark: 1000 Tokens Per Second',
  'output': "OpenAI just unleashed GPT-5.3-Codex-Spark, a lightning-fast coding model cranking out over 1000 tokens per second. Running on Cerebras' Wafer Scale Engine 3 hardware, it packs a 128k context window (text-only for now) and slashes latency by up to 80% via persistent WebSocket connections. Rolling out today to ChatGPT Pro users as a research preview, Codex-Spark crushes benchmarks—77.3% on Terminal-Bench 2.0 versus 64% for its predecessor—while completing real-world coding tasks significantly faster. OpenAI envisions dual modes: long-horizon reasoning and real-time collaboration, with multimodal support coming later. This positions Codex-Spark as the speed layer for live pair-programming, potentially redefining developer workflows industry-wide.",
  'image_url': None},
 {'id': 116,
  'headline': 'Uptiq Scores $25M to Put AI Agents in Banks',
  'output': "Uptiq just closed a $25 million Series B led by Curql to scale its AI agent platform for financial services. The company's Qore platform connects to banks' core systems, automating workflows like commercial underwriting, loan servicing, and client onboarding while keeping humans in the loop. Already live across 140+ financial institutions, Uptiq reports early adopters are seeing 41% faster underwriting, 29% lower operational costs, and up to 2x loan volume without hiring more staff. The fresh capital will fund a self-serve builder track, letting fintech startups and bank teams deploy financial AI in days instead of months—potentially democratizing enterprise-grade automation across the industry.",
  'image_url': None},
 {'id': 117,
  'headline': 'Cohere Crushes Revenue Target, Eyes IPO After $240M Year',
  'output': "Cohere blew past its 2025 revenue goal, delivering $240 million in annual recurring revenue against a $200 million target, with over 50% quarter-over-quarter growth throughout the year. An investor memo signals momentum toward an IPO. The company launched North, its enterprise AI workspace running on just two GPUs, designed for ultra-secure private deployments in air-gapped environments. Backed by Nvidia, AMD, and Salesforce Ventures, Cohere is landing regulated-sector wins like RBC's banking deployment. If enterprise AI demand holds, Cohere's efficiency-first approach could position it as a formidable public market contender against resource-heavy rivals.",
  'image_url': None},
 {'id': 118,
  'headline': 'Bracket Bags $7M to Kill Treasury Spreadsheets with AI',
  'output': 'Bracket just closed a $7 million seed round led by Macquarie Group and Blackfinch Ventures to scale its AI-powered treasury platform for mid-market businesses. The startup centralizes bank accounts across 11,000+ banks, automates FX workflows, and delivers real-time cash visibility across currencies—replacing clunky spreadsheet-driven processes. After reportedly hitting 600% revenue growth in 2025, Bracket will double headcount and expand into Europe and Australia. Its bank distribution model licenses the platform to financial institutions, positioning it to dominate treasury intelligence as mid-market finance teams ditch manual workflows for AI-driven automation.',
  'image_url': None},
 {'id': 119,
  'headline': 'Massachusetts Gives 40,000 State Workers ChatGPT Access',
  'output': "Massachusetts just became the first U.S. state to deploy ChatGPT enterprise-wide, rolling out OpenAI's AI assistant to nearly 40,000 executive branch employees. The three-year contract costs $13 per user monthly, dropping to $9 as adoption grows. The system runs in a secure, walled-off environment where state data won't train public models, with privacy oversight baked in. Usage is voluntary, with training provided as agencies onboard in phases starting with tech services. This first-in-the-nation move signals a major shift in how governments approach productivity, potentially setting a template for public-sector AI adoption nationwide.",
  'image_url': None},
 {'id': 120,
  'headline': 'OpenAI Killing GPT-4o as GPT-5.2 Takes Over',
  'output': "OpenAI is retiring GPT-4o and several legacy ChatGPT models effective February 13, 2026. The chopping block includes GPT-4.1, GPT-4.1 mini, OpenAI o4-mini, and even the recently announced GPT-5 (Instant and Thinking). Business, Enterprise, and Edu users get a grace period until April 3, 2026 for Custom GPTs. The good news? ChatGPT Voice and Images survive, and deprecated models stay accessible via API. All conversations default to GPT-5.2 post-retirement. This rapid model turnover signals OpenAI's aggressive push toward next-gen AI, potentially leaving competitors scrambling to keep pace.",
  'image_url': None},
 {'id': 121,
  'headline': "US Military Used Anthropic's Claude AI to Capture Maduro",
  'output': "The Wall Street Journal reports the U.S. military deployed Anthropic's Claude AI in a classified January 2026 operation that captured Venezuelan leader Nicolás Maduro, who now faces charges in New York. Claude was accessed through Anthropic's Palantir partnership and provided planning and analytical support, though its exact function remains undisclosed. Venezuela's defense ministry reports 83 deaths in Caracas during the raid. Neither the Pentagon, Anthropic, nor Palantir commented. Anthropic's usage policies explicitly prohibit violence and weapon development applications. This marks a watershed moment as the Pentagon expands AI integration into classified military operations, potentially redefining how tech companies navigate defense partnerships.",
  'image_url': None},
 {'id': 122,
  'headline': 'Anthropic Rumored Raising $30B at Eye-Watering $380B Valuation',
  'output': "Rumors are swirling that Anthropic is closing a massive $30B Series G funding round at a post-money valuation around $380B, though the company hasn't formally confirmed it. Singapore's GIC and Coatue are reportedly leading, joined by heavyweights like Founders Fund, ICONIQ Capital, and MGX. The AI startup is targeting $26B in 2026 revenue, up from a $9B run-rate in 2025. This would rank among tech's largest-ever private raises and fuel IPO speculation for 2026. If true, the valuation surge signals investor confidence that enterprise AI tools will dominate the next decade of corporate spending.",
  'image_url': None},
 {'id': 123,
  'headline': "Jensen Huang Bails on India's Massive AI Summit",
  'output': 'Nvidia CEO Jensen Huang won\'t attend India\'s AI Impact Summit 2026, scheduled February 16–20 in New Delhi. The chip giant cited "unforeseen circumstances" for the last-minute cancellation but is sending Executive VP Jay Puri to lead a high-level delegation instead. Prime Minister Narendra Modi will inaugurate the five-day event at Bharat Mandapam, featuring 700+ session proposals and executives from Google, DeepMind, and Anthropic. The summit positions India as a key player in global AI policy and infrastructure, with CEO roundtables on investments still moving forward despite Huang\'s notable absence.',
  'image_url': None},
 {'id': 124,
  'headline': 'ByteDance Drops Doubao 2.0 to Challenge GPT-5.2',
  'output': 'ByteDance released Doubao 2.0 on February 14, positioning its Pro variant against OpenAI\'s GPT-5.2 and Google\'s Gemini 3 Pro—at roughly 10x lower token costs. Built for the "agent era," the model handles complex reasoning and multi-step autonomous tasks, topping multimodal, math, and coding benchmarks. With 155 million weekly active users versus DeepSeek\'s 81.6 million, Doubao leads China\'s chatbot market. The Lunar New Year launch, alongside video-gen model Seedance 2.0, aims to fend off rivals like Alibaba\'s 3-billion-yuan promotion blitz. If ByteDance sustains this cost-performance edge, Western AI giants face serious price pressure—and China cements its infrastructure lead in the agent economy.',
  'image_url': None},
 {'id': 125,
  'headline': 'Saudi Arabia Ditches $100B Tourism Dreams for AI Superpower Play',
  'output': "Saudi Arabia is redirecting roughly $100 billion from stalled tourism megaprojects into Project Transcendence, a massive sovereign AI infrastructure initiative. Luxury resort expansions at Red Sea Global have been frozen, Neom's The Line scaled back, and the futuristic Mukaab suspended as the kingdom pivots hard toward AI compute and critical minerals. Crown Prince Mohammed bin Salman's Humain—backed by the Public Investment Fund—has locked in $23 billion in hardware deals with NVIDIA, AMD, Cisco, and Qualcomm, targeting 1.9 gigawatts of data center capacity by 2030. Google Cloud is co-building a $10 billion AI hub in Dammam. The shift signals Saudi Arabia's bet on silicon over sand as the new economic engine.",
  'image_url': None},
 {'id': 126,
  'headline': 'OpenAI Rolls Out Lockdown Mode for High-Risk Users',
  'output': "OpenAI just dropped Lockdown Mode and Elevated Risk labels in ChatGPT—an optional security upgrade for executives, security teams, and other high-risk users handling sensitive enterprise data. The feature uses a deterministic approach to prevent data leaks by restricting external system interactions. Web browsing gets limited to cached content, while image responses, Deep Research, Agent Mode, Canvas networking, and file downloads are completely disabled. Currently available for ChatGPT Enterprise, Education, Healthcare, and Teachers plans, it'll expand to consumer and team plans soon. This signals OpenAI's push into enterprise-grade security as AI tools handle increasingly sensitive corporate information.",
  'image_url': None},
 {'id': 127,
  'headline': 'Anduril Closes Monster $2.5B Round at $30.5B Valuation',
  'output': "Defense tech startup Anduril just closed a massive $2.5 billion funding round at a $30.5 billion valuation, cementing its status as a defense unicorn. Founders Fund led the charge with roughly $1 billion, while other investors piled into the rest. The raise, finalized in June 2025, marks a jump from the $28 billion valuation initially discussed back in February when term sheets were being signed. The capital will fuel scale-up manufacturing of autonomous systems through Anduril's Arsenal initiatives. This positions Anduril as a dominant player in AI-powered defense tech, signaling investor confidence in autonomous warfare systems as governments modernize military capabilities amid rising geopolitical tensions.",
  'image_url': None},
 {'id': 128,
  'headline': "OpenAI Bets Big on Sam Altman's Brain-Computer Startup",
  'output': "Sam Altman's brain-computer interface startup Merge Labs just emerged from stealth with an eye-popping $850 million valuation after raising $250 million in seed funding. OpenAI wrote the largest check and will collaborate on AI tools to accelerate R&D, though it won't run day-to-day ops. Unlike Neuralink's implanted electrodes, Merge Labs uses non-invasive ultrasound to read brain activity via molecules. Co-founded by Altman, Alex Blania, and neuroscientists, the research lab bridges biology and AI. With Neuralink valued at $9 billion, this marks an escalating race to decode the human brain and merge minds with machines.",
  'image_url': None},
 {'id': 129,
  'headline': 'India Drops AI Governance Playbook Ahead of Global Summit',
  'output': 'India\'s MeitY just released comprehensive AI Governance Guidelines under the IndiaAI Mission, setting the stage for safe, inclusive AI adoption before the India AI Impact Summit 2026 in February. The framework features seven core principles—dubbed "sutras"—adapted from RBI\'s FREE-AI framework, including Trust is Foundation, People First, and Innovation over Restraint. It maps actions across six pillars: Infrastructure, Capacity Building, Policy & Regulation, Risk Mitigation, Accountability, and Institutions. New bodies like an AI Governance Group and AI Safety Institute will coordinate standards and risk assessment. This techno-legal approach could position India as a Global South AI governance leader, balancing innovation with smart guardrails.',
  'image_url': None},
 {'id': 130,
  'headline': "India's AI Summit Unveils 70 Finalists, ₹5.85 Crore Prize",
  'output': 'India has announced 70 finalists across three Global AI Impact Challenges—AI for ALL, AI by HER, and YUVAi—set to showcase at the India AI Impact Summit in New Delhi, February 2026. From 4,650 applications spanning 60+ countries, the finalists include innovations like MalariaX, Zeko AI, and CropScan Smart Farming. The government-backed initiative offers a massive ₹5.85 crore prize pool, with AI for ALL and AI by HER each awarding ₹2.5 crore to top winners, while YUVAi distributes ₹85 lakh among youth innovators. This global showcase could position India as a serious AI innovation hub, accelerating cross-border collaboration and grassroots tech solutions.',
  'image_url': None},
 {'id': 131,
  'headline': 'Big Tech to Drop $650B on AI in 2026',
  'output': 'Alphabet, Amazon, Meta, and Microsoft are forecasting a combined $650 billion in capital expenditures for 2026—almost double their $381 billion spent in 2025. Amazon leads the pack at $200 billion, followed by Alphabet ($175-185B), Meta ($115-135B), and Microsoft ($97-105B). The cash is pouring into AI data centers, GPUs, servers, and power systems. Investors weren\'t thrilled—stocks dipped after the announcements. This marks the biggest single-year capex splash in a decade, but concerns are brewing about whether returns can justify this "mind-boggling tide" of spending.',
  'image_url': None}]

# %%
image_result(a)
# Out:
# ✅ US Drops $20M to Push American AI Across Asia → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/105.png
# ✅ WINN.AI Scores $18M to Coach Sales Reps Live → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/106.png
# ✅ Robo.ai Scores First Major Robot Training Data Deal → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/107.png
# ✅ Simile Raises $100M to Predict Human Behavior with AI → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/108.png
# ✅ Microsoft Drops $17.4B on Nebius GPU Deal → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/109.png
# ✅ Talkiatry Raises $210M to Scale AI-Powered Mental Health → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/110.png
# ...

# %%
public_urls_5
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/105.png',
#   'id': 105},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/106.png',
#   'id': 106},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/107.png',
#   'id': 107},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/108.png',
#   'id': 108},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/109.png',
#   'id': 109},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/110.png',
#   'id': 110},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/111.png',
#   'id': 111},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/112.png',
#   'id': 112},
# ...

# %%
upload_to_supabase(public_urls_5)

# %%
def upload_to_supabase(dictionary):
    for i in dictionary:
        supabase.table("hundred_word_articles").update(
                {"image_url": i['public_url']}
            ).eq("id", i['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
