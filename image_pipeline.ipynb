# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'final_output': '# Image Prompt\n\nA striking editorial illustration in wide 16:9 format: A single oversized golden key transforming into a sleek modern microchip at its bow end, suspended against a bold gradient background transitioning from deep emerald green to electric violet. The key floats in the center with dramatic lighting, symbolizing the shift from supplier access to ownership stake. Minimal composition with vast negative space',
  'id': 191},
 {'final_output': '# Image Prompt\n\nA bold editorial illustration in wide 16:9 format: A single glowing AI neural node or circuit point rendered as a luminous sphere, positioned prominently against a deep vibrant background that transitions from tech blue to warm saffron orange. From this central sphere, two elegant flowing ribbons or light trails extend outward in opposite directions—one in electric blue, one in warm orange',
  'id': 192},
 {'final_output': '# Image Prompt\n\nA single oversized golden rupee symbol (₹) standing upright like a monument against a bold gradient background of saffron orange to deep teal blue. A sleek, minimalist white rocket or arrow pierces upward through the center of the rupee symbol, suggesting explosive growth and technological ambition. The composition is centered with abundant negative space around the edges, creating a powerful',
  'id': 193},
 {'final_output': '# Image Prompt\n\nA powerful, minimalist editorial illustration showing a single gleaming circuit board shaped like the map of India, rendered in vibrant electric blue and gold against a deep teal background. The circuit pathways glow with luminous energy, emanating soft light rays that suggest computational power and sovereignty. The composition is centered with ample negative space around it, shot from a slight overhead angle. Bold,',
  'id': 194},
 {'final_output': '# Image Prompt\n\nA bold editorial illustration in vibrant saffron orange and deep indigo blue showing a single, oversized lotus flower blooming open against a clean white background. Each petal of the lotus contains flowing Devanagari script that dissolves into glowing circuit patterns at the edges, symbolizing the fusion of Indian languages and AI technology. The lotus is positioned slightly off-center with generous',
  'id': 195},
 {'final_output': "# Image Prompt\n\nA minimalist editorial illustration of a glowing stethoscope transforming into a digital circuit pattern at one end, rendered in bold teal and electric blue against a clean cream background. The stethoscope's chest piece pulses with a soft luminous aura, while delicate circuit traces flow from the earpieces, suggesting the fusion of medicine and AI. Simple, elegant composition",
  'id': 196},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single lightbulb with its filament formed by interconnected circuit pathways, glowing in bright electric blue and orange gradients against a clean off-white background. The bulb casts a sharp geometric shadow suggesting data or network patterns. Wide 16:9 format, bold colors, significant negative space in the upper two-thirds of the composition',
  'id': 197},
 {'final_output': '# Image Prompt\n\nA sleek, glowing brain made of interconnected geometric nodes and pathways, floating in deep space with a subtle network of light trails extending from it. The brain is rendered in vibrant electric blue and cyan against a dark navy gradient background. Minimal composition with the brain positioned in the upper right third, leaving expansive negative space in rich dark tones. Editorial illustration style with clean vector',
  'id': 198},
 {'final_output': "# Image Prompt\n\nA single large shield in bold cobalt blue, centered against a clean white background, with the shield's surface composed of interlocking geometric circuit-board patterns in metallic copper and silver. A small, simple human hand silhouette in warm coral color rests protectively on the shield's face. Minimal editorial illustration style with strong contrast and plenty of negative space around the shield. Wide",
  'id': 199},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single smartphone floating in clean space, with a glowing sound wave or voice ripple emanating from its screen in bright neon blue or electric purple. The phone is rendered in a bold, simplified geometric style against a vibrant gradient background (deep purple to coral pink). The sound wave should be stylized and abstract—just 2-3 curved lines',
  'id': 200},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single laptop computer with a heavy padlock icon overlaying its screen, rendered in a bold two-tone color scheme of deep navy blue and bright safety orange. The laptop is centered and floating against a clean off-white background with generous negative space. The padlock is oversized and prominent, symbolizing security and restricted access. Modern, flat illustration style with cri',
  'id': 201},
 {'final_output': 'A sleek modern smartwatch floating in minimal space, with a subtle glowing AI brain icon hovering just above its screen, set against a bold gradient background of Meta blue merging into electric purple. The watch casts a soft shadow below, emphasizing depth and premium quality in this clean, editorial composition.',
  'id': 202},
 {'final_output': "# Image Prompt\n\nA single oversized smartphone floating vertically in the center against a vibrant gradient background (coral pink to electric purple). Musical notes and sound waves are flowing OUT of the phone's screen like liquid or smoke, transforming from text letters at the top into musical notation as they cascade downward. The composition is minimal and clean with the phone taking up roughly one-third of the frame, surrounded by",
  'id': 203},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration showing a single oversized magnifying glass examining a simplified insurance policy document, with a glowing AI neural network pattern visible within the magnifying lens. The document is clean and white with subtle text lines, while the magnifying glass reveals vibrant electric blue and cyan neural pathways analyzing the text. Set against a bold coral or warm orange background with generous negative space. The',
  'id': 204},
 {'final_output': '# Image Prompt\n\nA sleek, minimalist smart speaker floating in the center against a bold gradient background transitioning from deep blue to vibrant coral. The speaker has a single glowing camera lens eye on its front face, suggesting AI awareness. Clean, modern product photography style with dramatic studio lighting creating a soft shadow beneath the device. The composition is centered with ample negative space around the edges. Editorial illustration aesthetic',
  'id': 205}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA striking editorial illustration in wide 16:9 format: A single oversized golden key transforming into a sleek modern microchip at its bow end, suspended against a bold gradient background transitioning from deep emerald green to electric violet. The key floats in the center with dramatic lighting, symbolizing the shift from supplier access to ownership stake. Minimal composition with vast negative space',
#   'id': 191},
#  {'final_output': '# Image Prompt\n\nA bold editorial illustration in wide 16:9 format: A single glowing AI neural node or circuit point rendered as a luminous sphere, positioned prominently against a deep vibrant background that transitions from tech blue to warm saffron orange. From this central sphere, two elegant flowing ribbons or light trails extend outward in opposite directions—one in electric blue, one in warm orange',
#   'id': 192},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 191,
#   'headline': 'Nvidia Ditches $100B Chip Deal for $30B OpenAI Stake',
#   'output': "Nvidia is swapping its massive $100 billion multi-year chip supply agreement for a cleaner $30 billion direct equity investment in OpenAI. This shift makes Nvidia an actual owner, not just a supplier, in the AI giant currently valued at $830 billion. OpenAI's hunting for over $100 billion total this round, with SoftBank and Amazon joining the party. Plot twist: OpenAI plans to spend much of that fresh cash buying Nvidia chips anyway. This move signals Nvidia wants skin in the game beyond hardware sales, positioning itself as a stakeholder in AI's future rather than just the picks-and-shovels provider during the gold rush.",
#   'image_url': None},
#  {'id': 192,
#   'headline': "OpenAI and Tata Group Join Forces for India's AI Revolution",
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': '# Image Prompt\n\nA striking editorial illustration in wide 16:9 format: A single oversized golden key transforming into a sleek modern microchip at its bow end, suspended against a bold gradient background transitioning from deep emerald green to electric violet. The key floats in the center with dramatic lighting, symbolizing the shift from supplier access to ownership stake. Minimal composition with vast negative space',
  'id': 191},
 {'final_output': '# Image Prompt\n\nA bold editorial illustration in wide 16:9 format: A single glowing AI neural node or circuit point rendered as a luminous sphere, positioned prominently against a deep vibrant background that transitions from tech blue to warm saffron orange. From this central sphere, two elegant flowing ribbons or light trails extend outward in opposite directions—one in electric blue, one in warm orange',
  'id': 192},
 {'final_output': '# Image Prompt\n\nA single oversized golden rupee symbol (₹) standing upright like a monument against a bold gradient background of saffron orange to deep teal blue. A sleek, minimalist white rocket or arrow pierces upward through the center of the rupee symbol, suggesting explosive growth and technological ambition. The composition is centered with abundant negative space around the edges, creating a powerful',
  'id': 193},
 {'final_output': '# Image Prompt\n\nA powerful, minimalist editorial illustration showing a single gleaming circuit board shaped like the map of India, rendered in vibrant electric blue and gold against a deep teal background. The circuit pathways glow with luminous energy, emanating soft light rays that suggest computational power and sovereignty. The composition is centered with ample negative space around it, shot from a slight overhead angle. Bold,',
  'id': 194},
 {'final_output': '# Image Prompt\n\nA bold editorial illustration in vibrant saffron orange and deep indigo blue showing a single, oversized lotus flower blooming open against a clean white background. Each petal of the lotus contains flowing Devanagari script that dissolves into glowing circuit patterns at the edges, symbolizing the fusion of Indian languages and AI technology. The lotus is positioned slightly off-center with generous',
  'id': 195},
 {'final_output': "# Image Prompt\n\nA minimalist editorial illustration of a glowing stethoscope transforming into a digital circuit pattern at one end, rendered in bold teal and electric blue against a clean cream background. The stethoscope's chest piece pulses with a soft luminous aura, while delicate circuit traces flow from the earpieces, suggesting the fusion of medicine and AI. Simple, elegant composition",
  'id': 196},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single lightbulb with its filament formed by interconnected circuit pathways, glowing in bright electric blue and orange gradients against a clean off-white background. The bulb casts a sharp geometric shadow suggesting data or network patterns. Wide 16:9 format, bold colors, significant negative space in the upper two-thirds of the composition',
  'id': 197},
 {'final_output': '# Image Prompt\n\nA sleek, glowing brain made of interconnected geometric nodes and pathways, floating in deep space with a subtle network of light trails extending from it. The brain is rendered in vibrant electric blue and cyan against a dark navy gradient background. Minimal composition with the brain positioned in the upper right third, leaving expansive negative space in rich dark tones. Editorial illustration style with clean vector',
  'id': 198},
 {'final_output': "# Image Prompt\n\nA single large shield in bold cobalt blue, centered against a clean white background, with the shield's surface composed of interlocking geometric circuit-board patterns in metallic copper and silver. A small, simple human hand silhouette in warm coral color rests protectively on the shield's face. Minimal editorial illustration style with strong contrast and plenty of negative space around the shield. Wide",
  'id': 199},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single smartphone floating in clean space, with a glowing sound wave or voice ripple emanating from its screen in bright neon blue or electric purple. The phone is rendered in a bold, simplified geometric style against a vibrant gradient background (deep purple to coral pink). The sound wave should be stylized and abstract—just 2-3 curved lines',
  'id': 200},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single laptop computer with a heavy padlock icon overlaying its screen, rendered in a bold two-tone color scheme of deep navy blue and bright safety orange. The laptop is centered and floating against a clean off-white background with generous negative space. The padlock is oversized and prominent, symbolizing security and restricted access. Modern, flat illustration style with cri',
  'id': 201},
 {'final_output': 'A sleek modern smartwatch floating in minimal space, with a subtle glowing AI brain icon hovering just above its screen, set against a bold gradient background of Meta blue merging into electric purple. The watch casts a soft shadow below, emphasizing depth and premium quality in this clean, editorial composition.',
  'id': 202},
 {'final_output': "# Image Prompt\n\nA single oversized smartphone floating vertically in the center against a vibrant gradient background (coral pink to electric purple). Musical notes and sound waves are flowing OUT of the phone's screen like liquid or smoke, transforming from text letters at the top into musical notation as they cascade downward. The composition is minimal and clean with the phone taking up roughly one-third of the frame, surrounded by",
  'id': 203},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration showing a single oversized magnifying glass examining a simplified insurance policy document, with a glowing AI neural network pattern visible within the magnifying lens. The document is clean and white with subtle text lines, while the magnifying glass reveals vibrant electric blue and cyan neural pathways analyzing the text. Set against a bold coral or warm orange background with generous negative space. The',
  'id': 204},
 {'final_output': '# Image Prompt\n\nA sleek, minimalist smart speaker floating in the center against a bold gradient background transitioning from deep blue to vibrant coral. The speaker has a single glowing camera lens eye on its front face, suggesting AI awareness. Clean, modern product photography style with dramatic studio lighting creating a soft shadow beneath the device. The composition is centered with ample negative space around the edges. Editorial illustration aesthetic',
  'id': 205}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        public_urls_5.append({
            'public_url': public_url,
            'id': i['id']
        })

        print(f"✅ {i['final_output']} → {public_url}")
        upload_to_supabase(i)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# Storage endpoint URL should have a trailing slash.
# ✅ # Image Prompt
#
# A striking editorial illustration in wide 16:9 format: A single oversized golden key transforming into a sleek modern microchip at its bow end, suspended against a bold gradient background transitioning from deep emerald green to electric violet. The key floats in the center with dramatic lighting, symbolizing the shift from supplier access to ownership stake. Minimal composition with vast negative space → https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png
# ✅ Saved
# ✅ # Image Prompt
#
# ...

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    for i in dictionary:
        supabase.table("hundred_word_articles").update(
            {"image_url": i['public_url']}
        ).eq("id", i['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
