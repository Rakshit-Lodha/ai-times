# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 221,
  'headline': '88 Countries Sign Voluntary AI Declaration With Seven Pillars',
  'output': 'The New Delhi Declaration, signed by 88 countries including the US, China, and EU on February 21, 2026, establishes a voluntary, non-binding AI governance framework organized around seven pillars: human capital development, social empowerment, trust and security, energy efficiency, AI for science, democratization of AI resources, and economic growth. Key outputs include the Global AI Impact Commons for shared resources, the Charter for Democratic Diffusion of AI, and the AI Workforce Development Playbook. The framework emphasizes industry-led voluntary measures across healthcare, agriculture, education, climate, and public services. Organizations can now align internal governance with these pillars to access cross-border AI collaboration without legal obligations.',
  'image_url': None},
 {'id': 222,
  'headline': "Microsoft Adds xAI's Grok to Copilot Studio",
  'output': "Microsoft Copilot Studio now offers Grok 4.1 Fast in preview for US-based teams after admin opt-in. The model delivers a 2-million-token context window and cuts hallucinations by roughly 3x versus its predecessor, designed for complex workflows requiring deep tool integration. It comes in reasoning and non-reasoning modes, supports function calling across finance, healthcare, law, and science domains, but generates text only. Customer data stays unretained and isn't used for training. US organizations can pilot large-context agent workflows this week under xAI's governance terms, then expand regionally after readiness reviews.",
  'image_url': None},
 {'id': 223,
  'headline': "Google's AI Red Team Ran 350 Safety Tests",
  'output': "Google and DeepMind published their February 2026 AI responsibility report detailing governance for Gemini 3 and frontier models. The Content Adversarial Red Team completed over 350 safety exercises across text, audio, image, video, and agentic AI in 2025. AlphaGenome now analyzes up to one million DNA letters at once, while flood forecasting reaches two billion people across 150 countries with seven-day warnings. A Nigeria pilot evacuated 3,250 households and cut food insecurity by 90 percent. Key takeaway: teams should adopt Google's Frontier Safety Framework with Critical Capability Level gating before launching frontier models.",
  'image_url': None},
 {'id': 224,
  'headline': 'PoshBuilder AI Combines IDE, Visual Builder, and CMS',
  'output': 'PoshBuilder AI launched an invite-only beta merging a desktop IDE, AI visual website builder, and self-hosted CMS into one platform. The Monaco-based IDE offers real-time code generation, debugging, and multi-file awareness for React, Vue, Next.js, PHP, and Python. The visual builder generates complete sites from prompts and exports clean, portable code with no lock-in. The self-hosted CMS includes one-click installation, SEO automation with Schema.org markup, and white-label agency options. Beta seats include 100 developers, 50 agencies, and 20 enterprises. Teams can now prototype, code, and deploy websites without switching between Cursor, visual tools, and WordPress, consolidating workflows into a single AI-native environment.',
  'image_url': None},
 {'id': 225,
  'headline': 'Google Gemini 3.1 Pro Doubles Reasoning, Generates Animated SVGs',
  'output': 'Google launched Gemini 3.1 Pro today, more than doubling reasoning performance with an ARC-AGI-2 score of 77.1% versus its predecessor. The upgraded model now generates website-ready animated SVGs from text prompts and maintains a 1M token input context with 64K token output. Available starting today in preview across Gemini API, Google AI Studio, Vertex AI, Android Studio tools, NotebookLM, and the Gemini app. Developers can now build complex agentic workflows like live aerospace dashboards and interactive visuals, reducing manual coding steps and accelerating prototyping for enterprise automation and creative projects.',
  'image_url': None},
 {'id': 226,
  'headline': 'Google Launches Project Genie for AI-Generated Interactive Worlds',
  'output': "Google DeepMind released Project Genie, an experimental prototype now available to Google AI Ultra subscribers in the U.S. Powered by Genie 3, the tool lets users create and explore interactive worlds from text or image prompts with real-time path generation and dynamic simulation. Users can sketch worlds with adjustable first- or third-person camera views, remix existing environments, and export exploration videos. Known limitations include 60-second generation caps, occasional physics mismatches, and character control latency. The release signals Google's push toward practical world-model AI, expanding immersive creation tools beyond research teams into subscriber hands today.",
  'image_url': None},
 {'id': 227,
  'headline': 'OpenAI Eyes Historic $100B Round From Nvidia, Amazon',
  'output': "OpenAI is reportedly finalizing first commitments for an unprecedented $100 billion private funding round, targeting close by month-end February 2026. Early commitments include Nvidia (potentially $20-30B), Amazon (up to $50B), SoftBank, and Microsoft, valuing the company around $830-850 billion post-money. The capital will fund massive compute infrastructure buildouts and GPU procurement for initiatives like Stargate. Terms may hinge on OpenAI's planned for-profit restructuring, with a second tranche expected later in 2026. The round underscores a strategic land grab by cloud and chip giants to lock in OpenAI's future compute needs and AI ecosystem influence.",
  'image_url': None},
 {'id': 228,
  'headline': 'Single Code Strip Now Deploys Multi-AI Publishing Directly',
  'output': 'HAIL AI launched a multi-AI publishing architecture that installs via one line of code on public websites, eliminating complex backend rebuilds. The system offers two modes: Prismatic (search-aware with links) and Textology (pure text), both synthesizing outputs across multiple AI models for consistency and search alignment. It supports 19 languages, audio narration, and multimedia integration with structured, web-ready formatting instead of chat-style responses. Product and marketing teams can now deploy interactive AI content on live pages without maintaining custom model infrastructure, with immediate SEO benefits and controlled publishing workflows.',
  'image_url': None},
 {'id': 229,
  'headline': 'Samsung Adds Perplexity Agent to Galaxy AI Ecosystem',
  'output': 'Samsung is integrating Perplexity as a system-level AI agent on upcoming flagship Galaxy devices, accessible via "Hey Plex" voice command. The agent connects across Notes, Clock, Gallery, Reminder, and Calendar apps to handle multi-step workflows in a single request. For example, Perplexity can update notes with a plan, create calendar events, and set reminders without switching apps. This reduces manual app-hopping for users managing schedules and assets. Galaxy AI basic features remain free, though enhanced and third-party features may carry fees. Availability details and supported devices will be announced soon.',
  'image_url': None},
 {'id': 230,
  'headline': 'Adaption Labs Raises $50M Seed for Self-Learning AI',
  'output': 'Adaption Labs closed a $50 million seed round led by Emergence Capital to build adaptive AI models that learn continuously on the fly. The equity financing includes Mozilla Ventures, Fifty Years, Threshold Ventures, Alpha Intelligence Capital, E14 Fund, and Neo. Funds will hire AI researchers, engineers, and designers while advancing gradient-free adaptive systems designed to cut training and inference costs. The deal signals a strategic shift away from the expensive scale-at-all-costs approach dominating current AI development, targeting models that adapt in real time without massive retraining cycles.',
  'image_url': None},
 {'id': 231,
  'headline': 'Tripo AI Generates Production 3D Assets in 20 Seconds',
  'output': 'Tripo AI is expanding its enterprise 3D generator across US spatial computing markets with a model exceeding 200 billion parameters. The platform generates standard assets in approximately 20 seconds, outputs 4K textures, and exports to GLB, FBX, OBJ, and STL formats. Over 700 enterprise clients across gaming, industrial design, and e-commerce now use the tool, supported by 6.5 million creators and 40,000 developers. Tripo Studio offers mesh control, auto-rigging, and API integration for concurrent workflows. For teams, this means asset pipelines can shift from hours to seconds, with immediate testing possible via the Lite version to validate cycle-time reduction.',
  'image_url': None},
 {'id': 232,
  'headline': "Anthropic's Claude Now Hunts Software Vulnerabilities Autonomously",
  'output': 'Anthropic launched Claude Code Security, an AI vulnerability scanner now in limited research preview for Enterprise and Team customers. Unlike traditional tools, it reasons about code, traces data flows, uses multi-stage verification, and suggests patches rather than auto-applying them. Security teams can scan pull requests for flaws, and developers review AI-generated patch recommendations before pushing fixes. During internal testing, Opus 4.6 identified over 500 zero-day vulnerabilities in production open-source code. Security engineers benefit most from automated detection across large codebases, though findings still require human approval to avoid false positives.',
  'image_url': None},
 {'id': 233,
  'headline': 'infoCorvus ROAD Platform Unifies Data Governance and AI',
  'output': 'infoCorvus launched its ROAD platform, merging data ingestion, migration, retirement, governance, and AI enablement into one governed architecture. A global manufacturer validated ROAD at scale, managing over 200 billion rows with full lineage and policy enforcement, archiving 100 million rows monthly without custom code. The Governed AI Bridge ensures AI systems access only approved, policy-compliant data at execution time. For teams juggling siloed governance tools, ROAD consolidates workflows into a single control plane, reducing integration friction and supporting defensible AI operations that align with regulatory requirements starting now.',
  'image_url': None},
 {'id': 234,
  'headline': '93% of AI Search Queries Skip Websites Entirely',
  'output': "Clear Ads launched an AI Search Optimization service targeting e-commerce brands as 93% of AI Mode queries now bypass websites entirely, according to data cited from Exposure Ninja. The shift matters because 37% of consumers start product searches with AI instead of Google, and 64% use AI tools to discover or research products. Google's January 2026 Universal Commerce Protocol announcement signals a structural shift toward AI-powered discovery. For marketing teams, this means traditional SEO may no longer predict brand visibility in AI-generated answers. Clear Ads recommends starting with an audit of brand signals across AI platforms this quarter.",
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': "# Image Prompt\n\nA single elegant white dove composed of geometric circuit board patterns and flowing data streams, positioned in the center against a bold gradient background transitioning from deep diplomatic blue to warm sunrise orange. The dove's wing is extended in a gesture of unity, with subtle golden light emanating from its form. The composition features abundant negative space around the bird, creating a sense of openness and international cooperation. Editorial illustration",
#   'id': 221},
#  {'final_output': '# Image Prompt\n\nA sleek robotic hand passing a glowing orb to a human hand against a deep blue gradient background. The orb emanates soft white and electric blue light rays. The robotic hand features Microsoft\'s signature blue metallic finish, while a subtle "X" symbol is integrated into the orb\'s core. Minimalist editorial illustration style with bold colors, dramatic lighting, and abundant',
#   'id': 222},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 221,
#   'headline': '88 Countries Sign Voluntary AI Declaration With Seven Pillars',
#   'output': 'The New Delhi Declaration, signed by 88 countries including the US, China, and EU on February 21, 2026, establishes a voluntary, non-binding AI governance framework organized around seven pillars: human capital development, social empowerment, trust and security, energy efficiency, AI for science, democratization of AI resources, and economic growth. Key outputs include the Global AI Impact Commons for shared resources, the Charter for Democratic Diffusion of AI, and the AI Workforce Development Playbook. The framework emphasizes industry-led voluntary measures across healthcare, agriculture, education, climate, and public services. Organizations can now align internal governance with these pillars to access cross-border AI collaboration without legal obligations.',
#   'image_url': None},
#  {'id': 222,
#   'headline': "Microsoft Adds xAI's Grok to Copilot Studio",
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': "# Image Prompt\n\nA single elegant white dove composed of geometric circuit board patterns and flowing data streams, positioned in the center against a bold gradient background transitioning from deep diplomatic blue to warm sunrise orange. The dove's wing is extended in a gesture of unity, with subtle golden light emanating from its form. The composition features abundant negative space around the bird, creating a sense of openness and international cooperation. Editorial illustration",
  'id': 221},
 {'final_output': '# Image Prompt\n\nA sleek robotic hand passing a glowing orb to a human hand against a deep blue gradient background. The orb emanates soft white and electric blue light rays. The robotic hand features Microsoft\'s signature blue metallic finish, while a subtle "X" symbol is integrated into the orb\'s core. Minimalist editorial illustration style with bold colors, dramatic lighting, and abundant',
  'id': 222},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single large red shield with a magnifying glass overlaying it, set against a clean gradient background transitioning from deep blue to white. The shield is bold and geometric, rendered in a flat matte crimson red, symbolizing AI safety and protection. The magnifying glass is positioned slightly off-center, its lens revealing circuit-like patterns or neural network nodes',
  'id': 223},
 {'final_output': '# Image Prompt\n\nA sleek, minimalist editorial illustration in wide 16:9 format showing a single glowing geometric cube floating in center frame against a vibrant gradient background transitioning from deep purple to electric blue. The cube has three distinct faces visible, each subtly displaying a different texture: one face shows clean code lines, another shows a simple wireframe grid, and the third shows content blocks -',
  'id': 224},
 {'final_output': 'A single glowing brain made of flowing, animated vector paths and bezier curves, rendered in vibrant electric blue and magenta gradients against a clean white background, with the vector paths subtly forming into geometric shapes as they radiate outward, suggesting both intelligence and creative generation in one elegant form.',
  'id': 225},
 {'final_output': '# Image Prompt\n\nA giant glowing magic lamp floating in vast cyan-blue negative space, with a miniature interactive 3D landscape world emerging from its spout like ethereal smoke — tiny trees, hills, and pathways materializing in soft, luminous form. The lamp is rendered in bold coral-orange gradient with geometric facets. Clean, dreamlike editorial illustration style with strong contrast between the solid',
  'id': 226},
 {'final_output': "# Image Prompt\n\nA sleek, minimalist editorial illustration in wide 16:9 format: A single, oversized golden key floating in the center against a rich deep blue background. The key's bow (handle) is designed as a glowing neural network pattern in electric blue and cyan, while its blade extends downward with clean, geometric cuts. Subtle gradient lighting creates depth, with warm amber highlights",
  'id': 227},
 {'final_output': '# Image Prompt\n\nA single glowing code bracket symbol "<>" floating in the center against a rich gradient background transitioning from deep purple to vibrant cyan. From this bracket, multiple colorful light beams radiate outward in different directions like a prism effect, ending in soft glows. The composition is minimal and centered with ample negative space around the edges. Editorial illustration style with bold, saturated',
  'id': 228},
 {'final_output': '# Image Prompt\n\nA sleek Samsung Galaxy smartphone standing upright in portrait orientation, centered in the frame, with a glowing purple and blue AI orb or voice wave emanating from its screen. The phone is rendered in a modern, minimalist style against a clean gradient background transitioning from deep navy to electric blue. The AI orb has a luminous, ethereal quality suggesting intelligent connectivity and voice activation',
  'id': 229},
 {'final_output': '# Image Prompt\n\nA single glowing neural node or synapse transforming from rigid geometric form into fluid, organic shapes, symbolizing AI evolution from fixed to adaptive learning. The node radiates soft light pulses in electric blue and vibrant coral against a deep navy background. Minimalist composition with the transforming element positioned in the center-left, surrounded by generous negative space. Clean, modern editorial illustration style',
  'id': 230},
 {'final_output': '# Image Prompt\n\nA single pristine white 3D geometric object (a stylized low-poly sculpture or game asset) materializing from a bright cyan digital particle stream against a bold coral-orange background. The object is centered and partially formed, suggesting rapid generation, with glowing particle fragments still coalescing around its edges. Minimal composition with the object occupying only the middle third of the frame,',
  'id': 231},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single magnifying glass examining a glowing code bracket symbol "{ }" floating in space. The magnifying glass lens reveals a small bug or crack within the code bracket. Bold two-tone color palette: deep navy blue background with electric cyan/turquoise for the code symbol and magnifying glass accent. Clean negative space surrounds the central composition. Modern',
  'id': 232},
 {'final_output': '# Image Prompt\n\nA sleek, modern highway road that transforms into a glowing digital data stream, rendered in bold editorial illustration style. The road surface begins as concrete asphalt at the bottom and dissolves into flowing luminous particles of cyan and electric blue toward the horizon. A single, simplified shield or lock icon floats above the center of the road, symbolizing governance and security. Deep navy blue background',
  'id': 233},
 {'final_output': "# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A single large magnifying glass floating in the center against a vibrant coral-pink background, but instead of a glass lens, there's a glowing AI circuit pattern or neural network node. Beneath the magnifying glass, a tiny, faded website browser window icon sits small and ghosted out in pale gray, barely",
  'id': 234}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
