# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 206,
  'headline': 'World Labs Raises $1 Billion for Spatial AI',
  'output': "World Labs closed a $1 billion equity round on February 18, 2026, to accelerate its spatial intelligence platform. Autodesk contributed $200 million and will integrate World Labs' Marble product into its 3D design tools. Other investors include Nvidia, AMD Ventures, Sea Ltd., Fidelity, and Emerson Collective. The financing, structured as convertible preferred stock, will fund expansion in gaming, robotics, and design workflows. Autodesk's strategic stake signals that world models generating persistent, editable 3D environments from text or images are moving from research into professional creative and engineering pipelines.",
  'image_url': None},
 {'id': 208,
  'headline': 'Code Metal Hits Unicorn Status With $125M Series B',
  'output': "Code Metal closed a $125 million Series B led by Salesforce Ventures, reaching a $1.25 billion valuation. The round included Accel, B Capital, Shield Capital, and defense investor RTX Ventures. The company modernizes legacy defense software using AI-driven code translation tools with built-in verification for mission-critical systems. Funds will expand engineering and go-to-market partnerships with customers including the U.S. Air Force, RTX, and L3Harris. Former Tableau executive Ryan Aytay joins as President and COO. RTX Ventures' participation signals strategic alignment with defense primes seeking verifiable AI tooling for regulated, high-stakes environments.",
  'image_url': None},
 {'id': 209,
  'headline': 'Peak XV Raises $1.3B in First Funds Post-Sequoia Split',
  'output': 'Peak XV Partners has closed $1.3 billion across three equity-focused venture funds targeting India and Asia, marking its first independent raise since separating from Sequoia. The capital spans India Seed, India Venture, and APAC funds, with global LPs including endowments and foundations participating. The firm will deploy the majority into India over the next two to three years, focusing on AI, fintech, consumer tech, and deeptech from seed to later stages. Peak XV now manages over $10 billion across 450+ portfolio companies and has backed more than 80 AI startups, signaling sustained conviction in the region despite recent senior-partner departures.',
  'image_url': None},
 {'id': 210,
  'headline': 'Gates, Wellcome Launch $60M AI Health Trial Fund',
  'output': "Gates Foundation, Novo Nordisk Foundation, and Wellcome today announced a $60 million grant program to evaluate mature AI health tools in low- and middle-income countries across sub-Saharan Africa, South Asia, and Southeast Asia. The Evidence for AI in Health initiative, delivered through J-PAL and APHRC, will fund randomized trials and implementation studies to assess efficacy, economic value, and acceptability of AI decision-support tools in primary care. Applications are now open. The program aims to generate real-world evidence guiding policy and deployment decisions in resource-constrained health systems, marking the second investment from the foundations' $300 million global health partnership.",
  'image_url': None},
 {'id': 211,
  'headline': "Anthropic's Claude Now Hunts Critical Bugs Across Codebases",
  'output': 'Anthropic launched Claude Code Security on February 20, 2026, a tool powered by Claude Opus 4.6 that autonomously scans entire codebases to find and prioritize high-severity vulnerabilities humans often miss. Unlike traditional pattern-based scanners, it performs end-to-end analysis, traces data flows across components, scores severity automatically, and suggests fixes without applying them. The research preview is available now for Enterprise and Team customers, with expedited access for open-source maintainers. Security teams gain faster triage and developers get guided remediation, addressing a critical gap in enterprise and open-source security workflows as vulnerabilities grow more complex.',
  'image_url': None},
 {'id': 212,
  'headline': 'Google Gemini Now Creates 30-Second AI Songs With Lyrics',
  'output': 'Google launched Lyria 3 in the Gemini app, letting users generate 30-second music tracks with lyrics and custom cover art from text or image prompts. Available in beta worldwide for users 18+, it adds auto-generated lyrics, enhanced control over style, vocals, and tempo, plus more realistic output compared to prior versions. Desktop access is live now, mobile coming soon. Creators can prototype video soundtracks faster or pair photos with prompts for shareable tracks. All outputs include SynthID watermarks for AI-origin verification. Google AI Plus, Pro, and Ultra subscribers get higher generation limits.',
  'image_url': None},
 {'id': 213,
  'headline': "India's Sarvam AI Unveils Models for 22 Languages",
  'output': "Sarvam AI launched two large language models, Sarvam-30B and Sarvam-105B, trained for all 22 Indian languages using a mixture-of-experts design with up to 128,000-token context windows. The company also debuted Vikram, an offline multilingual assistant that runs on feature phones, cars, and wearables for real-time voice conversations in local languages. Demos showed Hindi and Punjabi interactions for government-scheme guidance. Built with Nvidia and Yotta infrastructure under India's sovereign IndiaAI Mission, the models aim to challenge frontier AI with cost-efficient, edge-optimized reasoning and mark a major step toward homegrown, multilingual AI infrastructure.",
  'image_url': None},
 {'id': 214,
  'headline': 'Figma Make Pulls Live Research Data Into Prototypes',
  'output': 'Figma Make now supports external connectors via the Model Context Protocol, letting designers pull customer quotes, research findings, and analytics directly into prototype workflows using @mentions. Design teams can connect tools like Dovetail, Marvin, and zeroheight to surface live context during prototyping without switching apps. To start Monday: have an admin enable connectors for your organization, authenticate partner tools via OAuth, then reference them in Make prompts. This embeds real user research and data into design decisions, tightening collaboration between product, design, and engineering teams by grounding prototypes in actual customer context instead of assumptions.',
  'image_url': None},
 {'id': 215,
  'headline': 'Notion Agents Launch Next Week, Already Building Half Its Databases',
  'output': 'Notion will publicly launch custom AI agents next week that autonomously perform tasks across workspaces. Over 50% of Notion databases are now built by agents. The agents handle end-to-end workflows like generating status updates, building databases, and drafting documents across connected apps including Jira, Slack, and email. Product teams can automate cross-functional planning, research, and reporting that previously required manual page updates. Agents operate with your existing permissions and connect via expanded integrations. This matters now because it transforms knowledge work from manual coordination into agent-driven automation, relevant for teams planning workflows in Q1 and Q2 2026.',
  'image_url': None},
 {'id': 216,
  'headline': 'Weaviate Cuts RAG Pipeline Coding With Agent Skills',
  'output': 'Weaviate has launched Agent Skills, an open-source repository that lets AI coding assistants like Claude, Cursor, and GitHub Copilot automate Weaviate tasks through a unified command surface. Software engineers building RAG pipelines can now guide agents to handle schema inspection, data imports, and retrieval workflows instead of writing custom scripts. You can start Monday by installing the skills via npx, spinning up a free 14-day Weaviate Cloud Sandbox, and running quickstart commands to integrate agents into your environment. The shift standardizes how teams prototype and debug, cutting manual integration work and accelerating demos across engineering, product, and marketing.',
  'image_url': None},
 {'id': 217,
  'headline': 'WordPress Embeds AI Assistant for One-Prompt Content Edits',
  'output': "WordPress has launched an opt-in AI assistant built into its site editor and media library that edits text, translates content, adjusts fonts and layouts, and generates or edits images using Google's Nano Banana models. Marketers and designers can now update text, design, and visuals with a single natural-language prompt instead of manual edits across blocks and media assets. To start, enable AI tools in Site Settings, use the new Generate Image option in the Media Library, or type @ai in block notes for instant content suggestions. Sites built via WordPress' AI website builder have the assistant enabled by default, helping teams accelerate Q2 site management and campaign asset production.",
  'image_url': None},
 {'id': 218,
  'headline': 'Meta Bakes Manus AI Into Ads Manager Workflow',
  'output': 'Meta has embedded Manus AI directly into Ads Manager, eliminating the need for external tools or manual API work to generate reports and analyze audiences. Advertisers now access AI-powered campaign insights, automated reporting, and audience research through in-workflow prompts and a Tools menu shortcut. The integration is rolling out to all advertisers as of mid-February 2026. Marketing, data, and product teams can now collaborate faster inside a single platform. Starting Monday, enable the Manus shortcut, run a test automated report on a live campaign, and translate one AI-generated insight into an optimization task.',
  'image_url': None},
 {'id': 219,
  'headline': 'India mandates AI-generated content labels by February 20',
  'output': "India's new IT Rules 2026, effective February 20, mandate that all synthetic AI content (audio, video, images) must carry permanent labels and embedded metadata for traceability. Social media platforms must deploy user declaration flows, verification mechanisms, and remove unlawful AI content within three hours of a court or government notice, down from previous longer windows. Routine editing and educational materials are exempt. Platforms face enforcement penalties under existing Indian law. Implementation priority: build robust labeling infrastructure with embedded metadata and traceability chains to meet the three-hour takedown requirement and shortened seven-day grievance timelines.",
  'image_url': None},
 {'id': 220,
  'headline': '70% of Firms Use AI, Yet 80% See Zero Impact',
  'output': 'A new NBER study surveying nearly 6,000 executives across the US, UK, Germany, and Australia reveals a striking gap between AI adoption and results. Around 70% of firms actively use AI and two-thirds of executives spend 1.5 hours weekly on it, yet over 80% report no employment or productivity impact over the past three years. Firms forecast 1.4% productivity gains and 0.7% job cuts over the next three years, while employees expect net job growth. The takeaway: substantial ROI demands structured measurement frameworks, workflow redesign, and cross-functional governance, not just tool deployment.',
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA single, pristine white marble sphere floating in vast empty space, with subtle 3D wireframe grid lines wrapping partially around its surface. The sphere casts a soft shadow below. Bold gradient background transitioning from deep cobalt blue to electric purple. The marble has a luminous, almost holographic quality with hints of iridescent blue and gold reflections on its surface. Ultra',
#   'id': 206},
#  {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single, gleaming silver unicorn horn emerging vertically from a dark military-green shield. The horn has subtle circuit-board line patterns etched into its metallic surface, suggesting the fusion of legendary status and code/technology. The shield sits centered against a bold, solid deep navy background with generous negative space. The composition uses a limited color palette: metal',
#   'id': 208},
#  {'final_output': '# Image Prompt\n\nA single majestic mountain peak emerging from stylized clouds, rendered in bold editorial illustration style. The mountain is depicted in deep indigo and rich purple gradients, with a golden sunrise glow illuminating its summit. Soft, minimal cloud forms in cream and pale blue float around the base, creating negative space. The composition is clean and centered, shot in wide 16:9 ',
#   'id': 209},
#  {'final_output': '**Image Prompt:**\n\nA single glowing stethoscope with AI circuit patterns flowing through its tubing, set against a bold gradient background transitioning from deep teal to warm amber. The stethoscope floats in the center with generous negative space around it. The chest piece subtly illuminates with a soft technological glow, and minimal geometric circuit lines weave organically through the rubber tube.',
#   'id': 210},
#  {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A single glowing magnifying glass hovers over abstract code lines, with a critical bug rendered as a bold red geometric shape (like a stylized beetle or hexagon) caught in sharp focus beneath the lens. The background is a clean gradient of deep navy to soft blue, with sparse, faded code snippets floating in',
#   'id': 211},
#  {'final_output': '# Image Prompt\n\nA single vintage-style microphone standing vertically in the center, with vibrant sound waves materializing into glowing musical notes that flow upward and dissolve into the air. The microphone is rendered in bold teal and chrome, while the sound waves transition from electric purple to warm coral. Set against a clean gradient background from deep navy to soft lavender, with generous negative space around',
#   'id': 212},
#  {'final_output': '**Image Prompt:**\n\nA single glowing smartphone floating in center frame against a deep indigo background, with elegant flowing ribbons of text in multiple Indian scripts (Devanagari, Tamil, Bengali) spiraling gently around it in vibrant saffron, emerald green, and coral colors. The phone screen emits a warm, welcoming light. Minimal composition with the phone as the',
#   'id': 213},
#  {'final_output': '# Image Prompt\n\nA single oversized **@ symbol** in bold coral or electric blue, floating prominently in center frame, with delicate **golden threads or light beams** extending from it connecting to 3-4 small, abstract geometric shapes (circles, squares) scattered around it representing connected data sources. Clean white or soft gradient background with generous negative space. The @ symbol should feel tactile and',
#   'id': 214},
#  {'final_output': '# Image Prompt\n\nA sleek robotic arm emerging from below, constructing glowing database blocks that float and stack in mid-air. The blocks have a minimalist grid pattern suggesting organized data. The robotic arm is rendered in deep midnight blue with bright cyan accent lights, while the database blocks glow in vibrant gradient colors from coral pink to electric purple. Clean composition with the arm in lower third,',
#   'id': 215},
#  {'final_output': '# Image Prompt\n\nA sleek robotic arm or mechanical hand assembling colorful modular pipeline segments that float and connect in mid-air, set against a vibrant gradient background from deep purple to electric blue. The pipeline pieces are geometric, simplified shapes in bold colors—coral, yellow, and cyan—clicking together effortlessly with minimal gaps. The composition emphasizes the ease of assembly with plenty of breathing',
#   'id': 216},
#  {'final_output': "# Image Prompt\n\nA minimalist editorial illustration showing a single glowing magic wand hovering over an open laptop computer, with sparkles or light trails emerging from the wand tip and flowing into the screen. The laptop displays a simplified WordPress 'W' logo or abstract website layout. Use a bold two-color palette: deep purple background with bright electric cyan/turquoise for the wand and magical",
#   'id': 217},
#  {'final_output': '# Image Prompt\n\nA sleek, oversized megaphone in vibrant Meta blue emerging from or merging with a glowing AI brain node, set against a clean gradient background of coral pink to white. The megaphone represents advertising/Meta Ads Manager while the luminous neural network node symbolizes the embedded AI capability. Minimalist composition with the hybrid object positioned in the lower right third, leaving',
#   'id': 218},
#  {'final_output': '# Image Prompt\n\nA large rubber stamp pressing down onto a smartphone screen, leaving a bold red "AI" seal mark. The stamp is tilted at a dynamic angle, captured mid-press with the imprint partially visible on the glowing phone display. The composition uses a limited color palette of deep blue background, white smartphone, metallic silver stamp handle, and vibrant red seal. Dramatic side lighting creates',
#   'id': 219},
#  {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A sleek, glowing AI robot or digital brain icon sits alone on a pristine office desk, casting a shadow but leaving the desk surface otherwise completely empty and untouched. The robot/brain emits a soft blue-purple glow against a muted coral or warm gray background with abundant negative space. The composition',
#   'id': 220}]

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 206,
#   'headline': 'World Labs Raises $1 Billion for Spatial AI',
#   'output': "World Labs closed a $1 billion equity round on February 18, 2026, to accelerate its spatial intelligence platform. Autodesk contributed $200 million and will integrate World Labs' Marble product into its 3D design tools. Other investors include Nvidia, AMD Ventures, Sea Ltd., Fidelity, and Emerson Collective. The financing, structured as convertible preferred stock, will fund expansion in gaming, robotics, and design workflows. Autodesk's strategic stake signals that world models generating persistent, editable 3D environments from text or images are moving from research into professional creative and engineering pipelines.",
#   'image_url': None},
#  {'id': 208,
#   'headline': 'Code Metal Hits Unicorn Status With $125M Series B',
#   'output': "Code Metal closed a $125 million Series B led by Salesforce Ventures, reaching a $1.25 billion valuation. The round included Accel, B Capital, Shield Capital, and defense investor RTX Ventures. The company modernizes legacy defense software using AI-driven code translation tools with built-in verification for mission-critical systems. Funds will expand engineering and go-to-market partnerships with customers including the U.S. Air Force, RTX, and L3Harris. Former Tableau executive Ryan Aytay joins as President and COO. RTX Ventures' participation signals strategic alignment with defense primes seeking verifiable AI tooling for regulated, high-stakes environments.",
#   'image_url': None},
#  {'id': 209,
#   'headline': 'Peak XV Raises $1.3B in First Funds Post-Sequoia Split',
#   'output': 'Peak XV Partners has closed $1.3 billion across three equity-focused venture funds targeting India and Asia, marking its first independent raise since separating from Sequoia. The capital spans India Seed, India Venture, and APAC funds, with global LPs including endowments and foundations participating. The firm will deploy the majority into India over the next two to three years, focusing on AI, fintech, consumer tech, and deeptech from seed to later stages. Peak XV now manages over $10 billion across 450+ portfolio companies and has backed more than 80 AI startups, signaling sustained conviction in the region despite recent senior-partner departures.',
#   'image_url': None},
#  {'id': 210,
#   'headline': 'Gates, Wellcome Launch $60M AI Health Trial Fund',
#   'output': "Gates Foundation, Novo Nordisk Foundation, and Wellcome today announced a $60 million grant program to evaluate mature AI health tools in low- and middle-income countries across sub-Saharan Africa, South Asia, and Southeast Asia. The Evidence for AI in Health initiative, delivered through J-PAL and APHRC, will fund randomized trials and implementation studies to assess efficacy, economic value, and acceptability of AI decision-support tools in primary care. Applications are now open. The program aims to generate real-world evidence guiding policy and deployment decisions in resource-constrained health systems, marking the second investment from the foundations' $300 million global health partnership.",
#   'image_url': None},
#  {'id': 211,
#   'headline': "Anthropic's Claude Now Hunts Critical Bugs Across Codebases",
#   'output': 'Anthropic launched Claude Code Security on February 20, 2026, a tool powered by Claude Opus 4.6 that autonomously scans entire codebases to find and prioritize high-severity vulnerabilities humans often miss. Unlike traditional pattern-based scanners, it performs end-to-end analysis, traces data flows across components, scores severity automatically, and suggests fixes without applying them. The research preview is available now for Enterprise and Team customers, with expedited access for open-source maintainers. Security teams gain faster triage and developers get guided remediation, addressing a critical gap in enterprise and open-source security workflows as vulnerabilities grow more complex.',
#   'image_url': None},
#  {'id': 212,
#   'headline': 'Google Gemini Now Creates 30-Second AI Songs With Lyrics',
#   'output': 'Google launched Lyria 3 in the Gemini app, letting users generate 30-second music tracks with lyrics and custom cover art from text or image prompts. Available in beta worldwide for users 18+, it adds auto-generated lyrics, enhanced control over style, vocals, and tempo, plus more realistic output compared to prior versions. Desktop access is live now, mobile coming soon. Creators can prototype video soundtracks faster or pair photos with prompts for shareable tracks. All outputs include SynthID watermarks for AI-origin verification. Google AI Plus, Pro, and Ultra subscribers get higher generation limits.',
#   'image_url': None},
#  {'id': 213,
#   'headline': "India's Sarvam AI Unveils Models for 22 Languages",
#   'output': "Sarvam AI launched two large language models, Sarvam-30B and Sarvam-105B, trained for all 22 Indian languages using a mixture-of-experts design with up to 128,000-token context windows. The company also debuted Vikram, an offline multilingual assistant that runs on feature phones, cars, and wearables for real-time voice conversations in local languages. Demos showed Hindi and Punjabi interactions for government-scheme guidance. Built with Nvidia and Yotta infrastructure under India's sovereign IndiaAI Mission, the models aim to challenge frontier AI with cost-efficient, edge-optimized reasoning and mark a major step toward homegrown, multilingual AI infrastructure.",
#   'image_url': None},
#  {'id': 214,
#   'headline': 'Figma Make Pulls Live Research Data Into Prototypes',
#   'output': 'Figma Make now supports external connectors via the Model Context Protocol, letting designers pull customer quotes, research findings, and analytics directly into prototype workflows using @mentions. Design teams can connect tools like Dovetail, Marvin, and zeroheight to surface live context during prototyping without switching apps. To start Monday: have an admin enable connectors for your organization, authenticate partner tools via OAuth, then reference them in Make prompts. This embeds real user research and data into design decisions, tightening collaboration between product, design, and engineering teams by grounding prototypes in actual customer context instead of assumptions.',
#   'image_url': None},
#  {'id': 215,
#   'headline': 'Notion Agents Launch Next Week, Already Building Half Its Databases',
#   'output': 'Notion will publicly launch custom AI agents next week that autonomously perform tasks across workspaces. Over 50% of Notion databases are now built by agents. The agents handle end-to-end workflows like generating status updates, building databases, and drafting documents across connected apps including Jira, Slack, and email. Product teams can automate cross-functional planning, research, and reporting that previously required manual page updates. Agents operate with your existing permissions and connect via expanded integrations. This matters now because it transforms knowledge work from manual coordination into agent-driven automation, relevant for teams planning workflows in Q1 and Q2 2026.',
#   'image_url': None},
#  {'id': 216,
#   'headline': 'Weaviate Cuts RAG Pipeline Coding With Agent Skills',
#   'output': 'Weaviate has launched Agent Skills, an open-source repository that lets AI coding assistants like Claude, Cursor, and GitHub Copilot automate Weaviate tasks through a unified command surface. Software engineers building RAG pipelines can now guide agents to handle schema inspection, data imports, and retrieval workflows instead of writing custom scripts. You can start Monday by installing the skills via npx, spinning up a free 14-day Weaviate Cloud Sandbox, and running quickstart commands to integrate agents into your environment. The shift standardizes how teams prototype and debug, cutting manual integration work and accelerating demos across engineering, product, and marketing.',
#   'image_url': None},
#  {'id': 217,
#   'headline': 'WordPress Embeds AI Assistant for One-Prompt Content Edits',
#   'output': "WordPress has launched an opt-in AI assistant built into its site editor and media library that edits text, translates content, adjusts fonts and layouts, and generates or edits images using Google's Nano Banana models. Marketers and designers can now update text, design, and visuals with a single natural-language prompt instead of manual edits across blocks and media assets. To start, enable AI tools in Site Settings, use the new Generate Image option in the Media Library, or type @ai in block notes for instant content suggestions. Sites built via WordPress' AI website builder have the assistant enabled by default, helping teams accelerate Q2 site management and campaign asset production.",
#   'image_url': None},
#  {'id': 218,
#   'headline': 'Meta Bakes Manus AI Into Ads Manager Workflow',
#   'output': 'Meta has embedded Manus AI directly into Ads Manager, eliminating the need for external tools or manual API work to generate reports and analyze audiences. Advertisers now access AI-powered campaign insights, automated reporting, and audience research through in-workflow prompts and a Tools menu shortcut. The integration is rolling out to all advertisers as of mid-February 2026. Marketing, data, and product teams can now collaborate faster inside a single platform. Starting Monday, enable the Manus shortcut, run a test automated report on a live campaign, and translate one AI-generated insight into an optimization task.',
#   'image_url': None},
#  {'id': 219,
#   'headline': 'India mandates AI-generated content labels by February 20',
#   'output': "India's new IT Rules 2026, effective February 20, mandate that all synthetic AI content (audio, video, images) must carry permanent labels and embedded metadata for traceability. Social media platforms must deploy user declaration flows, verification mechanisms, and remove unlawful AI content within three hours of a court or government notice, down from previous longer windows. Routine editing and educational materials are exempt. Platforms face enforcement penalties under existing Indian law. Implementation priority: build robust labeling infrastructure with embedded metadata and traceability chains to meet the three-hour takedown requirement and shortened seven-day grievance timelines.",
#   'image_url': None},
#  {'id': 220,
#   'headline': '70% of Firms Use AI, Yet 80% See Zero Impact',
#   'output': 'A new NBER study surveying nearly 6,000 executives across the US, UK, Germany, and Australia reveals a striking gap between AI adoption and results. Around 70% of firms actively use AI and two-thirds of executives spend 1.5 hours weekly on it, yet over 80% report no employment or productivity impact over the past three years. Firms forecast 1.4% productivity gains and 0.7% job cuts over the next three years, while employees expect net job growth. The takeaway: substantial ROI demands structured measurement frameworks, workflow redesign, and cross-functional governance, not just tool deployment.',
#   'image_url': None}]

# %%
public_urls_5 = []

# %%
prompt = [
 {'final_output': '**Image Prompt:**\n\nA single glowing stethoscope with AI circuit patterns flowing through its tubing, set against a bold gradient background transitioning from deep teal to warm amber. The stethoscope floats in the center with generous negative space around it. The chest piece subtly illuminates with a soft technological glow, and minimal geometric circuit lines weave organically through the rubber tube.',
  'id': 210},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A single glowing magnifying glass hovers over abstract code lines, with a critical bug rendered as a bold red geometric shape (like a stylized beetle or hexagon) caught in sharp focus beneath the lens. The background is a clean gradient of deep navy to soft blue, with sparse, faded code snippets floating in',
  'id': 211},
 {'final_output': '# Image Prompt\n\nA single vintage-style microphone standing vertically in the center, with vibrant sound waves materializing into glowing musical notes that flow upward and dissolve into the air. The microphone is rendered in bold teal and chrome, while the sound waves transition from electric purple to warm coral. Set against a clean gradient background from deep navy to soft lavender, with generous negative space around',
  'id': 212},
 {'final_output': '**Image Prompt:**\n\nA single glowing smartphone floating in center frame against a deep indigo background, with elegant flowing ribbons of text in multiple Indian scripts (Devanagari, Tamil, Bengali) spiraling gently around it in vibrant saffron, emerald green, and coral colors. The phone screen emits a warm, welcoming light. Minimal composition with the phone as the',
  'id': 213},
 {'final_output': '# Image Prompt\n\nA single oversized **@ symbol** in bold coral or electric blue, floating prominently in center frame, with delicate **golden threads or light beams** extending from it connecting to 3-4 small, abstract geometric shapes (circles, squares) scattered around it representing connected data sources. Clean white or soft gradient background with generous negative space. The @ symbol should feel tactile and',
  'id': 214},
 {'final_output': '# Image Prompt\n\nA sleek robotic arm emerging from below, constructing glowing database blocks that float and stack in mid-air. The blocks have a minimalist grid pattern suggesting organized data. The robotic arm is rendered in deep midnight blue with bright cyan accent lights, while the database blocks glow in vibrant gradient colors from coral pink to electric purple. Clean composition with the arm in lower third,',
  'id': 215},
 {'final_output': '# Image Prompt\n\nA sleek robotic arm or mechanical hand assembling colorful modular pipeline segments that float and connect in mid-air, set against a vibrant gradient background from deep purple to electric blue. The pipeline pieces are geometric, simplified shapes in bold colors—coral, yellow, and cyan—clicking together effortlessly with minimal gaps. The composition emphasizes the ease of assembly with plenty of breathing',
  'id': 216},
 {'final_output': "# Image Prompt\n\nA minimalist editorial illustration showing a single glowing magic wand hovering over an open laptop computer, with sparkles or light trails emerging from the wand tip and flowing into the screen. The laptop displays a simplified WordPress 'W' logo or abstract website layout. Use a bold two-color palette: deep purple background with bright electric cyan/turquoise for the wand and magical",
  'id': 217},
 {'final_output': '# Image Prompt\n\nA sleek, oversized megaphone in vibrant Meta blue emerging from or merging with a glowing AI brain node, set against a clean gradient background of coral pink to white. The megaphone represents advertising/Meta Ads Manager while the luminous neural network node symbolizes the embedded AI capability. Minimalist composition with the hybrid object positioned in the lower right third, leaving',
  'id': 218},
 {'final_output': '# Image Prompt\n\nA large rubber stamp pressing down onto a smartphone screen, leaving a bold red "AI" seal mark. The stamp is tilted at a dynamic angle, captured mid-press with the imprint partially visible on the glowing phone display. The composition uses a limited color palette of deep blue background, white smartphone, metallic silver stamp handle, and vibrant red seal. Dramatic side lighting creates',
  'id': 219},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration in wide 16:9 format: A sleek, glowing AI robot or digital brain icon sits alone on a pristine office desk, casting a shadow but leaving the desk surface otherwise completely empty and untouched. The robot/brain emits a soft blue-purple glow against a muted coral or warm gray background with abundant negative space. The composition',
  'id': 220}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/199.png',
#   'id': 199},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/200.png',
#   'id': 200},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/201.png',
#   'id': 201},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/202.png',
#   'id': 202},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/203.png',
#   'id': 203},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/204.png',
#   'id': 204},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/205.png',
#   'id': 205}]

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# UploadResponse(path='52.png', full_path='article-image/52.png', fullPath='article-image/52.png')

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headline': 'NIST Drops $3M on Eight Wild Tech Bets', 'image_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/52.png'}], count=None)

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
