# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 334,
  'headline': "Malicious Extensions Could Hijack Chrome's Gemini Panel",
  'output': "Palo Alto Networks discovered a high-severity flaw letting rogue Chrome extensions hijack Google's Gemini Live panel and access your camera, microphone, and local files. The attack worked through basic extension permissions, turning a feature meant to help you into a phishing tool. Google patched it in early January after October disclosure, but the vulnerability exposes a bigger problem: AI assistants baked directly into browsers create juicy new targets for attackers. Every helpful AI panel is now potential real estate for malware. The era of trusting browser extensions because they seem harmless just ended.",
  'image_url': None},
 {'id': 335,
  'headline': "Lenovo's Qira AI Learns What You Were Doing on Your Laptop",
  'output': 'Lenovo is rolling out Qira, an ambient AI that remembers what you were working on when you switch between your laptop, tablet, and phone. Coming to 20+ devices in the next few weeks, it suggests next actions based on context. Close a spreadsheet on your ThinkPad, open your IdeaPad, and Qira picks up where you left off. The first tablet version ships on the Idea Tab Pro Gen 2 with live transcription and instant summaries. Six languages launch first, with Motorola phones joining later this year. The bet: AI that follows you between devices beats AI trapped in one app.',
  'image_url': None},
 {'id': 336,
  'headline': 'Andreessen Horowitz Bets $41M on AI for Therapist Paperwork',
  'output': "Ease Health just raised $41 million from Andreessen Horowitz to replace the jumble of software that bogs down behavioral health clinics. The startup automates admissions, intake forms, clinical notes, insurance verification, and billing with AI. Think of it as swapping a dozen clunky tools for one system that handles everything from verifying a patient's coverage to documenting their session. The money will go toward hiring engineers and signing up more treatment centers across the U.S. If it works, therapists could spend less time fighting with insurance portals and more time actually treating patients.",
  'image_url': None},
 {'id': 337,
  'headline': 'AI Turns Phone Snapshots Into 4K Product Photos',
  'output': "Rewarx just launched RewarxStudio, a tool that converts rough product snapshots into 4K commercial images without anyone writing a single prompt. The platform claims to handle 100+ products per minute using what it calls Visual Intent Recognition—you pick a scene, it figures out the lighting and shadows. It's built for online sellers who list hundreds of SKUs across Amazon, Shopify, and Etsy but can't afford traditional photoshoots for every item. The catch? Performance numbers come from an internal audit, not independent testing. If it works as advertised, the $200-per-product studio shoot might become as obsolete as dial-up.",
  'image_url': None},
 {'id': 338,
  'headline': 'Smack Technologies Raises $32M for Pentagon AI Models',
  'output': 'Smack Technologies closed $32 million across seed and Series A rounds to build what it calls the first frontier AI lab dedicated to national security. Geodesic Capital and Costanoa Ventures led the Series A, with Point72 Ventures anchoring the earlier seed round. The company plans to train domain-specific AI models named Omega and Alpha for U.S. military use, expanding contracts with the Defense Department and warfighting labs. While Big Tech faces restrictions selling advanced AI to governments, investors are betting that specialized defense-focused labs can fill the gap where general-purpose models fall short on classified networks.',
  'image_url': None},
 {'id': 339,
  'headline': 'SK Telecom Doubles AI Model to 1 Trillion Parameters',
  'output': 'South Korea\'s largest telecom just upgraded its homegrown AI model from 519 billion to over 1 trillion parameters and added image, voice, and video understanding arriving later this year. The move is part of SK Telecom\'s bid to make Korea a top-three AI power by building what it calls "AI sovereignty," complete with 1 gigawatt of data center capacity to match. One early test: a manufacturing AI built with SK hynix that spots defects in real time on chip production lines. The strategy bets that nations will care as much about owning their AI stack as they once did about controlling their telecom networks.',
  'image_url': None},
 {'id': 340,
  'headline': 'Telecom Industry Launches Its Own AI Model Hub',
  'output': "GSMA just launched Open Telco AI, a shared portal for telecoms to build models that actually understand network operations. The timing matters: only 16% of AI deployments touch network ops today. Current frontier models can't handle telco-specific troubleshooting reliably enough for real deployment.\n\nThe hub pools open models (AT&T is contributing its family), datasets, compute from AMD, and a benchmark index to test whether models can handle telecom tasks. Think GitHub meets model zoo, but for an industry that moves billions of calls and packets daily.\n\nThe surprise? Telecoms finally admitted they need their own models instead of waiting for ChatGPT to learn network protocols.",
  'image_url': None},
 {'id': 341,
  'headline': 'Nvidia Bets $4 Billion on Laser Suppliers',
  'output': "Nvidia just invested $2 billion each in Coherent and Lumentum, two companies that make the lasers and optical components connecting AI chips inside data centers. The deals come with multibillion-dollar purchase commitments and guaranteed access to manufacturing capacity. Both suppliers will build new U.S. factories. The message: Nvidia thinks the next AI bottleneck won't be chips, but the fiber optics and lasers shuttling data between them. When the company making GPUs starts locking down the humble components that carry light signals, it's a sign AI infrastructure is moving faster than the supply chain can handle.",
  'image_url': None},
 {'id': 342,
  'headline': 'Fed Warns AI Could Push Up Unemployment, Complicate Inflation Fight',
  'output': "The Federal Reserve is racing to understand how AI will reshape jobs and prices, and the early signals are messy. Officials now acknowledge AI could drive unemployment higher in the near term, even as it boosts productivity. That's a policy nightmare: rising joblessness usually calls for rate cuts, but AI's massive energy and infrastructure demands could keep inflation sticky. Block just previewed the stakes, cutting 4,000 jobs (40% of staff) in one swoop. The Fed's bet? Productivity gains won't cool prices fast enough to offset the disruption. Central bankers are discovering that AI doesn't follow the old playbook where unemployment and inflation move in lockstep.",
  'image_url': None},
 {'id': 343,
  'headline': 'Israeli Startup Raises $58M Seed for Solo Seller Platform',
  'output': "ZyG Edge, an Israeli startup, just closed a $58 million seed round to help solo inventors compete with major brands online. That's roughly 10x the typical seed check, signaling investors believe AI can finally crack the long tail of e-commerce.\n\nThe company's platform uses AI agents to handle growth tasks for small sellers, from marketing to logistics. ZyG takes payment only as sellers grow and offers funding to top-scoring products on its network.\n\nThree top-tier firms (Bessemer, Viola, Lightspeed) co-led the round. The bet: millions of solo creators need the same tools as Amazon merchants, without the upfront cost.",
  'image_url': None},
 {'id': 344,
  'headline': 'Quantum Math Shrinks AI Models 95% to Run Offline',
  'output': "Multiverse Computing launched CompactifAI App on March 3, a mobile tool that compresses AI models by up to 95% using quantum-inspired mathematics. The trade-off: 2-3% precision loss. What you get: advanced AI running fully offline on your phone, no cloud required. The app lets field workers in dead zones or privacy-sensitive environments run AI locally, then switch to cloud APIs when connectivity returns for heavier tasks. Think engineers inspecting remote infrastructure or doctors reviewing patient data in rural clinics. The surprise isn't just shrinking models—it's that quantum techniques, not silicon breakthroughs, finally made your phone smart enough to work alone.",
  'image_url': None},
 {'id': 345,
  'headline': 'AMD Brings Copilot+ PCs to Desktops for First Time',
  'output': "AMD just announced the first desktop chips designed to run Microsoft's Copilot+ PC features, which until now only worked on laptops. The new Ryzen AI 400 desktop processors pack a dedicated AI chip that crunches 50 trillion operations per second, while their mobile workstation siblings hit 60 trillion. Translation: AI tasks like transcription or image editing happen on your machine instead of round-tripping to a data center. The mobile chips also beat Intel's latest by 30% in multithreaded workloads. Dell, HP, and Lenovo will ship machines with the new chips starting in Q2 2026. The real test will be whether on-device AI proves faster than today's cloud-based tools in daily work.",
  'image_url': None},
 {'id': 346,
  'headline': 'Two-Thirds of Companies Stuck in AI Pilot Purgatory',
  'output': "McKinsey published a sobering reality check: roughly 66% of organizations have never scaled AI beyond pilots, with fewer than 10% getting AI agents past trial runs in any single department. The culprit isn't the technology. Companies with senior leaders who actually use the tools daily and champion AI are three times more likely to see real returns. One bank's executives integrated AI dashboards into their routines and unlocked $150 million in new revenue. A pharma firm cut drug launch prep from 12 months to three. Turns out the hardest part of AI transformation is getting the C-suite to change their Tuesday morning habits.",
  'image_url': None},
 {'id': 347,
  'headline': 'Amazon Doubles Down on Spain with $40B AI Bet',
  'output': "Amazon just committed €33.7 billion ($40B) to build AWS data centers and AI server manufacturing plants in Spain through 2035, more than doubling the €15.7B it pledged last year. The cash will fund a new manufacturing plant that builds and repairs AI servers in Aragón, plus expanded cloud capacity across the country. Spain is positioning itself as Europe's AI infrastructure hub while other nations debate regulatory guardrails. The move signals Amazon expects European AI demand to explode, and it's willing to build the physical backbone before customers even ask for it. Big tech is betting billions that the AI boom needs a continental manufacturing footprint, not just California campuses.",
  'image_url': None},
 {'id': 348,
  'headline': 'MacBook Air M5 Runs AI 9.5x Faster Than M1',
  'output': "Apple's new MacBook Air with M5 ships March 11 with Neural Accelerators in every GPU core, letting you run language models locally without touching the cloud. AI tasks run 9.5x faster than the M1 generation and 4x faster than last year's M4. The kicker: base storage doubles to 512GB, and prices still start at $1,099. You can now prototype AI apps on a laptop that weighs 2.7 pounds, keeping your training data off someone else's servers. The shift matters because Apple just made privacy-first AI development a mainstream option, not a compromise.",
  'image_url': None},
 {'id': 349,
  'headline': '79% of Companies Have Shadow AI Running Right Now',
  'output': "Nutanix surveyed 1,600 IT executives at large companies and found a messy reality: 79% report employees in non-IT departments are already running their own AI tools without permission. The kicker? While 85% say AI is speeding up their shift to containers, 82% admit their current infrastructure isn't ready for it. Companies are caught between employees racing ahead with AI and data centers struggling to keep up. Meanwhile, 80% are prioritizing keeping data inside national borders, adding another layer of complexity. The gap between AI ambition and what IT can actually support has never been wider.",
  'image_url': None},
 {'id': 350,
  'headline': "China's KargoBot Raises $100M to Put 10,000 Driverless Trucks on Highways",
  'output': "KargoBot.ai just closed a $100 million Series B to blanket China's highways with autonomous freight trucks. The startup, which spun out of Didi, already runs 400 self-driving trucks and plans to hit 1,000 this year before scaling to 10,000. That's not a pilot program, it's an industrial rollout.\n\nHorizon Robotics and Gaorong Ventures co-led the round, signaling investors believe fully autonomous long-haul trucking will arrive in China before it reaches American interstates. While U.S. companies chase permits and navigate patchwork state rules, KargoBot is quietly building a nationwide driverless logistics network on routes where human driver shortages already bite hard.",
  'image_url': None},
 {'id': 351,
  'headline': 'AI Agents Can Now Rewire Telecom Networks On Demand',
  'output': "Nokia and Google Cloud are letting AI agents directly control cellular networks through simple APIs. Over 75 telecom carriers have signed on to a system where a Google Gemini agent can verify your phone's location, boost video call quality, or reroute traffic without human intervention. Three network control APIs launched on Google Cloud Marketplace last July, covering tasks that previously required manual tickets and cross-team approvals. The pitch: your delivery app could automatically request priority network access for drivers in dead zones, or a security tool could detect SIM swaps in real time. Telecoms are betting they can sell network intelligence the way AWS sells compute.",
  'image_url': None},
 {'id': 352,
  'headline': 'Nvidia and AMD Back $500M Bet on Optical Chips',
  'output': "Ayar Labs just closed a $500 million Series E at a $3.75 billion valuation, with backing from both Nvidia and AMD. The company makes co-packaged optics, which replace electrical wiring inside data centers with light-based connections to move data faster between AI chips. The investor list reads like a who's who of AI infrastructure: ARK Invest, Sequoia, and Qatar's sovereign wealth fund all joined. That rivals are betting on the same underlying technology reveals something: the real AI bottleneck isn't smarter models but simply getting data between processors fast enough.",
  'image_url': None},
 {'id': 353,
  'headline': "China's State AI Fund Backs $362M Robot Round",
  'output': "Galbot just closed a $362 million round led by China's national AI fund, valuing the humanoid robot maker above $2.9 billion. It's now China's highest-valued unlisted robotics firm. The money will fund its embodied AI model and factory rollouts at clients like Toyota, Bosch, and battery giant CATL. Galbot has raised nearly $700 million in three months, all with heavy state and industrial backing. The company is eyeing a Hong Kong IPO next. Beijing is betting humanoid robots will staff Chinese factories before they reach American ones.",
  'image_url': None},
 {'id': 354,
  'headline': 'Telecom Giants Launch Blueprint to Run AI Like Utilities',
  'output': 'TM Forum, an alliance of 800+ telecom companies, unveiled three projects designed to move AI from experiment to everyday operations. The core idea: treat AI models like utilities you can turn on anywhere (cloud, edge, your own servers) without vendor lock-in. One project standardizes how to manage dozens of models at once. Another turns messy data silos into clean, governed data products that AI agents can safely tap. The third builds security guardrails for AI-to-AI conversations. The surprise? Telcos claim their blueprint could unlock hundreds of billions industrywide, making AI as boring and reliable as running a cell tower.',
  'image_url': None},
 {'id': 355,
  'headline': 'StorageChain Promises 80% Savings on Enterprise AI Search',
  'output': "StorageChain's new Bring Your Own Cloud tool lets companies run AI search across Amazon S3 and other storage platforms without moving data into a single vendor's system. The company claims 80% cost savings versus centralized setups from OpenAI, Amazon, or Google. Your files stay put. The AI layer sits on top, searching across whichever clouds you already use. It's a bet that enterprises care more about keeping data where it lives than picking the fanciest model host. The catch? Beyond S3, StorageChain hasn't named which other storage systems work yet.",
  'image_url': None},
 {'id': 356,
  'headline': 'Stripe Lets AI Startups Auto-Charge 30% Token Markups',
  'output': "Stripe just previewed a billing tool that automatically tacks a markup onto your AI app's token costs and passes the bill to customers. Set a 30% margin once, and the system tracks API prices across OpenAI, Anthropic, and Google, then invoices users for their usage plus your cut. It works with Stripe's new gateway or third-party ones like Vercel. The feature is waitlisted for now. For context, OpenRouter charges a flat 5.5% on token fees. The shift turns every ChatGPT call your app makes into a potential profit line, not just a cost to eat or bury in subscription tiers.",
  'image_url': None},
 {'id': 357,
  'headline': 'EY Launches AI Sales Platform After 78% Miss Quota',
  'output': "EY built an AI platform to fix a brutal problem: 78% of sellers missed their targets in 2025. The new tool, EY.ai Agentic for Sales, combines Snowflake's data with Canva's design automation to handle everything from finding prospects to writing proposals. It's targeting the one-fifth of a salesperson's day lost to admin work and toggling between systems. EY is testing it on itself first, rolling it out internally in North America this month before offering it to clients. The bet: companies will pay consultants to replace the dozen fragmented tools their sales teams already ignore.",
  'image_url': None},
 {'id': 358,
  'headline': 'Dialpad Resolves 70% of Support Requests Day One',
  'output': 'Dialpad rolled out tools that let customer service teams test AI agents before going live, avoiding the "build it and pray" phase that kills most chatbot projects. The company claims 70% of customer requests now get resolved on day one. Their new Proving Ground feature lets managers validate return on investment before full rollout by tracking resolution rates and customer satisfaction in real time. A healthcare customer already runs AI agents handling sensitive patient calls under governance controls. The pitch: stop launching AI pilots that flop after three months because no one measured whether they actually work.',
  'image_url': None},
 {'id': 359,
  'headline': 'OpenAI Cuts Hallucinations 27% in GPT-5.3 Update',
  'output': 'OpenAI\'s GPT-5.3 Instant, released today, makes fewer things up. High-stakes testing showed hallucinations dropped 27% when the model searches the web and 20% when it doesn\'t, compared to earlier versions. The update also stops littering answers with unnecessary warnings and caveats. It balances web results with its own reasoning instead of just parroting search results. The biggest shift: ChatGPT now gives you a straight answer instead of hedging with "I should mention" preambles. For anyone tired of fact-checking every AI response, this is the first meaningful trust upgrade in months.',
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': "**Image Prompt:**\n\nA sleek Chrome browser puzzle piece in Google's signature colors (red, yellow, green, blue) with a dramatic dark shadow cast behind it that forms the ominous silhouette of a hooded figure. The puzzle piece floats in stark white negative space, slightly fractured or separated at one edge. Editorial illustration style with bold, saturated colors and clean vector shapes. The",
#   'id': 334},
#  {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single glowing laptop with a gentle, ethereal trail of luminous particles or light flowing seamlessly from its screen into empty space, suggesting memory and continuity. The laptop is positioned at a three-quarter angle in deep purple or midnight blue, with the flowing light trail rendered in vibrant cyan and magenta gradient. The background is a solid, clean color',
#   'id': 335},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 295,
#   'headline': "Google's Gemini Now Cites Scientific Sources Directly",
#   'output': 'Google just rolled out Gemini 3.1 with a new Deep Think reasoning mode that pulls verified citations straight from scientific papers. The upgrade lets researchers skip the usual game of tracking down which study an AI actually paraphrased. Engineers and scientists on Google AI Ultra can now tackle complex problems with a model that shows its work. The update also includes Lyria 3 for 30-second music generation and higher-fidelity image tools. What changed: Gemini is moving from a chatbot that summarizes research to one that links you directly to the source, making it harder to pass off hallucinations as fact.',
#   'image_url': None},
#  {'id': 334,
#   'headline': "Malicious Extensions Could Hijack Chrome's Gemini Panel",
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': "**Image Prompt:**\n\nA sleek Chrome browser puzzle piece in Google's signature colors (red, yellow, green, blue) with a dramatic dark shadow cast behind it that forms the ominous silhouette of a hooded figure. The puzzle piece floats in stark white negative space, slightly fractured or separated at one edge. Editorial illustration style with bold, saturated colors and clean vector shapes. The",
  'id': 334},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single glowing laptop with a gentle, ethereal trail of luminous particles or light flowing seamlessly from its screen into empty space, suggesting memory and continuity. The laptop is positioned at a three-quarter angle in deep purple or midnight blue, with the flowing light trail rendered in vibrant cyan and magenta gradient. The background is a solid, clean color',
  'id': 335},
 {'final_output': '# Image Prompt\n\nA clean, minimalist editorial illustration in wide 16:9 format: A single clipboard with a simple patient form dissolves into floating digital particles or light fragments on one edge, symbolizing the transformation from paperwork to AI automation. The clipboard is centered against a bold two-tone background—perhaps a calming teal blue on one side fading to warm coral. The dissolving effect',
  'id': 336},
 {'final_output': "# Image Prompt\n\nA single smartphone floating at a slight angle in clean space, with a rough, poorly-lit sneaker photo visible on its glowing screen. From the phone's surface, the same sneaker emerges in three-dimensional form—polished, perfectly lit, and photorealistic—as if the device is transforming and projecting the object into premium quality. The emerging sneaker should appear",
  'id': 337},
 {'final_output': '# Image Prompt\n\nA striking editorial illustration of a single, sleek metallic AI neural node sphere floating in front of a bold, geometric Pentagon shield silhouette. The sphere has subtle circuit-like patterns glowing in electric blue, while the pentagon shield behind it is rendered in deep navy and crimson red gradients. Minimalist composition with dramatic negative space in clean off-white background. Modern, sophisticated',
  'id': 338},
 {'final_output': '# Image Prompt\n\nA sleek, oversized microchip floating in space, with a glowing neural network pattern radiating outward from its surface in vibrant electric blue and magenta gradients. The chip casts a strong shadow against a clean, mint-green backdrop. Minimalist editorial illustration style with bold, saturated colors and sharp geometric forms. Vast negative space surrounding the single chip emphas',
  'id': 339},
 {'final_output': '# Image Prompt\n\nA single giant telecommunications tower emerging from a glowing circuit board base, rendered in bold editorial illustration style. The tower is simplified and geometric, constructed from stacked AI neural network nodes (simple connected dots) instead of traditional metal lattice. The color palette is vibrant: deep electric blue tower against a warm coral/orange gradient sky. Minimalist composition with the tower positioned slightly off-center',
  'id': 340},
 {'final_output': '# Image Prompt\n\nA single glowing fiber optic cable strand suspended in space, splitting into two luminous beams that arc gracefully through deep blue negative space. The cable glows with intense green and amber laser light from within, creating a striking contrast against the minimal background. Ultra-clean editorial illustration style with bold, saturated colors. Dramatic lighting emphasizes the cable as the hero object. Modern,',
  'id': 341},
 {'final_output': '# Image Prompt\n\nA single industrial robot arm frozen mid-motion, suspended in empty space, with its hydraulic cables fraying and disconnecting into wisps of blue digital particles that dissolve into the void. The robot arm is rendered in cold metallic silver and deep navy blue against a warm terracotta/burnt orange background, creating stark contrast. The composition is minimal with the robot arm positioned in the lower',
  'id': 342},
 {'final_output': '# Image Prompt\n\nA single lightbulb floating in the center, half-illuminated in bright electric blue light, with a small sprouting plant growing inside the glass bulb. The background is a warm gradient from coral pink to soft cream, creating dramatic negative space. The lightbulb casts a subtle shadow below. Editorial illustration style with bold, saturated colors and clean vector aesthetic. Minim',
  'id': 343},
 {'final_output': '# Image Prompt\n\nA single smartphone floating in deep space, glowing softly from within, surrounded by elegant quantum wave patterns that spiral inward and compress into the device. The phone displays a subtle luminous screen. Color palette: deep cosmic purple background with electric blue and bright cyan quantum waves, warm amber glow from the phone. Ultra-minimal composition with the phone centered in the lower third, plenty of negative',
  'id': 344},
 {'final_output': '# Image Prompt\n\nA sleek desktop computer tower in deep metallic blue, standing upright with a glowing neural network pattern of bright cyan and magenta nodes pulsing from within its transparent side panel. The tower casts a sharp shadow against a warm coral gradient background. Minimalist, editorial illustration style with bold color blocking and dramatic lighting, emphasizing the fusion of traditional desktop computing with AI intelligence.',
  'id': 345},
 {'final_output': '# Image Prompt\n\nA single businessman in a suit standing waist-deep in a shallow pool of glowing blue liquid, frozen mid-step, briefcase in hand. The figure is rendered in a bold, flat editorial illustration style with a limited color palette of deep blues, warm oranges, and cream. The vast majority of the composition is empty negative space above—a gradient from pale cream to soft orange suggesting',
  'id': 346},
 {'final_output': '# Image Prompt\n\nA massive, gleaming server tower emerging from Spanish red clay earth, its metallic surface reflecting bold cobalt blue sky. The server is stylized as a single monolithic structure with subtle glowing orange circuit patterns, roots made of fiber optic cables spreading beneath the soil. The composition is vertical with the server occupying the center, surrounded by vast empty terracotta-colored ground and bright',
  'id': 347},
 {'final_output': '# Image Prompt\n\nA single sleek silver MacBook Air laptop shown from a three-quarter angle, floating against a vibrant electric blue background. A bold, glowing neural network pattern in neon magenta emanates from the keyboard area, visualizing AI processing power as elegant, luminous interconnected nodes that fade into the negative space above the device. Minimal shadows, clean editorial illustration style, dramatic lighting',
  'id': 348},
 {'final_output': '# Image Prompt\n\nA single sleek laptop computer sits centered in the frame, casting a dark, sprawling shadow beneath it that morphs into an abstract AI neural network pattern spreading outward. The shadow is disproportionately large and ominous compared to the laptop itself. Shot from a three-quarter overhead angle against a vibrant gradient background transitioning from electric blue to deep purple. The laptop is',
  'id': 349},
 {'final_output': '# Image Prompt\n\nA single sleek autonomous truck rendered in bold editorial illustration style, shown from a three-quarter front view on an empty highway that stretches into the horizon. The truck is depicted in deep metallic blue with glowing cyan sensor lines along its cab, emphasizing its driverless nature. The highway is minimal - just clean gray asphalt with a single yellow center line disappearing into a',
  'id': 350},
 {'final_output': '# Image Prompt\n\nA striking editorial illustration of a single glowing neural network brain made of fiber optic cables, suspended in clean space, with translucent streams of light data flowing through its pathways. The brain\'s "neurons" are represented by connection nodes where fiber optic strands intersect, pulsing with light. Color palette: electric blue fiber optics against deep midnight blue background with accent highlights',
  'id': 351},
 {'final_output': '**Image Prompt:**\n\nA single glowing fiber optic cable flowing in an elegant S-curve against a deep navy blue background, with light particles streaming through it in vibrant electric blue and amber gold. The cable has a sleek, modern appearance with a glass-like translucent quality, emitting a soft luminous glow. Minimalist composition with the cable positioned in the lower two-thirds',
  'id': 352},
 {'final_output': "# Image Prompt\n\nA single sleek humanoid robot figure standing in a confident pose, rendered in a bold editorial illustration style. The robot should have a minimalist, modern design with smooth surfaces. Color palette: deep crimson red for the robot body against a clean pale blue or white background. The robot's form should suggest both industrial capability and advanced AI, with subtle geometric details. Extreme negative space around the",
  'id': 353},
 {'final_output': '# Image Prompt\n\nA single oversized utility power switch mounted on a clean wall, styled in bold editorial illustration. The switch plate is colored in vibrant telecommunication blue, with the toggle itself in bright coral or orange, positioned in the "ON" position. A simple glowing AI circuit pattern or neural network icon subtly emanates from behind the switch, suggesting AI power being activated. Minimalist composition with',
  'id': 354},
 {'final_output': '# Image Prompt\n\nA minimalist editorial illustration of a single large translucent cloud with a glowing magnifying glass hovering above it, all rendered in bold gradients of electric blue and coral orange. The cloud should be semi-transparent showing abstract data dots or particles floating inside. Clean composition with generous white negative space around the elements. Modern, geometric style with smooth gradients and soft shadows. The magnifying',
  'id': 355},
 {'final_output': '# Image Prompt\n\nA sleek, oversized price tag floating in the center against a bold gradient background of electric blue to deep purple. The tag is clean and modern, colored in vibrant coral or hot pink. A single golden percentage symbol (%) is prominently displayed on the tag. Minimalist, editorial illustration style with sharp shadows and dramatic lighting. Plenty of negative space around the tag. 16',
  'id': 356},
 {'final_output': '# Image Prompt\n\nA single glowing robotic arm emerging from a sea of calm blue negative space, reaching toward and holding a gleaming golden sales target bullseye. The robotic arm is sleek, modern, and constructed from bright white and electric blue segments with subtle circuit-like details. The target is a simple concentric circle design in metallic gold that catches dramatic light. The composition is minimal and',
  'id': 357},
 {'final_output': '**Image Prompt:**\n\nA single, oversized vintage telephone handset floating in negative space, with its coiled cord forming a simple checkmark shape below it. The handset is rendered in a bold, warm coral color against a clean, minimal background of soft cream. The checkmark cord is in deep navy blue. Editorial illustration style with subtle texture, clean geometric forms, and dramatic scale. The composition is asym',
  'id': 358},
 {'final_output': '# Image Prompt\n\nA single sleek robot head in profile, rendered in bold editorial illustration style, with one small Band-Aid or patch placed cleanly on its temple area. The robot should be minimal and geometric, depicted in confident navy blue and white against a vibrant coral or warm orange background. The Band-Aid is a simple beige/tan accent. Clean, spacious composition with the robot head占',
  'id': 359}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 with open(file_name, "rb") as f:
#       3     image_bytes = f.read()
# ----> 5 supabase.storage.from_("article-image").upload(
#       6     "52.png",
#       7     image_bytes,
#       8     file_options={"content-type": "image/png"}
#       9 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/storage3/_sync/file_api.py:578, in SyncBucketActionsMixin.upload(self, path, file, file_options)
#     564 """
#     565 Uploads a file to an existing bucket.
#     566
#    (...)
#     575     HTTP headers.
#     576 """
#     577 path_parts = relative_path_to_parts(path)
# --> 578 return self._upload_or_update("POST", path_parts, file, file_options)
#
# ...

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
