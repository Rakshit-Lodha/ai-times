# %%
from openai import OpenAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os

# %%
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
from supabase import create_client, Client

# %%
supabase_url = os.environ.get("SUPABASE_URL")

# %%
supabase_api_key = os.environ.get("SUPBASE_KEY")

# %%
supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
import base64

# %%
import anthropic

# %%
client_anthropic = anthropic.Anthropic(api_key = os.getenv('CLAUDE_API_KEY'))

# %%
def claude_image_builder(image_prompt_builder):
    final_news_article = []
    for i in image_prompt_builder:
        response = client_anthropic.messages.create(
            model = "claude-sonnet-4-5",
            max_tokens = 85,
            messages = [{
                "role": "user",
                "content":  f"""
                You are an art director for a modern digital news platform.
                Given a news story, generate an image prompt that:
                - Depicts ONE single visual concept that represents the story
                - Maximum 2-3 objects in the entire image
                - Clean, minimal composition with plenty of negative space
                - No charts, no numbers, no percentages, no data visualizations
                - No split compositions or multiple scenes
                - Think "magazine cover" not "infographic"
                - Uses editorial illustration style with bold colors
                - Wide 16:9 format for mobile card thumbnail
                
                Story headline: {i['headline']}
                Story summary: {i['output']}
            """
            }]
        )

        final_output = response.content[0].text

        final_image_dictionary = {
            'final_output': final_output,
            'id': i['id']
        }

        final_news_article.append(final_image_dictionary)

    return final_news_article

# %%
a = [{'id': 265,
  'headline': 'Claude Opus 4.6 Now Remembers 1M Tokens of Context',
  'output': 'Anthropic just released Claude Opus 4.6 with a 1 million token context window, meaning it can hold roughly 750,000 words in memory at once. That\'s enough to track an entire quarter\'s worth of Slack threads while writing code. The new model introduces "adaptive thinking" with four effort levels and lets AI agents form teams to tackle multi-step projects without constant supervision. It\'s live today on the API and consumer site, though deeper thinking modes cost more and run slower. The real shift: AI that can finally keep up with how messy and long-running real work actually is.',
  'image_url': None},
 {'id': 266,
  'headline': 'McKinsey: 75% of Corporate Jobs Will Need Reshaping for AI',
  'output': 'McKinsey surveyed 10,000 executives across 15 countries and found companies are creating entirely new job categories to work alongside AI agents: "agent orchestrators" who manage AI workflows, "hybrid managers" who oversee mixed human-AI teams, and "AI coaches." Three-quarters of current roles will need new skill combinations. The consulting giant argues companies can\'t just bolt AI onto existing processes. Instead, they need complete redesigns that assume AI handles routine work while humans focus on judgment calls and creativity. The subtext? Your org chart probably looks nothing like it will in two years.',
  'image_url': None},
 {'id': 267,
  'headline': 'AI Accounting Startup Hits $1.15B in 18 Months',
  'output': "Basis, a New York startup that automates accounting work with AI agents, just raised $100 million at a $1.15 billion valuation. The company was founded in 2023, which means it crossed the unicorn threshold faster than almost any fintech in recent memory. Accel led the Series B with backing from GV, Khosla Ventures, and former Goldman CEO Lloyd Blankfein. The money will go toward building out engineering and machine-learning teams. Investors are betting that accounting firms would rather rent AI agents than hire junior associates to reconcile ledgers and chase invoices. If they're right, the Big Four's talent model just got a lot more fragile.",
  'image_url': None},
 {'id': 268,
  'headline': "Notion's New Agents Run on Autopilot Until You Run Out of Credits",
  'output': "Notion just launched Custom Agents that work around the clock without prompting, automating status updates, triage, and Q&A across Slack, Linear, Figma, and other connected tools. The catch: they run on a consumption-based credit model with no rollover, so a helpful bot could quietly burn through your monthly budget by Tuesday. Admins get full logging and kill switches, but teams need to track spending per agent or risk surprise bills. It's free through May 3, then you're buying credits in monthly blocks. The new worry isn't whether AI can handle your busywork—it's whether you budgeted enough tokens for it.",
  'image_url': None},
 {'id': 269,
  'headline': '300,000 ChatGPT Credentials Stolen as AI Speeds Up Hacking',
  'output': "IBM's 2026 threat report reveals hackers stole over 300,000 ChatGPT credentials last year, treating AI tools like any other corporate software to breach. Attacks starting with public-facing apps jumped 44%, partly because AI helps attackers find security holes faster. Ransomware groups grew 49% as vulnerability hunting became the leading cause of breaches. The twist: companies are locking down their cloud apps but leaving AI platforms wide open with weak logins. The arms race is now symmetric: both sides are using AI to move faster, and whoever automates authentication wins.",
  'image_url': None},
 {'id': 270,
  'headline': 'AI Chip Startup MatX Raises $500M to Challenge Nvidia',
  'output': "MatX just closed a $500 million Series B led by quant giant Jane Street and Situational Awareness LP to build a chip that promises dramatically faster performance for training large language models. The startup is betting it can crack Nvidia's stranglehold on AI hardware with its MatX One chip, set to ship in 2027 via TSMC manufacturing. Bloomberg reports the round values MatX at multiple billions, though the company isn't disclosing exact numbers. Backers include Stripe's Collison brothers and chipmaker Marvell. The investor lineup suggests serious conviction that someone will finally unseat Nvidia in the AI compute race.",
  'image_url': None},
 {'id': 271,
  'headline': "Nvidia's Rubin Cuts AI Inference Costs 10x vs Blackwell",
  'output': 'Nvidia unveiled Rubin at CES 2026, a new rack-scale computing platform that slashes inference token costs by up to 10x compared to its current Blackwell chips. The system also trains huge mixture-of-experts models using roughly 75% fewer GPUs. AWS, Google Cloud, and Microsoft will start rolling out Rubin-based servers in late 2026. The surprise: Nvidia is now selling entire racks, not just chips, bundling six custom components into one supercomputer-sized package. If the cost savings hold, running ChatGPT-scale models could become cheap enough that every company tries it.',
  'image_url': None},
 {'id': 272,
  'headline': 'Canva Buys Motion Design Tool and AI Ad Optimizer',
  'output': "Canva just bought two companies to close the gap between making a design and seeing it perform. Cavalry brings 2D motion graphics into Canva's professional suite, so you can animate without switching tools. MangoAI adds AI that tweaks video ads in real time based on performance, feeding directly into Canva Grow. The goal: turn Canva from a place you design things into a place you design, animate, and measure them all at once. With 265 million users and $4 billion in revenue, Canva is betting the future of creative work isn't just faster templates but tighter loops between creation and results.",
  'image_url': None},
 {'id': 273,
  'headline': 'Self-Driving Startup Hits $8.6B Without a Single Map',
  'output': "Wayve closed $1.2 billion at an $8.6 billion valuation, with Uber kicking in another $300 million tied to hitting robotaxi milestones. The bet? That AI can teach cars to drive anywhere without those absurdly detailed HD maps most competitors rely on. Wayve claims it's already driven in over 500 cities across three continents this year alone, learning on the fly. Backers include NVIDIA, Microsoft, and three major automakers who'll license the tech for consumer cars starting in 2027. London gets robotaxis next year. The money signals a industry shift: investors think generalized AI beats hand-coded routes city by city.",
  'image_url': None},
 {'id': 274,
  'headline': 'Samsung Embeds Gemini and Perplexity Inside Galaxy S26',
  'output': "Samsung's Galaxy S26, available March 11, lets you pick between Gemini and Perplexity as built-in agents that handle multi-step tasks across apps with a single prompt. Ask it to organize photos, create a calendar event, and set a reminder, and it happens in the background without opening each app manually.\n\nThe bet: you'll trust an AI assistant more if you can choose which one powers your phone. Samsung is building an open ecosystem where multiple agents coexist, rather than locking users into a single voice. If it works, your phone becomes less about tapping icons and more about stating intent.",
  'image_url': None},
 {'id': 275,
  'headline': 'BlackRock Bets $250M on European Edge-AI Chips',
  'output': "Axelera AI just closed one of Europe's largest AI chip raises, pulling in more than $250 million with BlackRock joining as a new investor. The money will scale production of the company's Europa edge-AI accelerator, set to ship before June. Founded in 2021, Axelera has now raised over $450 million. The real signal? A Wall Street giant is betting on European semiconductor startups to challenge the chip industry's Asia-heavy manufacturing status quo. Edge chips process AI locally on devices rather than in the cloud, promising faster responses and lower costs. Europe finally has hardware money to match its AI ambitions.",
  'image_url': None},
 {'id': 276,
  'headline': 'Figma Now Pulls Claude Code Prototypes Onto the Canvas',
  'output': 'Figma just added a feature that lets you grab web pages and flows you built in Claude Code and drop them straight into Figma as editable frames. No more screenshots or manual rebuilds. The update also includes a pre-configured Notion integration that auto-documents meetings and turns docs into FigJam diagrams, plus new governance controls that let admins lock AI traffic to Figma\'s AWS environment. Six new connectors (Amplitude, Box, Dovetail, Granola, Marvin, zeroheight) round out the release. The gap between "I coded this" and "now let\'s design it" just got a lot smaller.',
  'image_url': None},
 {'id': 277,
  'headline': 'SolveAI Raises Two Rounds in One (Amount Unconfirmed)',
  'output': "London-based SolveAI jumped from pre-seed to Series A without pausing for breath, pulling in back-to-back rounds from Accel and GV. The company won't confirm reports pegging total funding at $50 million. Founded by ex-Palantir engineer Steve Basher, SolveAI promises to turn plain-English requests into working enterprise software that plugs straight into corporate IT systems. The dual-round structure suggests investors believe the market for no-code tools is moving too fast to wait for traditional milestones. Strategic angels from DeepMind and other AI labs hint that the tech goes deeper than a wrapper around GPT-4. Skipping Series A milestones is becoming the new Series A milestone.",
  'image_url': None},
 {'id': 278,
  'headline': "Adobe's Firefly Now Edits Your Raw Footage for You",
  'output': 'Adobe just released Quick Cut, a beta feature that watches your uploaded clips and assembles a first-draft edit automatically. You describe the video in plain English, pick an aspect ratio and pacing, and Firefly stitches together scenes using automatic shot selection and audio analysis. The tool is built for anyone who dreads staring at hours of raw footage: product reviewers, podcasters, marketers. You still refine the final cut, but the soul-crushing "where do I even start?" phase disappears. The real story? Adobe is betting that video editing\'s new bottleneck isn\'t fancy effects but simply getting to a watchable rough cut fast enough to iterate.',
  'image_url': None},
 {'id': 279,
  'headline': "Atlassian's Rovo Now Pulls Live Figma Designs Into Jira",
  'output': "Atlassian just turned Rovo into a plug-and-play connector for apps like Figma, GitHub, and Intercom. The new MCP Gallery lets its AI agents pull live dashboards, update tickets, or draft launch briefs without custom code. One example: marketers can yank Figma designs, Amplitude metrics, and customer feedback into a single Confluence page. Canva's agent can then spin up social posts and blog drafts from that brief. The connector catalog hit 20 partners by December 2025 and now works with ChatGPT, Claude, and AWS tools. Atlassian is betting that switching between tabs is finally becoming optional.",
  'image_url': None}]

# %%
claude_image_builder(a)
# Out:
# [{'final_output': '# Image Prompt\n\nA single oversized human brain rendered in a bold, editorial illustration style, with its surface texture transformed into neatly organized filing folders or accordion-style document stacks that appear to be expanding outward. The brain is depicted in vibrant coral pink against a clean, minimal background of soft cream or pale blue. One or two small, simplified document icons or paper sheets float near the brain,',
#   'id': 265},
#  {'final_output': '# Image Prompt\n\nA sleek business suit jacket hanging on a minimalist coat hanger, but the jacket is fragmenting into geometric polygons and wireframe pieces that float away and reassemble into a new, different form. The jacket on the left is traditional navy blue, while the fragmenting pieces transition to electric blue and coral pink as they reshape. Clean white background with dramatic shadows. The transformation captures mid-',
#   'id': 266},
# ...

# %%
result = supabase.table('hundred_word_articles')\
    .select('id','headline','output','image_url')\
.is_('image_url','null')\
    .order('created_at', desc=False)\
    .execute()

result.data
# Out:
# [{'id': 265,
#   'headline': 'Claude Opus 4.6 Now Remembers 1M Tokens of Context',
#   'output': 'Anthropic just released Claude Opus 4.6 with a 1 million token context window, meaning it can hold roughly 750,000 words in memory at once. That\'s enough to track an entire quarter\'s worth of Slack threads while writing code. The new model introduces "adaptive thinking" with four effort levels and lets AI agents form teams to tackle multi-step projects without constant supervision. It\'s live today on the API and consumer site, though deeper thinking modes cost more and run slower. The real shift: AI that can finally keep up with how messy and long-running real work actually is.',
#   'image_url': None},
#  {'id': 266,
#   'headline': 'McKinsey: 75% of Corporate Jobs Will Need Reshaping for AI',
# ...

# %%
public_urls_5 = []

# %%
prompt = [{'final_output': '# Image Prompt\n\nA single oversized human brain rendered in a bold, editorial illustration style, with its surface texture transformed into neatly organized filing folders or accordion-style document stacks that appear to be expanding outward. The brain is depicted in vibrant coral pink against a clean, minimal background of soft cream or pale blue. One or two small, simplified document icons or paper sheets float near the brain,',
  'id': 265},
 {'final_output': '# Image Prompt\n\nA sleek business suit jacket hanging on a minimalist coat hanger, but the jacket is fragmenting into geometric polygons and wireframe pieces that float away and reassemble into a new, different form. The jacket on the left is traditional navy blue, while the fragmenting pieces transition to electric blue and coral pink as they reshape. Clean white background with dramatic shadows. The transformation captures mid-',
  'id': 266},
 {'final_output': '# Image Prompt\n\nA sleek, anthropomorphic robot arm in metallic silver holding a single gleaming gold coin, photographed against a vibrant gradient background of deep navy blue to electric teal. The robot arm emerges from the bottom right corner, fingers delicately pinching the coin which catches dramatic side lighting. Minimalist composition with the coin positioned in the upper left third, creating dynamic negative',
  'id': 267},
 {'final_output': "# Image Prompt\n\nA sleek robotic arm or mechanical hand suspended in mid-air, holding a single glowing credit card that's visibly disintegrating into digital particles or fading away at the edges. The robot arm is modern and minimalist in design, rendered in cool grays and blues. The credit card emits a soft cyan or electric blue glow as it dissolves. Set against a",
  'id': 268},
 {'final_output': '# Image Prompt\n\nA single sleek chatbot icon or speech bubble being pierced by a sharp digital key or lock pick, suspended in dramatic lighting against a bold two-tone background (electric blue and deep crimson). The chatbot symbol shows visible cracks or fracture lines spreading from the penetration point. Minimalist editorial illustration style with strong shadows, maximum negative space, sharp geometric forms. The composition',
  'id': 269},
 {'final_output': '# Image Prompt\n\nA single, oversized microchip floating in bold crimson red against a clean gradient background transitioning from deep navy to electric blue. The chip casts a sharp, dramatic shadow below it, emphasizing its monumentality. The chip design is sleek and geometric with visible circuit patterns rendered in metallic gold. Minimalist, editorial illustration style with strong contrast and plenty of negative space around',
  'id': 270},
 {'final_output': '# Image Prompt\n\nA single, oversized emerald-green GPU chip standing vertically like a monolith, with a dramatic downward-pointing arrow slicing through its center. The chip has subtle circuit board patterns etched on its surface. The arrow is bold and geometric in bright magenta. The composition is centered against a deep navy blue background with generous negative space around the edges. Editorial illustration style with',
  'id': 271},
 {'final_output': '# Image Prompt\n\nA single oversized purple paintbrush transforming into a glowing lightning bolt as it sweeps across the frame, leaving animated sparkles and motion trails in its wake. The paintbrush handle is solid and tactile in deep purple, while the bristle-end dissolves into electric neon green and cyan energy representing motion and AI. Set against a warm peachy-pink gradient background',
  'id': 272},
 {'final_output': '# Image Prompt\n\nA single autonomous car floating or driving on an ethereal, glowing blue neural network path that emerges from darkness, disappearing into fog ahead. The car is sleek and modern, shown from a three-quarter front angle. The neural network pathway beneath it is abstract - just a few luminous interconnected nodes and lines suggesting AI learning rather than a traditional map. Deep navy blue background with',
  'id': 273},
 {'final_output': '# Image Prompt\n\nA modern smartphone shown from a straight-on view, floating in clean space with its screen displaying a simple glowing conversation bubble or command interface. Emerging from the top of the phone are two distinct, abstract geometric shapes—one representing each AI assistant—rendered as bold, colorful floating forms (perhaps a sphere and a cube) that appear to be offering themselves as choices. Use a bold three',
  'id': 274},
 {'final_output': '# Image Prompt\n\nA sleek, metallic microchip positioned at the center, rendered in bold cobalt blue and silver tones, with geometric circuit pathways that fade into the background. A single golden compass needle overlays or points toward the chip, symbolizing investment direction and navigation. Clean gradient background transitioning from deep navy to electric blue. Dramatic side lighting creates sharp shadows. Ultra-minimal composition',
  'id': 275},
 {'final_output': '# Image Prompt\n\nA single lightning bolt bridge connecting two floating geometric shapes — a code bracket symbol "{}" on one side and a design artboard frame "□" on the other — suspended in clean negative space. Bold duotone color palette of electric blue and coral pink against a soft cream background. The lightning bolt is stylized and angular, suggesting instant connection and energy transfer. Minimal, flat illustration style with',
  'id': 276},
 {'final_output': '# Image Prompt\n\nA single rocket ship in mid-flight, dramatically skipping across the surface of a calm body of water like a stone, creating two distinct expanding ripple circles behind it. The rocket is sleek and modern, rendered in bold navy blue. The ripples are rendered as clean, concentric circles in bright turquoise against a soft mint green water surface. The background is a clean gradient sky',
  'id': 277},
 {'final_output': "# Image Prompt\n\nA single pair of oversized scissors cutting through a flowing strip of film reel in mid-air, suspended against a vibrant gradient background of Adobe's signature blues and magentas. The film strip curves dynamically through the frame, showing just a few visible sprocket holes catching the light. The scissors are sleek and modern, rendered in a bold editorial illustration style with clean geometric shapes.",
  'id': 278},
 {'final_output': '# Image Prompt\n\nA sleek editorial illustration in wide 16:9 format showing a large glowing purple puzzle piece connecting with a bright blue puzzle piece against a clean gradient background. The connection point emits a subtle burst of light, symbolizing seamless integration. Minimalist composition with the puzzle pieces floating in negative space, rendered in a modern flat design style with bold, vibrant colors (Atl',
  'id': 279}]

# %%
def image_result(image_input):
    for i in image_input:
        image_result = client.images.generate(
            model = "gpt-image-1-mini",
            prompt = i['final_output'],
            size = "1536x1024"
        )

        image_base64 = image_result.data[0].b64_json
        image_bytes = base64.b64decode(image_base64)

        file_name = f"{i['id']}.png"

        supabase.storage.from_("article-image").upload(
            file_name,
            image_bytes,
            file_options = {"content-type": "image/png"}
        )

        public_url = supabase.storage.from_("article-image").get_public_url(file_name)
        

        final_dict = {
            'public_url': public_url,
            'id': i['id']
        }

        upload_to_supabase(final_dict)
        print(f"✅ Saved")

# %%
image_result(prompt)
# Out:
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved
# ✅ Saved

# %%
a = []
for i in public_urls_5:
    if i['id']>=191:
        a.append(i)
a
# Out:
# [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/191.png',
#   'id': 191},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/192.png',
#   'id': 192},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/193.png',
#   'id': 193},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/194.png',
#   'id': 194},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/195.png',
#   'id': 195},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/196.png',
#   'id': 196},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/197.png',
#   'id': 197},
#  {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/198.png',
#   'id': 198},
# ...

# %%
public_urls_6 = [{'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/146.png',
  'id': 146},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/147.png',
  'id': 147},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/148.png',
  'id': 148},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/149.png',
  'id': 149},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/150.png',
  'id': 150},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/151.png',
  'id': 151},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/152.png',
  'id': 152},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/153.png',
  'id': 153},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/154.png',
  'id': 154},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/155.png',
  'id': 155},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/156.png',
  'id': 156},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/157.png',
  'id': 157},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/158.png',
  'id': 158},
 {'public_url': 'https://wbssuitpowuljcvazlnd.supabase.co/storage/v1/object/public/article-image/159.png',
  'id': 159}]

# %%
upload_to_supabase(a)

# %%
def upload_to_supabase(dictionary):
    supabase.table("hundred_word_articles").update(
        {"image_url": dictionary['public_url']}
    ).eq("id", dictionary['id']).execute()

# %%
file_name = "/Users/Rakshit.Lodha/Desktop/ai-times/52"
with open(file_name, "rb") as f:
    image_bytes = f.read()

supabase.storage.from_("article-image").upload(
    "52.png",
    image_bytes,
    file_options={"content-type": "image/png"}
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 5
#       2 with open(file_name, "rb") as f:
#       3     image_bytes = f.read()
# ----> 5 supabase.storage.from_("article-image").upload(
#       6     "52.png",
#       7     image_bytes,
#       8     file_options={"content-type": "image/png"}
#       9 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/storage3/_sync/file_api.py:578, in SyncBucketActionsMixin.upload(self, path, file, file_options)
#     564 """
#     565 Uploads a file to an existing bucket.
#     566
#    (...)
#     575     HTTP headers.
#     576 """
#     577 path_parts = relative_path_to_parts(path)
# --> 578 return self._upload_or_update("POST", path_parts, file, file_options)
#
# ...

# %%
public_url = supabase.storage.from_("article-image").get_public_url("52.png")

supabase.table("hundred_word_articles").update(
    {"image_url": public_url}
).eq("id", 52).execute()
# Out:
# APIResponse(data=[{'id': 52, 'event_id': '364_2026-02-10', 'model_provider': 'claude', 'news_date': '2026-02-10', 'output': 'NIST just handed $3.19 million to eight U.S. small businesses spanning AI, quantum computing, biotech, and semiconductors. The Phase II SBIR awards fund 24 months of R&D prototyping across innovations like quantum photon chips, AI-powered biopharmaceutical monitoring, wearable PFAS detectors, and cybersecurity scoring tools for hardware makers. Projects range from magnetic electron microscope upgrades to sensor-free home energy optimization.\n\nThese awards signal a federal push to commercialize cutting-edge tech through small players, potentially accelerating breakthroughs in quantum networks, medical imaging, and industrial AI compliance.', 'sources': '[{"name": "nist.gov", "url": "https://www.nist.gov/news-events/news/2026/02/nist-awards-over-3-million-small-businesses-advancing-ai-biotechnology"}]', 'created_at': '2026-02-12T05:09:50.090269+00:00', 'headlin
# ...

# %%
a = [2, 53, 46, 47, 48, 49, 50, 54]
for i in a:
    file_name = f"/Users/Rakshit.Lodha/Desktop/ai-times/{i}"
    with open(file_name, "rb") as f:
        image_bytes = f.read()

        supabase.storage.from_("article-image").upload(
            f"{i}.png",
            image_bytes,
            file_options={"content-type": "image/png"}
        )

    public_url = supabase.storage.from_("article-image").get_public_url(f"{i}.png")

    supabase.table("hundred_word_articles").update(
        {"image_url": public_url}
    ).eq("id", i).execute()
