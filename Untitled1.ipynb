# %%
from dotenv import load_dotenv
load_dotenv()
import os
from supabase import create_client, Client
supabase_url = os.environ.get("SUPABASE_URL")
supabase_api_key = os.environ.get("SUPBASE_KEY")

supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
from openai import OpenAI
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
def report_research(date, next_date):
    result = supabase.table('curation_selected_items')\
        .select('event_id, output,sources, news_date','topic')\
    .gte('created_at', date)\
    .lt('created_at', next_date)\
    .eq('topic', 'Report')\
        .order('created_at', desc=False)\
        .execute()
    
    return result.data

# %%
report_deep_dive = report_research('2026-02-23', '2026-02-24')

# %%
report_deep_dive
# Out:
# [{'event_id': '1357_2026-02-21',
#   'output': "Official publication of the AI Impact Summit (New Delhi) Declaration on the Government of India (Ministry of External Affairs) website. The declaration (dated/published 21 Feb 2026) describes seven 'Chakras' (pillars) and frames outputs (e.g., Trusted AI Commons, Global AI Impact Commons, Charter for Democratic Diffusion of AI) as voluntary, non‑binding measures. The page includes an authoritative list of endorsing countries/international organisations (88 entries) and underscores voluntary, non‑binding cooperation rather than legally binding safety commitments.",
#   'sources': [{'url': 'https://www.mea.gov.in/bilateral-documents.htm?dtl/40809',
#     'name': 'India Ministry of External Affairs'}],
#   'news_date': '2026-02-21',
#   'topic': 'Report'},
#  {'event_id': '1353_2026-02-22',
#   'output': "Google AI 'Progress Report' / responsibility update (Feb 2026) describing Google's multi-layered approach to responsible AI governance and focusing on agentic/frontier risks — relevant to corporate governance and policy signals from a major lab (pdf on ai.google).",
#   'sources': [{'url': 'https://ai.google/static/documents/ai-responsibility-update-2026.pdf',
#     'name': 'Google AI'}],
#   'news_date': '2026-02-22',
#   'topic': 'Report'}]

# %%
def openai_research_workflow(research_input):
    for i in research_input:
        response = client.responses.create(
            model = "gpt-5-nano",
            tools = [{
                "type": "web_search"
            }],
            include = ["web_search_call.action.sources"],
            input = f"""
            You are a senior research analyst for Krux.

            TASK:
              Create a deep, fact-checked brief for ONE AI report/paper/benchmark release.
            
            GOAL:
              Extract the highest-value findings and implementation guidance so a later 100-word summary can capture most practical signal.
            
            OUTPUT FORMAT:
              - 12 to 16 bullet points.
              - Each bullet must include inline citations:
                [Source: <publisher>, <url>]
              - No text before or after bullets.
            
            MANDATORY STRUCTURE:
              1) REPORT SNAPSHOT
              - What was published, by whom, and when.
              - Scope: geography, sectors, sample size, time window, method type.
            
              2) CORE FINDINGS (MOST IMPORTANT)
              - 4 to 6 bullets with the strongest quantified findings.
              - Include exact numbers, not vague language.
            
              3) WHAT THIS ACTUALLY MEANS
              - 2 to 3 bullets translating findings into plain English implications for real teams.
            
              4) IMPLEMENTATION PLAYBOOK
              - 3 to 4 bullets: what organizations should do in the next quarter.
              - Include sequencing (e.g., data readiness -> pilot -> measurement -> rollout).
            
              5) METRICS TO TRACK
              - 1 or 2 bullets on KPIs teams should monitor to apply the report in practice.
            
              6) LIMITATIONS / CAVEATS
              - 1 or 2 bullets on methodology limits, sample bias, missing data, or uncertainty.
            
              7) DECISION TAKEAWAY
              - 1 bullet: “If a team only does one thing based on this report, it should be X.”
            
              STRICT RULES:
              - No hype, no opinion, no generic AI commentary.
              - Every factual claim must be source-backed.
              - If a key detail is missing, write: "Not disclosed in cited sources."
              - Prefer primary sources (original report/paper) over secondary articles.
              - If secondary coverage conflicts with primary report, prioritize primary and note conflict.
            
              QUALITY CHECK:
              - Must contain quantified findings.
              - Must contain actionable implementation steps.
              - Must clearly separate findings from interpretation.
              - Must include limitations.
            
              Report/event to research:
              Report summary: {i['output']}
              Source: {i['sources']}
            """,
        )

        output = response.output_text
        print(output)

        final_dictionary = {
            'event_id': i['event_id'],
            'news_date': i['news_date'],
            'output': output,
            'model_provider': 'openai',
            'topic': i['topic']
        }
        print(final_dictionary)

        save_research(final_dictionary)

        print("✅ Done")

# %%
openai_research_workflow(report_deep_dive)
# Out:
# - REPORT SNAPSHOT 1: Official publication of the AI Impact Summit Declaration produced in the context of the India AI Impact Summit held in New Delhi (Feb 16–21, 2026); formal release on Feb 21, 2026. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - REPORT SNAPSHOT 2: Scope includes a global set of participants from more than 85 countries and international organizations; pillars span health, education, agriculture, climate, public services, and other sectors; time window Feb 16–21, 2026; approach is a voluntary, non-binding governance framework rather than a treaty. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - REPORT SNAPSHOT 3: Endorsers total 88 signatories as of Feb 21, 2026, including major powers (US, EU, China) and a mix of larger and smaller nations. [Source: The Times of India, https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms] ([timesofindia.indiatimes.com](https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms))
#
# - REPORT SNAPSHOT 4: The declaration is framed as voluntary and non-binding, with no enforceable safety commitments; sovereignty and national policy considerations are explicitly acknowledged. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (MOST IMPORTANT) 1: The Declaration is organized around seven Chakras (pillars): human capital development; social empowerment; trust and security; energy efficiency; AI for science; democratisation of AI resources; and use of AI for economic growth and social good. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (MOST IMPORTANT) 2: Outputs highlighted include the Global AI Impact Commons, the Charter for Democratic Diffusion of AI, the Trusted AI Commons, the International Network of AI for Science Institutions, and the AI Workforce Development Playbook. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (MOST IMPORTANT) 3: The declaration emphasizes industry-led voluntary measures and technical safeguards as part of a broader governance approach, rather than prescriptive binding rules. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (MOST IMPORTANT) 4: The initiative foregrounds energy efficiency and affordable access to AI infrastructure, including open-source approaches and diffusion of foundational AI resources. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (MOST IMPORTANT) 5: The seven Pillars and associated platforms aim to spur cross-border collaboration, knowledge-sharing, and scalable AI applications across healthcare, agriculture, education, climate resilience, and public services. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - WHAT THIS ACTUALLY MEANS 1: For practitioner teams, this signals a non-binding, international governance frame you can align with to access shared AI resources and collaborative initiatives without committing to legal obligations. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - IMPLEMENTATION PLAYBOOK 1: In the next quarter, map your existing AI governance to the seven Chakras to identify gaps and prioritize 1–2 Pillars for initial internal pilots. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - IMPLEMENTATION PLAYBOOK 2: Define sequencing: data readiness -> pilot -> measurement -> rollout, with pilot success criteria tied to at least one Chakra and one output (e.g., use of Global AI Impact Commons). [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - IMPLEMENTATION PLAYBOOK 3: Establish partnerships or memberships in the Global AI Impact Commons and pilot the Charter for Democratic Diffusion of AI principles to increase access to compute/datasets. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - METRICS TO TRACK 1: Monitor uptake of the seven Chakras across internal AI governance documents and track usage/participation in the Global AI Impact Commons where applicable. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - LIMITATIONS / CAVEATS 1: The framework is voluntary and non-binding; its value depends on the willingness of signatories to adopt and operationalize the pillars, which may vary by country and sector. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - DECISION TAKEAWAY 1: If a team can implement only one thing from this report, prioritize aligning governance with the seven Chakras and pursuing participation in the Global AI Impact Commons to access shared AI resources. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - REPORT SNAPSHOT (ADDITIONAL CONTEXT) 5: The final Delhi Declaration text explicitly frames outputs (e.g., Trusted AI Commons, Global AI Impact Commons) as voluntary tools to diffuse AI responsibly, not as binding safety commitments. [Source: The Times of India, https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms] ([timesofindia.indiatimes.com](https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms))
#
# - REPORT SNAPSHOT (ADDITIONAL CONTEXT) 6: The event backdrop shows leadership sessions on Feb 18–19, with the declaration formally released on Feb 21, 2026, and the summit spanned Feb 16–21, 2026. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - CORE FINDINGS (ADDITIONAL CONTEXT) 6: The seven Pillars explicitly named by the discourse include “democratisation of AI resources” and “AI for science,” underscoring a cross-cutting agenda from capability access to research collaboration. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - IMPLEMENTATION PLAYBOOK (ADDITIONAL CONTEXT) 4: The playbook concept and platform references are part of the declaration’s outputs and are intended to be voluntary channels for knowledge and resource diffusion across borders. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))
#
# - LIMITATIONS / CAVEATS (ADDITIONAL CONTEXT) 2: Public coverage notes that signatory counts shifted (e.g., 70, 85, then 88) as the summit progressed, illustrating dynamic endorsement rather than a fixed treaty posture. [Source: Hindustan Times, https://www.hindustantimes.com/india-news/ai-impact-summit-2026-70-countries-sign-new-delhi-ai-declaration-more-expected-101771639691358.html] ([hindustantimes.com](https://www.hindustantimes.com/india-news/ai-impact-summit-2026-70-countries-sign-new-delhi-ai-declaration-more-expected-101771639691358.html?utm_source=openai))
#
# - DECISION TAKEAWAY (ADDITIONAL CONTEXT) 2: If constrained to one action, executives should push for a formal, cross-border data/infrastructure collaboration via the Global AI Impact Commons to accelerate practical pilots. [Source: Economic Times, https://economictimes.indiatimes.com/tech/artificial-intelligence/delhi-declaration-urges-democratic-ai-for-social-good/articleshow/128675192.cms] ([economictimes.indiatimes.com](https://economictimes.indiatimes.com/tech/artificial-intelligence/india-calls-for-democratic-diffusion-of-ai-at-new-delhi-summit/articleshow/128647002.cms/?utm_source=openai))
# {'event_id': '1357_2026-02-21', 'news_date': '2026-02-21', 'output': '- REPORT SNAPSHOT 1: Official publication of the AI Impact Summit Declaration produced in the context of the India AI Impact Summit held in New Delhi (Feb 16–21, 2026); formal release on Feb 21, 2026. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- REPORT SNAPSHOT 2: Scope includes a global set of participants from more than 85 countries and international organizations; pillars span health, education, agriculture, climate, public services, and other sectors; time window Feb 16–21, 2026; approach is a voluntary, non-binding governance framework rather than a treaty. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- REPORT SNAPSHOT 3: Endorsers total 88 signatories as of Feb 21, 2026, including major powers (US, EU, China) and a mix of larger and smaller nations. [Source: The Times of India, https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms] ([timesofindia.indiatimes.com](https://timesofindia.indiatimes.com/technology/tech-news/ai-summit-2026-us-china-eu-and-a-total-of-88-countries-sign-new-delhi-declaration-on-global-ai-impact-whats-in-it-and-why-it-matters/articleshow/128648923.cms))\n\n- REPORT SNAPSHOT 4: The declaration is framed as voluntary and non-binding, with no enforceable safety commitments; sovereignty and national policy considerations are explicitly acknowledged. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- CORE FINDINGS (MOST IMPORTANT) 1: The Declaration is organized around seven Chakras (pillars): human capital development; social empowerment; trust and security; energy efficiency; AI for science; democratisation of AI resources; and use of AI for economic growth and social good. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- CORE FINDINGS (MOST IMPORTANT) 2: Outputs highlighted include the Global AI Impact Commons, the Charter for Democratic Diffusion of AI, the Trusted AI Commons, the International Network of AI for Science Institutions, and the AI Workforce Development Playbook. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- CORE FINDINGS (MOST IMPORTANT) 3: The declaration emphasizes industry-led voluntary measures and technical safeguards as part of a broader governance approach, rather than prescriptive binding rules. [Source: NDTV, https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893] ([ndtv.com](https://www.ndtv.com/india-news/85-countries-rally-behind-new-delhi-declaration-as-ai-impact-summit-wraps-up-11117893))\n\n- CORE FINDINGS (MOST IMPORTANT) 4: The initiative foregrounds energy efficiency and affordable access to AI infrastructure, including open-source approaches and diffusion of foundational AI resource ...
# ✅ Done
# - REPORT SNAPSHOT: Progress Report published February 2026 by Google AI and Google DeepMind; 16-page document with signatories Laurie Richardson and Helen King. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - REPORT SNAPSHOT: Global, multi-modal governance covering model development to post-launch monitoring; focuses on agentic/frontier risks and includes Gemini 3 and the Frontier Safety Framework. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: Content Adversarial Red Team (CART) completed over 350 exercises in 2025 across text, audio, images, video, including agentic AI. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: AlphaGenome analyzes up to 1,000,000 DNA letters at once; demonstrated in collaboration with academic centers. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: Flood forecasting initiative provides seven-day real-time riverine flood warnings; spans data-scarce regions and impacts over 2 billion people in 150 countries. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: Nigeria-based anticipatory action program led to 3,250 households evacuated and a 90% reduction in food insecurity. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: SAIF 2.0 adds three elements: an agent risk map, security capabilities across Google agents, and donation of risk-map data to the Coalition for Secure AI Risk Map. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: SynthID watermarking, 2.1 Content Credentials standard (C2PA), Pixel 10 integration, and SynthID Detector introduced (2025). [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: UK collaboration includes Frontier AI access for scientists and planning for a UK automated materials science lab in 2026. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - CORE FINDINGS: Proactive AGI risk work and defense-in-depth governance; researchers project AGI-related risks and mitigations with a view toward 2030. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - LIMITATIONS / CAVEATS: Not disclosed in cited sources: exact numeric gains for Gemini 3; sample sizes for external evaluators; certain claims are forward-looking or context-specific. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - WHAT THIS ACTUALLY MEANS: Governance adapts to each innovation via Launch Review forums and the AGI Futures Council overseeing long-term opportunities and safety priorities. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - WHAT THIS ACTUALLY MEANS: Emphasizes collaboration with governments, academia, industry, and civil society to set standards and accelerate responsible AI deployment. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - IMPLEMENTATION PLAYBOOK: Next quarter, formalize Frontier Safety Framework and embed Launch Review gating for frontier model launches. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - IMPLEMENTATION PLAYBOOK: Pilot User Alignment Critic and Agent Origin Sets in Chrome, add social-engineering mitigations, and require human oversight for sensitive actions. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - IMPLEMENTATION PLAYBOOK: Expand red-teaming and automated defense tooling; scale across products; share results with external evaluators and partner coalitions. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - METRICS TO TRACK: Track CART exercise counts, seven-day flood lead times, population reach, evacuation outcomes, and SynthID/C2PA adoption metrics. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
#
# - DECISION TAKEAWAY: If a team must do one thing, implement the Frontier Safety Framework with Critical Capability Levels gating for frontier AI. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))
# {'event_id': '1353_2026-02-22', 'news_date': '2026-02-22', 'output': '- REPORT SNAPSHOT: Progress Report published February 2026 by Google AI and Google DeepMind; 16-page document with signatories Laurie Richardson and Helen King. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- REPORT SNAPSHOT: Global, multi-modal governance covering model development to post-launch monitoring; focuses on agentic/frontier risks and includes Gemini 3 and the Frontier Safety Framework. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: Content Adversarial Red Team (CART) completed over 350 exercises in 2025 across text, audio, images, video, including agentic AI. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: AlphaGenome analyzes up to 1,000,000 DNA letters at once; demonstrated in collaboration with academic centers. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: Flood forecasting initiative provides seven-day real-time riverine flood warnings; spans data-scarce regions and impacts over 2 billion people in 150 countries. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: Nigeria-based anticipatory action program led to 3,250 households evacuated and a 90% reduction in food insecurity. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: SAIF 2.0 adds three elements: an agent risk map, security capabilities across Google agents, and donation of risk-map data to the Coalition for Secure AI Risk Map. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: SynthID watermarking, 2.1 Content Credentials standard (C2PA), Pixel 10 integration, and SynthID Detector introduced (2025). [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: UK collaboration includes Frontier AI access for scientists and planning for a UK automated materials science lab in 2026. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- CORE FINDINGS: Proactive AGI risk work and defense-in-depth governance; researchers project AGI-related risks and mitigations with a view toward 2030. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- LIMITATIONS / CAVEATS: Not disclosed in cited sources: exact numeric gains for Gemini 3; sample sizes for external evaluators; certain claims are forward-looking or context-specific. [Source: Google AI, https://ai.google/static/documents/ai-responsibility-update-2026.pdf] ([ai.google](https://ai.google/static/documents/ai-responsibility-update-2026.pdf))\n\n- WHAT THIS ACTUALLY MEANS: Governance adapts to each innovation via Launch Review forums and the AGI Futures Council overseeing long-term opportunities and safety priorities. [Source: Google AI, https://ai.google/static/documents/ai-respon ...
# ✅ Done

# %%
def save_research(research_json):
    supabase.table('research_assistant').insert({
        'event_id': research_json['event_id'],
        'model_provider': research_json['model_provider'],
        'news_date': research_json['news_date'],
        'output': research_json['output'],
        'topic': research_json['topic']
    }).execute()
