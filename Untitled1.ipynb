# %%
from dotenv import load_dotenv
load_dotenv()
import os
from supabase import create_client, Client
supabase_url = os.environ.get("SUPABASE_URL")
supabase_api_key = os.environ.get("SUPBASE_KEY")

supabase: Client = create_client(supabase_url, supabase_api_key)

# %%
from openai import OpenAI
client = OpenAI(api_key = os.getenv("OPENAI_API_KEY"))

# %%
def report_research(date):
    result = supabase.table('curation_selected_items')\
        .select('event_id, output,sources, news_date','topic')\
    .eq('news_date', date)\
    .eq('topic', 'Report')\
        .order('created_at', desc=False)\
        .execute()
    
    return result.data

# %%
report_deep_dive = report_research('2026-02-21')

# %%
report_deep_dive
# Out:
# [{'event_id': '1302_2026-02-21',
#   'output': 'India\'s Information Technology (Intermediary Guidelines and Digital Media Ethics Code) Amendment Rules, 2026 (IT Rules 2026) — recognized and regulated "Synthetically Generated Information" (SGI). Key requirements: mandatory visible labelling of AI-generated content and audio disclosures; embedding persistent digital identifiers/metadata for traceability (tampering prohibited); much faster removal timelines (3-hour takedown for government/court-declared unlawful content; 2-hour removal for highly sensitive deepfake intimate material); shorter complaint-resolution timelines; stricter pre-publication duties and technical verification requirements for Significant Social Media Intermediaries (SSMIs, platforms >5M users); failure to comply risks loss of safe-harbour protections. Rules brought into force from 20 Feb 2026.',
#   'sources': [{'url': 'https://www.lexology.com/library/detail.aspx?g=4db8f74b-7cec-4fdf-806f-ec24e856cd15',
#     'name': 'Lexology'}],
#   'news_date': '2026-02-21',
#   'topic': 'Report'},
#  {'event_id': '1304_2026-02-21',
#   'output': 'TechHQ (Feb 20, 2026) summarizes a new NBER working paper ("Firm Data on AI") based on surveys of ~6,000 executives across the US, UK, Germany and Australia. Key findings reported: 69% of firms use some form of AI (41% using text generation/LLMs, 28% ML data processing, 29% visual content); measured productivity gains averaged ~0.29% across the four countries over the past three years (with larger gains in some contexts); executives expect cumulative productivity gains of ~1.4% by 2028; early high-impact case studies (e.g., controlled studies showing ~14% gains in customer support with generative AI) exist but aggregate effects remain modest so far; workforce disruption is limited in early deployments and complementary investments (training, workflow redesign) are critical to capture measurable ROI.',
#   'sources': [{'url': 'https://techhq.com/news/enterprises-measuring-steady-gains-from-ai/',
#     'name': 'TechHQ'}],
#   'news_date': '2026-02-21',
#   'topic': 'Report'}]

# %%
def openai_research_workflow(research_input):
    for i in research_input:
        response = client.responses.create(
            model = "gpt-5-nano",
            tools = [{
                "type": "web_search"
            }],
            include = ["web_search_call.action.sources"],
            input = f"""
            You are a senior research analyst for Krux.

            TASK:
              Create a deep, fact-checked brief for ONE AI report/paper/benchmark release.
            
            GOAL:
              Extract the highest-value findings and implementation guidance so a later 100-word summary can capture most practical signal.
            
            OUTPUT FORMAT:
              - 12 to 16 bullet points.
              - Each bullet must include inline citations:
                [Source: <publisher>, <url>]
              - No text before or after bullets.
            
            MANDATORY STRUCTURE:
              1) REPORT SNAPSHOT
              - What was published, by whom, and when.
              - Scope: geography, sectors, sample size, time window, method type.
            
              2) CORE FINDINGS (MOST IMPORTANT)
              - 4 to 6 bullets with the strongest quantified findings.
              - Include exact numbers, not vague language.
            
              3) WHAT THIS ACTUALLY MEANS
              - 2 to 3 bullets translating findings into plain English implications for real teams.
            
              4) IMPLEMENTATION PLAYBOOK
              - 3 to 4 bullets: what organizations should do in the next quarter.
              - Include sequencing (e.g., data readiness -> pilot -> measurement -> rollout).
            
              5) METRICS TO TRACK
              - 1 or 2 bullets on KPIs teams should monitor to apply the report in practice.
            
              6) LIMITATIONS / CAVEATS
              - 1 or 2 bullets on methodology limits, sample bias, missing data, or uncertainty.
            
              7) DECISION TAKEAWAY
              - 1 bullet: “If a team only does one thing based on this report, it should be X.”
            
              STRICT RULES:
              - No hype, no opinion, no generic AI commentary.
              - Every factual claim must be source-backed.
              - If a key detail is missing, write: "Not disclosed in cited sources."
              - Prefer primary sources (original report/paper) over secondary articles.
              - If secondary coverage conflicts with primary report, prioritize primary and note conflict.
            
              QUALITY CHECK:
              - Must contain quantified findings.
              - Must contain actionable implementation steps.
              - Must clearly separate findings from interpretation.
              - Must include limitations.
            
              Report/event to research:
              Report summary: {i['output']}
              Source: {i['sources']}
            """,
        )

        output = response.output_text
        print(output)

        final_dictionary = {
            'event_id': i['event_id'],
            'news_date': i['news_date'],
            'output': output,
            'model_provider': 'openai',
            'topic': i['topic']
        }
        print(final_dictionary)

        save_research(final_dictionary)

        print("✅ Done")

# %%
openai_research_workflow(report_deep_dive)
# Out:
# - REPORT SNAPSHOT: Publication of the Information Technology (Intermediary Guidelines and Digital Media Ethics Code) Amendment Rules, 2026 (IT Rules 2026) by the Government of India, published in the Gazette of India on February 10, 2026, effective February 20, 2026. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - REPORT SNAPSHOT: Scope and scope irritants include intermediaries and Significant Social Media Intermediaries (SSMIs) under the IT Rules framework; key definitions and compliance timelines come into force on February 20, 2026. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - CORE FINDINGS: The amendment defines “synthetically generated information” (SGI) as audio, visual, or audio-visual content created or altered by a computer resource that appears real, with explicit exemptions for routine or good-faith editing, or the creation/presentation of documents or educational materials that do not produce false records. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - CORE FINDINGS: SGI content and related material must be prominently labelled and embedded with permanent metadata or a technical provenance mechanism (including a unique identifier) to enable traceability; intermediaries may not remove or suppress these labels/identifiers. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - CORE FINDINGS: Significant Social Media Intermediaries (SSMIs) face additional duties, including requiring user declarations regarding SGI and applying verification mechanisms; if SGI is identified, it must be clearly labelled. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - CORE FINDINGS: Takedown timelines are tightened to remove or disable access to unlawful SGI within three hours of a court order or reasoned government notice; earlier timeliness under the IT Rules 2021 was longer. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - CORE FINDINGS: Grievance redressal timelines are shortened (e.g., certain responses within seven days instead of fifteen days), and related timeframes for specific actions are adjusted accordingly. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - WHAT THIS ACTUALLY MEANS: Platforms must invest in SGI labeling, traceability infrastructure, and automated detection/tools to enforce the SGI framework; onboarding and ongoing governance must reflect the three key pillars of labeling, metadata, and user disclosures. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - WHAT THIS ACTUALLY MEANS: The amendments introduce potential penalties and enforcement actions tied to SGI and SGI-associated activities under existing Indian laws (e.g., Bharatiya Nyaya Sanhita, 2023 and other statutes), reinforcing compliance expectations for platforms and users. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - IMPLEMENTATION PLAYBOOK: Data readiness and SGI risk mapping should begin by inventorying computer resources that could generate SGI and mapping the content generation workflows that feed into intermediaries. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - IMPLEMENTATION PLAYBOOK: Run a targeted pilot to label SGI and embed permanent metadata on a representative subset of content, validating the labeling visibility and traceability workflows prior to broader rollout. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - IMPLEMENTATION PLAYBOOK: Roll out platform-wide labeling and metadata requirements, implement user-declaration flows for SGI where feasible, and establish quarterly user-notice communications along with revised governance and compliance processes. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - METRICS TO TRACK: Time-to-removal for SGI content (target three hours after a court order or authorized notice) and proportion of SGI content that is correctly labeled/traceable, plus adherence to revised grievance timeliness (e.g., seven-day resolution where applicable). [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - LIMITATIONS / CAVEATS: The rules preserve explicit exemptions for routine editing, educational materials, or content that does not create false records, and some enforcement details or thresholds may be clarified only through future notifications or clarifications. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
#
# - DECISION TAKEAWAY: If a team can implement one priority, focus on building robust SGI labeling with embedded metadata and a reliable traceability chain across major platforms to meet the three-hour takedown demand. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]
# {'event_id': '1302_2026-02-21', 'news_date': '2026-02-21', 'output': '- REPORT SNAPSHOT: Publication of the Information Technology (Intermediary Guidelines and Digital Media Ethics Code) Amendment Rules, 2026 (IT Rules 2026) by the Government of India, published in the Gazette of India on February 10, 2026, effective February 20, 2026. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- REPORT SNAPSHOT: Scope and scope irritants include intermediaries and Significant Social Media Intermediaries (SSMIs) under the IT Rules framework; key definitions and compliance timelines come into force on February 20, 2026. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- CORE FINDINGS: The amendment defines “synthetically generated information” (SGI) as audio, visual, or audio-visual content created or altered by a computer resource that appears real, with explicit exemptions for routine or good-faith editing, or the creation/presentation of documents or educational materials that do not produce false records. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- CORE FINDINGS: SGI content and related material must be prominently labelled and embedded with permanent metadata or a technical provenance mechanism (including a unique identifier) to enable traceability; intermediaries may not remove or suppress these labels/identifiers. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- CORE FINDINGS: Significant Social Media Intermediaries (SSMIs) face additional duties, including requiring user declarations regarding SGI and applying verification mechanisms; if SGI is identified, it must be clearly labelled. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- CORE FINDINGS: Takedown timelines are tightened to remove or disable access to unlawful SGI within three hours of a court order or reasoned government notice; earlier timeliness under the IT Rules 2021 was longer. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- CORE FINDINGS: Grievance redressal timelines are shortened (e.g., certain responses within seven days instead of fifteen days), and related timeframes for specific actions are adjusted accordingly. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- WHAT THIS ACTUALLY MEANS: Platforms must invest in SGI labeling, traceability infrastructure, and automated detection/tools to enforce the SGI framework; onboarding and ongoing governance must reflect the three key pillars of labeling, metadata, and user disclosures. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- WHAT THIS ACTUALLY MEANS: The amendments introduce potential penalties and enforcement actions tied to SGI and SGI-associated activities under existing Indian laws (e.g., Bharatiya Nyaya Sanhita, 2023 and other statutes), reinforcing compliance expectations for platforms and users. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- IMPLEMENTATION PLAYBOOK: Data readiness and SGI risk mapping should begin by inventorying computer resources that could generate SGI and mapping the content generation workflows that feed into intermediaries. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- IMPLEMENTATION PLAYBOOK: Run a targeted pilot to label SGI and embed permanent metadata on a representative subset of content, validating the labeling visibility and traceability workflows prior to broader rollout. [Source: The Gazette of India, https://egazette.gov.in/WriteReadData/2026/269993.pdf]\n\n- IMPLEMENTATION PLAYBOOK: Roll out platform-wide labeling and metadata requirements, implement user-declaration flows for SGI where feasible, and establish quarterly user-notice communications along w ...
# ✅ Done
# - REPORT SNAPSHOT — What was published, by whom, and when: NBER Working Paper 34836, “Firm Data on AI,” by Ivan Yotzov, Jose Maria Barrero, Nicholas Bloom, Philip Bunn, Steven J. Davis, Kevin M. Foster, Aaron Jalca, Brent H. Meyer, Paul Mizen, Michael A. Navarrete, Pawel Smietanka, Gregory Thwaites, and Ben Zhe Wang; Issue Date February 2026. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - REPORT SNAPSHOT — Scope: geography, sectors, sample size, time window, method type: Almost 6,000 CFOs/CEOs/executives surveyed across the US, UK, Germany and Australia; cross-country, representative firm samples; outcomes assessed over the past 3 years with projected effects over the next 3 years; method = firm-level survey. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS (MOST IMPORTANT) — Adoption rate: Around 70% of firms actively use AI. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS — Executive usage: More than two-thirds of top executives regularly use AI; average usage is 1.5 hours per week; about 25% report no AI use. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS — Current impact: Over 80% of firms report no impact on employment or productivity from AI in the past 3 years. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS — Near-term projections: Firms forecast productivity up 1.4%, output up 0.8%, and employment down 0.7% over the next 3 years; employees forecast a net employment increase of about 0.5% over the same horizon. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS — AI category breakdown: Not disclosed in cited sources (no published breakdown by technologies such as text generation, ML data processing, or visual content within the primary report). [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - CORE FINDINGS — Heterogeneity: Adoption is more prevalent among larger, more productive firms. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - WHAT THIS ACTUALLY MEANS — Near-term ROI clarity: The aggregate productivity gains observed to date are modest, implying substantial ROI requires deliberate complements (training, workflow redesign, governance). [Source: Fortune, https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-age/] ([fortune.com](https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-technology-age/))
#
# - WHAT THIS ACTUALLY MEANS — Expectation vs reality: Executives anticipate sizable gains (1.4% productivity, 0.8% output) while most employees expect job growth or little disruption, signaling a misalignment that can affect deployment buy-in. [Source: Fortune, https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-age/] ([fortune.com](https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-technology-age/))
#
# - IMPLEMENTATION PLAYBOOK — Step 1 (next quarter): Establish cross-functional AI ROI governance and identify high-potential, data-ready use cases; prepare clean data assets and owner accountability. [Source: KPMG Tech Executives 2026 report] ([kpmg.com](https://kpmg.com/xx/en/media/press-releases/2026/01/tech-executives-double-down-on-ai-talent-and-adapative-strategies.html?utm_source=openai))
#
# - IMPLEMENTATION PLAYBOOK — Step 2: Design controlled pilots with explicit success criteria and a pre-registered measurement plan; align pilots with measurable ROI pillars. [Source: KPMG Tech Executives 2026; Fortune coverage of ROI concerns] ([kpmg.com](https://kpmg.com/xx/en/media/press-releases/2026/01/tech-executives-double-down-on-ai-talent-and-adapative-strategies.html?utm_source=openai))
#
# - IMPLEMENTATION PLAYBOOK — Step 3: Measure ROI across three pillars (financial returns, operational efficiency, strategic positioning); use multi-metric dashboards to reduce single-metric bias. [Source: KPMG Tech Executives 2026] ([kpmg.com](https://kpmg.com/xx/en/media/press-releases/2026/01/tech-executives-double-down-on-ai-talent-and-adapative-strategies.html?utm_source=openai))
#
# - IMPLEMENTATION PLAYBOOK — Step 4: Sequencing for rollout: data readiness -> pilot -> measurement -> scalable rollout; institute change-management and governance to sustain benefits. [Source: KPMG Tech Executives 2026] ([kpmg.com](https://kpmg.com/xx/en/media/press-releases/2026/01/tech-executives-double-down-on-ai-talent-and-adapative-strategies.html?utm_source=openai))
#
# - METRICS TO TRACK — KPIs to apply the report in practice: AI usage hours per week by executives (around 1.5 hours observed) and measured productivity gains (targeting or exceeding ~1.4% annually over multi-year horizons). [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - LIMITATIONS / CAVEATS — Methodology caveats: Not all technology categories are broken out in the primary data; results are self-reported by executives; cross-country comparability may be limited; three-year horizon extrapolations assume linear trends. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))
#
# - DECISION TAKEAWAY — If a team should do one thing based on this report: implement a structured ROI measurement framework for AI pilots that tracks financial, productivity, and employment-related outcomes across multiple use cases. [Source: Fortune, https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-age/] ([fortune.com](https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-technology-age/))
# {'event_id': '1304_2026-02-21', 'news_date': '2026-02-21', 'output': '- REPORT SNAPSHOT — What was published, by whom, and when: NBER Working Paper 34836, “Firm Data on AI,” by Ivan Yotzov, Jose Maria Barrero, Nicholas Bloom, Philip Bunn, Steven J. Davis, Kevin M. Foster, Aaron Jalca, Brent H. Meyer, Paul Mizen, Michael A. Navarrete, Pawel Smietanka, Gregory Thwaites, and Ben Zhe Wang; Issue Date February 2026. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- REPORT SNAPSHOT — Scope: geography, sectors, sample size, time window, method type: Almost 6,000 CFOs/CEOs/executives surveyed across the US, UK, Germany and Australia; cross-country, representative firm samples; outcomes assessed over the past 3 years with projected effects over the next 3 years; method = firm-level survey. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS (MOST IMPORTANT) — Adoption rate: Around 70% of firms actively use AI. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS — Executive usage: More than two-thirds of top executives regularly use AI; average usage is 1.5 hours per week; about 25% report no AI use. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS — Current impact: Over 80% of firms report no impact on employment or productivity from AI in the past 3 years. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS — Near-term projections: Firms forecast productivity up 1.4%, output up 0.8%, and employment down 0.7% over the next 3 years; employees forecast a net employment increase of about 0.5% over the same horizon. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS — AI category breakdown: Not disclosed in cited sources (no published breakdown by technologies such as text generation, ML data processing, or visual content within the primary report). [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- CORE FINDINGS — Heterogeneity: Adoption is more prevalent among larger, more productive firms. [Source: NBER, https://www.nber.org/papers/w34836] ([nber.org](https://www.nber.org/papers/w34836))\n\n- WHAT THIS ACTUALLY MEANS — Near-term ROI clarity: The aggregate productivity gains observed to date are modest, implying substantial ROI requires deliberate complements (training, workflow redesign, governance). [Source: Fortune, https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-age/] ([fortune.com](https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-technology-age/))\n\n- WHAT THIS ACTUALLY MEANS — Expectation vs reality: Executives anticipate sizable gains (1.4% productivity, 0.8% output) while most employees expect job growth or little disruption, signaling a misalignment that can affect deployment buy-in. [Source: Fortune, https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-age/] ([fortune.com](https://fortune.com/2026/02/17/ai-productivity-paradox-ceo-study-robert-solow-information-technology-age/))\n\n- IMPLEMENTATION PLAYBOOK — Step 1 (next quarter): Establish cross-functional AI ROI governance and identify high-potential, data-ready use cases; prepare clean data assets and owner accountability. [Source: KPMG Tech Executives 2026 report] ([kpmg.com](https://kpmg.com/xx/en/media/press-releases/2026/01/tech-executives-double-down-on-ai-talent-and-adapative-strategies.html?utm_source=openai))\n\n- IMPLEMENTATION PLAYBOOK — Step 2: Design controlled pilots with explicit success criteria and a pre-registered measurement plan; align pilots with measurable ROI pillars. [Source: KPMG Tech Executi ...
# ✅ Done

# %%
def save_research(research_json):
    supabase.table('research_assistant').insert({
        'event_id': research_json['event_id'],
        'model_provider': research_json['model_provider'],
        'news_date': research_json['news_date'],
        'output': research_json['output'],
        'topic': research_json['topic']
    }).execute()
